# %%
class Morph:
    def __init__(self, surface, base, pos, pos1):
        self.surface = surface
        self.base = base
        self.pos = pos
        self.pos1 = pos1
        
    def __str__(self):
        return 'surface: {0}, base: {1}, pos: {2}, po1: {3}'.format(self.surface, self.base, self.pos, self.pos1)

# %%
class Chunk:
    def __init__(self, morphs, dst):
        self.morphs = morphs
        self.dst = dst
        self.srcs = []
        self.surfaces2 = ''
        
        for morph in self.morphs:
            if morph.pos != '記号':
                self.surfaces2 += morph.surface
        
    def __str__(self):
        return 'surfaces2: {0}, dst: {1}, srcs: {2}'.format(self.surfaces2, self.dst, self.srcs)

# %%
fname = 'neko.txt.cabocha'
Morphs_list = []
Morphs = []
Chunks_list = []
Chunks = []
Chunk_Morphs = []
EOS_count = 0
src_dst = []

with open(fname) as file:
    for line in file:
        line = line.rstrip('\n')
        if line[0] == '*':
            if len(Chunk_Morphs) > 0:
                Chunks.append(Chunk(Chunk_Morphs, phrase_info[2][:-1]))
            Chunk_Morphs = []
            phrase_info = line.split(' ')
            if EOS_count > 0:
                for s_d in src_dst:
                    if int(s_d[1]) != -1:
                        Chunks[int(s_d[1])].srcs.append(s_d[0])
                src_dst = []
                Chunks_list.append(Chunks)
                Chunks = []
                EOS_count -= 1
            while EOS_count > 0:
                Chunks_list.append([])
                EOS_count -= 1
            src_dst.append([phrase_info[1], phrase_info[2][:-1]])
            continue
        if line == 'EOS':
            Morphs_list.append(Morphs)
            Morphs = []
            EOS_count += 1
            continue
        morpheme = line.split('\t')
        surface = morpheme[0]
        base = morpheme[1].split(',')[6]
        pos = morpheme[1].split(',')[0]
        pos1 = morpheme[1].split(',')[1]
        Morphs.append(Morph(surface, base, pos, pos1))
        Chunk_Morphs.append(Morph(surface, base, pos, pos1))
        
for Chunks in Chunks_list:
    for c in Chunks:
        src = c
        dst = Chunks[int(c.dst)]
        flag, flag2 = 0, 0
        
        for morph in src.morphs:
            if morph.pos == '名詞':
                flag = 1
        for morph in dst.morphs:
            if morph.pos == '動詞':
                flag2 = 1
                
        if c.dst != '-1' and flag == 1 and flag2 == 1:
            print('{0}\t{1}'.format(c.surfaces2, Chunks[int(c.dst)].surfaces2))
# Out:
# どこで	生れた
# かとんと	つかぬ
# 見当が	つかぬ
# した所で	泣いて
# いた事だけは	記憶している
# 吾輩は	見た
# ここで	始めて
# ものを	見た
# あとで	聞くと
# 我々を	捕えて
# 掌に	載せられて
# スーと	持ち上げられた
# 時	フワフワした
# 感じが	あったばかりである
# 上で	落ちついて
# 顔を	見たのが
# ものの	見始であろう
# ものだと	思った
# 感じが	残っている
# 今でも	残っている
# 第一毛をもって	装飾されべきはずの
# 顔が	つるつるして
# その後	逢ったが
# 猫にも	逢ったが
# 一度も	出会わし
# 真中が	突起している
# 中から	吹く
# 煙を	吹く
# 咽せぽくて	弱った
# 人間の	飲む
# 事は	知った
# 頃	知った
# 裏で	坐って
# 心持に	坐って
# 速力で	運転し始めた
# 書生が	動くのか
# 動くのか	動くのか
# 自分だけが	動くのか
# 動くのか	分らないが
# 眼が	廻る
# 胸が	悪くなる
# 音が	して
# 眼から	出た
# 火が	出た
# それまでは	記憶しているが
# 記憶しているが	分らない
# あとは	分らない
# 事やら	分らない
# 気が	付いて
# 書生は	いない
# たくさん	おった
# 兄弟が	見えぬ
# 一疋も	見えぬ
# 母親さえ	隠してしまった
# 姿を	隠してしまった
# 所とは	違って
# 眼を	明いていられぬくらいだ
# 吾輩は	棄てられたのである
# 上から	棄てられたのである
# 急に	棄てられたのである
# 中へ	棄てられたのである
# 思いで	這い出すと
# 笹原を	這い出すと
# 向うに	ある
# 池が	ある
# 吾輩は	見た
# 前に	坐って
# 分別も	出ない
# 書生がまた	来てくれるかと
# 迎に	来てくれるかと
# ニャーと	やって
# 誰も	来ない
# 池の上を	渡って
# 風が	渡って
# 日が	かかる
# 暮れ	かかる
# 腹が	減って来た
# 非常に	減って来た
# 食物の	ある
# 所まで	ある
# 決心を	して
# 池を	廻り始めた
# 左りに	廻り始めた
# そこを	我慢して
# 我慢して	這って行くと
# 無理やりに	這って行くと
# 事で	出た
# 所へ	出た
# ここへ	這入ったら
# 竹垣の	崩れた
# 穴から	もぐり込んだ
# 邸内に	もぐり込んだ
# もので	餓死したかも知れんのである
# 竹垣が	破れていなかったなら
# 吾輩は	餓死したかも知れんのである
# 路傍に	餓死したかも知れんのである
# 蔭とは	云った
# 穴は	なっている
# 今日に	至るまで
# 吾輩が	訪問する
# 三毛を	訪問する
# 通路に	なっている
# 邸へは	忍び込んだものの
# うちに	暗くなる
# 腹は	減る
# 雨が	降って来るという
# 始末で	出来なくなった
# 猶予が	出来なくなった
# 方へ	あるいて行く
# 方へと	あるいて行く
# 今から	考えると
# 時は	おったのだ
# 内に	這入って
# ここで	遭遇したのである
# 吾輩は	遭遇したのである
# 人間を	見るべき
# 機会に	遭遇したのである
# 第一に	逢ったのが
# これは	抛り出した
# 書生より	見るや
# 方で	見るや
# 吾輩を	見るや
# 否やいきなり	つかんで
# 頸筋を	つかんで
# 表へ	抛り出した
# 駄目だと	思ったから
# 眼を	ねぶって
# 運を	任せていた
# 天に	任せていた
# 寒いのには	出来ん
# 我慢が	出来ん
# 吾輩は	這い上った
# 隙を	見て
# 台所へ	這い上った
# 吾輩は	這い上り
# 何でも	繰り返したのを
# 事を	繰り返したのを
# 四五遍	繰り返したのを
# 繰り返したのを	記憶している
# 時に	云う
# おさんと	云う
# 者は	いやになった
# 偸んで	してやってから
# 返報を	してやってから
# 痞が	下りた
# 吾輩が	つまみ出されようとした
# 最後に	つまみ出されようとした
# ときに	来た
# 主人が	来た
# 何だと	いいながら
# 出て	来た
# 下女は	困りますと
# 吾輩を	ぶら下げて
# 方へ	向けて
# 小猫が	困りますと
# 出しても	上って来て
# 御台所へ	上って来て
# 主人は	おったが
# 毛を	撚りながら
# 顔を	眺めて
# そんなら	置いてやれといったまま
# 内へ	置いてやれといったまま
# 置いてやれといったまま	這入ってしまった
# 奥へ	這入ってしまった
# 主人は	見えた
# 口を	聞かぬ
# 人と	見えた
# 下女は	抛り出した
# 口惜しそうに	抛り出した
# 吾輩を	抛り出した
# 台所へ	抛り出した
# 吾輩は	したのである
# 家を	極める
# 住家と	極める
# 事に	したのである
# 滅多に	合せる
# 吾輩と	合せる
# 顔を	合せる
# 学校から	帰ると
# 終日	這入った
# 書斎に	這入った
# 勉強家だと	思っている
# ものが	いうような
# 吾輩は	見るが
# 忍び足に	覗いて
# 書斎を	覗いて
# 彼は	ある
# 昼寝を	している
# 事が	ある
# 上に	たらしている
# 涎を	たらしている
# 彼は	あらわしている
# 胃弱で	帯びて
# 色が	帯びて
# 黄色を	帯びて
# 徴候を	あらわしている
# 癖に	食う
# 大飯を	食う
# 大飯を	食った
# 後で	飲む
# タカジヤスターゼを	飲む
# 後で	ひろげる
# 書物を	ひろげる
# 二三ページ	読むと
# 涎を	垂らす
# 上へ	垂らす
# これが	繰り返す
# 毎夜	繰り返す
# 吾輩は	ある
# 猫ながら	考える
# 事が	ある
# 人間と	生れたら
# 教師と	なるに
# 猫にでも	出来ぬ
# 主人に	云わせると
# ないそうで	鳴らしている
# 彼は	鳴らしている
# 友達が	来る
# 度に	鳴らしている
# 不平を	鳴らしている
# 吾輩が	住み込んだ
# 家へ	住み込んだ
# どこへ	行っても
# 相手に	してくれ
# 珍重されなかったかは	分る
# 今日に	至るまで
# 名前さえ	つけてくれないのでも
# つけてくれないのでも	分る
# 吾輩は	つとめた
# 仕方がないから	入れてくれた
# 限り	入れてくれた
# 吾輩を	入れてくれた
# 傍に	いる
# 事を	つとめた
# 朝主人が	読む
# 新聞を	読む
# ときは	乗る
# 上に	乗る
# 彼が	する
# 昼寝を	する
# ときは	乗る
# 背中に	乗る
# これは	やむを得んのである
# その後	した
# 上	した
# 朝は	した
# 上	した
# 夜は	した
# 上	した
# 昼は	した
# 椽側へ	寝る
# 事と	した
# 夜に	入って
# 寝床へ	もぐり込んで
# いっしょに	ねる
# 小供というのは	寝る
# 三つで	なると
# 夜に	なると
# 二人が	寝る
# 一つ	寝る
# 床へ	入って
# 一間へ	寝る
# 吾輩は	割り込むのであるが
# いつでも	見出して
# 中間に	見出して
# 己れを	見出して
# 余地を	見出して
# 割り込むのであるが	なる
# 運悪く	醒ますが
# 一人が	醒ますが
# 眼を	醒ますが
# 事に	なる
# 小供は	泣き出すのである
# 猫が	来た
# 猫が	来たと
# 夜中でも	泣き出すのである
# 何でも	泣き出すのである
# 声で	泣き出すのである
# 主人は	飛び出してくる
# 眼を	さまして
# 部屋から	飛び出してくる
# せんだってなどは	叩かれた
# 物指で	叩かれた
# 尻ぺたを	叩かれた
# 吾輩は	断言せざるを得ないようになった
# 人間と	同居して
# 同居して	観察すれば
# 彼等を	観察すれば
# 観察すれば	する
# 彼等は	断言せざるを得ないようになった
# ものだと	断言せざるを得ないようになった
# 吾輩が	同衾する
# ごときに	至っては
# 時は	押し込んだりする
# 人を	したり
# 逆さに	したり
# 頭へ	かぶせたり
# 袋を	かぶせたり
# 中へ	押し込んだりする
# しようものなら	加える
# 家内総がかりで	追い廻して
# 迫害を	加える
# この間も	磨いだら
# 畳で	磨いだら
# 爪を	磨いだら
# 細君が	怒って
# 非常に	怒って
# それから	入れない
# 容易に	入れない
# 座敷へ	入れない
# 板の間で	顫えていても
# 他が	顫えていても
# 吾輩の	尊敬する
# 白君は	四疋産まれたのである
# 子猫を	四疋産まれたのである
# 書生が	行って
# 三日目に	行って
# そいつを	持って
# 池へ	持って
# 四疋ながら	棄てて
# 白君は	いわれた
# 涙を	流して
# 一部始終を	話した
# 上	剿滅せねばならぬと
# 我等猫族が	して
# 愛を	して
# 家族的生活を	するには
# 人間と	戦って
# これを	剿滅せねばならぬと
# 剿滅せねばならぬと	いわれた
# 議論と	思う
# 三毛君などは	解していないと
# 事を	解していないと
# 大に	憤慨している
# 同族間では	なっている
# 臍でも	見付けた
# 先に	見付けた
# ものが	食う
# これを	食う
# 権利が	ある
# ものと	なっている
# 相手が	守らなければ
# 規約を	守らなければ
# 腕力に	訴えて
# 我等が	見付けた
# 御馳走は	掠奪せらるるのである
# ために	掠奪せらるるのである
# 彼等は	すましている
# 強力を	頼んで
# 正当に	食い得べき
# 吾人が	食い得べき
# ものを	奪って
# 白君は	持っている
# 家に	おり
# 三毛君は	持っている
# 主人を	持っている
# 家に	住んでいるだけ
# その日	送られればよい
# 日が	送られればよい
# いつまでも	栄える
# 気を	待つが
# 時節を	待つが
# 我儘で	思い出したから
# 主人が	失敗した
# 我儘で	失敗した
# 話を	しよう
# いって人に	勝れて
# 何にでも	出したがる
# 手を	出したがる
# 俳句を	やって
# ほととぎすへ	したり
# 投書を	したり
# 新体詩を	出したり
# 明星へ	出したり
# 英文を	かいたり
# 弓に	凝ったり
# 謡を	習ったりまた
# ときは	鳴らしたりするが
# ヴァイオリンなどを	鳴らしたりするが
# 事には	おらん
# どれも	おらん
# これも	おらん
# 物に	なって
# 癖	やり出すと
# 中で	うたって
# 謡を	うたって
# 近所で	つけられている
# 渾名を	つけられている
# もので	繰返している
# これは	繰返している
# 宗盛にて	繰返している
# 候を	繰返している
# みんなが	吹き出す
# そら宗盛だと	吹き出す
# 主人が	なった
# 考に	なった
# ものか	帰って来た
# 吾輩の	住み込んでから
# 一月ばかり後の	ある
# 月給日に	帰って来た
# 包みを	提げて
# 何を	買って来たのかと
# 買って来たのかと	思うと
# 紙で	やめて
# 今日から	やめて
# 俳句を	やめて
# 絵を	見えた
# 決心と	見えた
# ものは	かいている
# 毎日書斎で	かいている
# 昼寝も	かいている
# しないで	かいている
# 絵ばかり	かいている
# かき	上げた
# ものを	見ると
# 何を	かいた
# ものやら	つかない
# 誰にも	つかない
# 鑑定が	つかない
# ものか	聞いた
# 友人で	来た
# 美学とかを	やっている
# 人が	来た
# 時に	しているのを
# 話を	しているのを
# しているのを	聞いた
# 人のを	見ると
# ないようだが	感ずる
# 自ら	とって
# 筆を	とって
# 今更のように	感ずる
# 眼鏡越に	見ながら
# 顔を	見ながら
# 初めから	かけないさ
# 上手には	かけないさ
# 想像ばかりで	かける
# 画が	かける
# アンドレア・デル・サルトが	言った
# 事が	ある
# 画を	かくなら
# 何でも	写せ
# 自然その物を	写せ
# 天に	あり
# 星辰	あり
# 地に	あり
# 露華	あり
# 禽	あり
# 獣	あり
# 池に	あり
# 金魚	あり
# 枯木に	あり
# 寒鴉	あり
# 君も	かこうと
# 画を	かこうと
# 写生を	したら
# へえアンドレア・デル・サルトが	いった
# 事を	いった
# 事が	あるかい
# その通りだと	感心している
# 主人は	感心している
# 裏には	見えた
# 笑が	見えた
# 翌日	やっている
# 吾輩は	やっている
# 例のごとく	していたら
# 椽側に	していたら
# 昼寝を	していたら
# 主人が	出て来て
# 書斎から	出て来て
# 後ろで	やっている
# 何か	やっている
# 眼が	覚めて
# 何を	しているかと
# 一分ばかり	あけて
# 細目に	あけて
# 眼を	あけて
# 彼は	極め込んでいる
# アンドレア・デル・サルトを	極め込んでいる
# 吾輩は	禁じ得なかった
# 有様を	見て
# 失笑するのを	禁じ得なかった
# 彼は	写生しつつあるのである
# 友に	揶揄せられたる
# 結果として	写生しつつあるのである
# 手初めに	写生しつつあるのである
# 吾輩を	写生しつつあるのである
# 吾輩は	寝た
# 十分	寝た
# 欠伸が	したくて
# 主人が	執っているのを
# 熱心に	執っているのを
# 筆を	執っているのを
# 執っているのを	動いては
# 気の毒だと	思って
# 辛棒して	おった
# 彼は	彩っている
# 今	かき上げて
# 輪廓を	かき上げて
# あたりを	彩っている
# 色	彩っている
# 吾輩は	自白する
# 毛並と	いい顔の
# 造作と	いい
# 猫に	勝るとは
# 吾輩でも	思われない
# 今	描き出されつつあるような
# 主人に	描き出されつつあるような
# 姿とは	思われない
# 第一色が	違う
# 吾輩は	有している
# 猫のごとく	含める
# 黄を	含める
# 灰色に	有している
# 皮膚を	有している
# これだけは	思う
# 誰が	見ても
# 事実と	思う
# 彩色を	見ると
# 褐色でもない	さればとて
# これらを	交ぜた
# 色であると	いうより
# これは	写生したのだから
# ところを	写生したのだから
# 写生したのだから	判然しないのである
# 所さえ	見えないから
# 盲猫だか	寝ている
# 猫だか	判然しないのである
# 吾輩は	思った
# 熱心には	感服せざるを得ない
# さっきから	うしている
# 小便が	うしている
# 催	うしている
# 筋肉は	むずむずする
# 一分も	出来ぬ
# 猶予が	出来ぬ
# 仕儀と	なったから
# 失敬して	して
# 両足を	して
# 前へ	して
# 存分の	して
# 首を	押し出して
# あーあと	した
# 欠伸を	した
# 打ち壊わしたのだから	這い出した
# ついでに	行って
# 裏へ	行って
# 用を	足そうと
# 主人は	怒鳴った
# 怒りを	掻き交ぜたような
# 声を	して
# 中から	怒鳴った
# 馬鹿野郎と	怒鳴った
# 人を	罵る
# ほかに	知らないのだから
# 言いようを	知らないのだから
# 知らないのだから	知らないで
# 仕方がないが	知らないで
# 今まで	知らないで
# 気も	知らないで
# 失敬だと	思う
# それも	受けるが
# 平生	乗る
# 吾輩が	乗る
# 背中へ	乗る
# 時に	するなら
# 顔でも	するなら
# 漫罵も	甘んじて
# こっちの	便利になる
# 小便に	立ったのを
# ものは	増長している
# 慢じて	増長している
# みんな	増長している
# ものが	出て来て
# 先どこまで	増長するか
# 増長するか	分らない
# 我儘も	我慢するが
# 我慢するが	ある
# 吾輩は	ある
# 不徳について	ある
# これよりも	ある
# 数倍	悲しむべき
# 報道を	した
# 耳に	した
# 事が	ある
# 裏に	ある
# 茶園が	ある
# 瀟洒と	した
# 日の	当る
# 小供が	騒いで
# 昼寝の	出来ない
# 折などは	養うのが
# 吾輩は	養うのが
# いつでも	養うのが
# ここへ	養うのが
# 出て浩然の気を	養うのが
# 二時頃であったが	運ばした
# 吾輩は	運ばした
# 昼飯後快よく	一睡した
# 後	運ばした
# 茶園へと	運ばした
# 歩を	運ばした
# 根を	一本一本嗅ぎながら
# 一本一本嗅ぎながら	くると
# そばまで	くると
# 枯菊を	押し倒して
# その上に	寝ている
# 猫が	寝ている
# 前後不覚に	寝ている
# 彼は	眠っている
# 吾輩の	近づくのも
# 近づくのも	心付かざるごとくまた
# 無頓着なるごとく	眠っている
# 鼾を	して
# 体を	眠っている
# 横えて	眠っている
# 庭内に	睡られる
# ものが	睡られる
# かくまで	睡られる
# 平気に	睡られる
# ものかと	驚かざるを得なかった
# 吾輩は	驚かざるを得なかった
# 窃かに	驚かざるを得なかった
# 度胸に	驚かざるを得なかった
# 午を	過ぎたる
# 太陽は	思われた
# 光線を	かけて
# 上に	かけて
# 抛げ	かけて
# 間より	見えぬ
# 眼に	見えぬ
# 炎でも	思われた
# 燃え出ずるように	思われた
# 彼は	有している
# 大王とも	云うべき
# 体格を	有している
# 倍は	ある
# 吾輩は	落ちた
# 念と	佇立して
# 心に	忘れて
# 前後を	忘れて
# 前に	佇立して
# 佇立して	眺めていると
# 風が	落ちた
# 上から	出たる
# 枝を	誘って
# 葉が	落ちた
# 茂みに	落ちた
# 大王は	開いた
# 眼を	開いた
# 今でも	記憶している
# 眼は	輝いていた
# 人間の	珍重する
# ものよりも	輝いていた
# 彼は	しない
# 身動きも	しない
# 奥から	射るごとき
# 光を	あつめて
# 上に	あつめて
# 御めえは	云った
# 何だと	云った
# 大王に	しては
# 底に	籠っているので
# 犬をも	籠っているので
# 力が	籠っているので
# 吾輩は	抱いた
# 恐れを	抱いた
# 挨拶を	しないと
# 険呑だと	思ったから
# 平気を	装って
# 冷然と	答えた
# 時	おった
# 心臓は	おった
# 鼓動して	おった
# 大に	軽蔑せる
# 猫が	聞いて
# 全てえ	住んでるんだ
# どこに	住んでるんだ
# 吾輩は	いるのだ
# 家に	いるのだ
# 事だろうと	思った
# いやに	瘠せてるじゃねえかと
# 大王だけに	吹きかける
# 気焔を	吹きかける
# 言葉付から	察すると
# 察すると	思われない
# 猫とも	思われない
# 膏	切って
# ところを	見ると
# 御馳走を	食ってるらしい
# 豊かに	暮しているらしい
# 吾輩は	聞かざるを得なかった
# 誰だいと	聞かざるを得なかった
# 近辺で	知らぬ
# 誰も	交際しない
# 的に	なっている
# 吾輩は	起すと同時に
# 名を	聞いて
# 感じを	起すと同時に
# 念も	生じたのである
# 吾輩は	見た
# 無学であるかを	試してみようと
# 問答を	して
# 極って	いら
# 主人を	見ねえ
# 車屋に	いると
# 御馳走が	食えると
# 何に	しねえつもりだ
# なんざ	しねえつもりだ
# 国へ	行ったって
# 食い物に	しねえつもりだ
# 不自由は	しねえつもりだ
# 御めえなんかも	廻っていねえで
# 茶畠ばかり	廻っていねえで
# 後へ	くっ付いて来て
# 一と	たたねえ
# 月と	たたねえ
# うちに	見違えるように
# 見違えるように	太れるぜ
# 事に	しよう
# 家は	思われる
# 大きいのに	住んでいるように
# 住んでいるように	思われる
# うちなんか	たって
# いくら	たって
# 腹の	足しに
# 彼は	立ち去った
# 大に	障った
# 肝癪に	障った
# 様子で	立ち去った
# 寒竹を	そいだような
# 耳を	し
# きりと	付かせて
# あららかに	立ち去った
# 吾輩が	なったのは
# 黒と	なったのは
# 知己に	なったのは
# その後	邂逅する
# 吾輩は	邂逅する
# 黒と	邂逅する
# 毎に	吐く
# 彼は	吐く
# 気焔を	吐く
# 先に	したという
# 吾輩が	したという
# 耳に	したという
# 不徳事件も	聞いたのである
# 黒から	聞いたのである
# 例のごとく	質問した
# 黒は	していると
# 中で	寝転びながら
# 雑談を	していると
# 彼は	質問した
# 自慢話しを	繰り返した
# 新しそうに	繰り返した
# あとで	質問した
# 吾輩に	向って
# 下のごとく	質問した
# 御めえは	ある
# 今までに	とった
# 鼠を	とった
# 何匹	とった
# 事が	ある
# 智識は	発達しているつもりだが
# 黒よりも	発達しているつもりだが
# 発達しているつもりだが	ならないと
# 勇気とに	至っては
# 比較には	ならないと
# 覚悟は	していた
# 問に	接したる
# 事実は	行かないから
# 訳には	行かないから
# 吾輩は	答えた
# とろうとろうと	思って
# 黒は	笑った
# 先から	張っている
# ぴんと突	張っている
# 長い髭を	震わせて
# 非常に	笑った
# 黒は	あって
# 自慢を	する
# 丈に	足りない
# どこか	足りない
# ところが	あって
# 気焔を	感心したように
# 感心したように	謹聴していれば
# 咽喉を	鳴らして
# 謹聴していれば	御しやすい
# 吾輩は	定めた
# 近付に	なってから
# 呼吸を	飲み込んだから
# 場合にも	わるくするのも
# 己れを	弁護して
# 弁護して	わるくするのも
# 形勢を	わるくするのも
# 事彼に	しゃべらして
# 手柄話を	しゃべらして
# 御茶を	濁すに
# 思案を	定めた
# 君などは	とったろうと
# 年であるから	とったろうと
# 彼は	吶喊して来た
# 欠所に	吶喊して来た
# 三四十は	とったろうとは
# 彼は	合わねえ
# 語を	つづけて
# 二百は	引き受けるが
# 一人で	引き受けるが
# いつでも	引き受けるが
# いたちってえ	合わねえ
# 奴は	合わねえ
# 手に	合わねえ
# いたちに	向って
# 目に	逢った
# 相槌を	打つ
# 黒は	云う
# 眼を	ぱちつかせて
# 亭主が	持って
# 袋を	持って
# 下へ	這い込んだら
# 野郎が	喰って
# 面	喰って
# 感心して	見せる
# こん畜生って	追っかけて
# 気で	追っかけて
# 中へ	追い込んだと
# 御めえいざって	なると
# え段に	なると
# 奴め最後っ屁を	こきゃがった
# いたちを	見ると
# 彼は	なで廻わした
# ここに	至って
# 臭気を	感ずるごとく
# 今なお	感ずるごとく
# 前足を	揚げて
# 頭を	なで廻わした
# 二三遍	なで廻わした
# 吾輩も	する
# 感じが	する
# 景気を	付けて
# やろうと	思って
# 鼠なら	睨まれては
# 君に	睨まれては
# 君は	呈出した
# 鼠を	捕るのが
# 捕るのが	食う
# 名人で	食う
# 鼠ばかり	食う
# 御機嫌を	とる
# 質問は	呈出した
# 不思議にも	呈出した
# 結果を	呈出した
# 彼は	いう
# 喟然として	大息して
# 大息して	いう
# 考げ	えると
# 鼠を	とったって
# 一てえ	ふてえ
# 人間ほど	ふてえ
# 奴は	いねえぜ
# 世の中に	いねえぜ
# 人の	とった
# 鼠を	取り上げやがって
# みんな	取り上げやがって
# 交番へ	持って行きゃ
# 交番じゃ	捕ったか
# 誰が	捕ったか
# たんびに	くれるじゃねえか
# 五銭ずつ	くれるじゃねえか
# 亭主なんか	儲けて
# 御蔭で	儲けて
# 壱円五十銭くらい	儲けて
# 癖に	食わせた
# 碌なものを	食わせた
# 事も	ありゃしねえ
# 泥棒だぜさすが	わかると
# 黒も	わかると
# 理窟は	わかると
# 容子で	逆立てている
# 毛を	逆立てている
# 吾輩は	帰った
# 加減に	胡魔化して
# 場を	胡魔化して
# 胡魔化して	帰った
# 家へ	帰った
# 時から	決心した
# 吾輩は	とるまいと
# 鼠を	とるまいと
# 子分に	なって
# 御馳走を	あるく
# 猟って	あるく
# 事も	しなかった
# 御馳走を	食うよりも
# 家に	いると
# 性質に	なると
# 要心しないと	なるかも知れない
# 胃弱に	なるかも知れない
# 教師と	いえば
# 主人も	至っては
# 近頃に	至っては
# 水彩画において	悟った
# 事を	悟った
# ものと	見えて
# 日記に	かきつけた
# 事を	かきつけた
# 人に	始めて
# 会で	始めて
# 人は	している
# 大分放蕩を	した
# 人だと	云うが
# 風采を	している
# 女に	好かれる
# ものだからが	したと
# 放蕩を	したと
# 放蕩を	するべく
# 元来放蕩家を	いう
# 放蕩を	する
# 放蕩家をもって	自任する
# これらは	余儀なくされないのに
# 無理に	進んでやるのである
# 水彩画に	於ける
# きもので	卒業する
# 通人だと	思って
# 酒を	飲んだり
# 待合へ	這入るから
# 通人と	なり得るという
# 論が	立つなら
# 吾輩も	なり得る
# 水彩画家に	なり得る
# 通人論は	首肯しかねる
# 妻君を	羨しいなどという
# 口に	すべからざる
# 主人は	抜けない
# かくのごとく	にも関せず
# 自知の	にも関せず
# にも関せず	抜けない
# 自惚心は	抜けない
# 中二日	置いて
# 日記に	書いている
# 事を	書いている
# 昨夜は	ならんと
# 僕が	かいて
# 水彩画を	かいて
# 物に	ならんと
# そこらに	抛って
# 置いたのを	して
# 誰かが	して
# 額に	して
# 欄間に	懸けてくれた
# 夢を	見た
# 額に	なった
# ところを	見ると
# 我ながら	上手になった
# 急に	上手になった
# これなら	眺め暮らしていると
# ものだと	眺め暮らしていると
# 独りで	眺め暮らしていると
# 眺め暮らしていると	明瞭になってしまった
# 夜が	覚めて
# 眼が	覚めて
# 事が	明瞭になってしまった
# 朝日と共に	明瞭になってしまった
# 主人は	背負ってあるいていると
# 裡まで	背負ってあるいていると
# 未練を	背負ってあるいていると
# 所謂通人にも	なれない
# 主人が	見た
# 水彩画を	見た
# 美学者が	訪問した
# 久し振りで	訪問した
# 主人を	訪問した
# 彼は	切った
# 座に	つくと
# 劈頭第一に	切った
# 口を	切った
# 主人は	分るようだ
# 顔を	して
# 忠告に従って	力めているが
# 写生を	力めているが
# 写生を	すると
# 今まで	つかなかった
# 気の	つかなかった
# 変化などが	分るようだ
# 西洋では	しから
# 昔	しから
# 写生を	主張した
# 今日のように	発達した
# ものと	思われる
# アンドレア・デル・サルトだと	出さないでまた
# 事は	出さないでまた
# おくびにも	出さないでまた
# アンドレア・デル・サルトに	感心する
# 美学者は	掻く
# 出鱈目だよと	掻く
# 頭を	掻く
# 何がと	つかない
# 主人は	つかない
# た事に	つかない
# 気が	つかない
# 君の	感服している
# 僕の	捏造した
# 君が	信じようとは
# 真面目に	信じようとは
# 吾輩は	想像せざるを得なかった
# 椽側で	聞いて
# 対話を	聞いて
# 日記には	記さるるであろうかと
# 事が	記さるるであろうかと
# 事を	吹き散らして
# 人を	担ぐのを
# 担ぐのを	楽にしている
# 唯一の	楽にしている
# 彼は	饒舌った
# アンドレア・デル・サルト事件が	伝えたかを
# 情線に	伝えたかを
# 響を	伝えたかを
# 顧慮せざるもののごとく	なって
# 得意に	なって
# 事を	饒舌った
# 冗談を	言うと
# 人が	受けるので
# 大に	挑撥するのは
# 滑稽的美感を	挑撥するのは
# せんだって	ある
# 学生に	忠告して
# ニコラス・ニックルベーが	忠告して
# ギボンに	忠告して
# 忠告して	大著述なる
# 一世の	大著述なる
# 仏国革命史を	書くのを
# 仏語で	書くのを
# 書くのを	やめにして
# 英文で	出版させたと
# 出版させたと	言ったら
# 男で	繰り返したのは
# 演説会で	話した
# 真面目に	話した
# 僕の	話した
# 通りを	繰り返したのは
# 約百名ばかりであったが	おった
# 皆	傾聴して
# 熱心に	傾聴して
# それを	傾聴して
# 傾聴して	おった
# 話が	ある
# せんだって	出たから
# 文学者の	いる
# 席で	出たから
# 歴史小説セオファーノの	話しが
# 女主人公が	死ぬ
# ところは	襲うようだと
# 鬼気人を	襲うようだと
# 襲うようだと	評したら
# 向うに	坐っている
# 先生が	いった
# 名文だと	いった
# 僕は	知った
# 男も	読んでおらないという
# 僕同様	読んでおらないという
# 小説を	読んでおらないという
# 事を	知った
# 主人は	問いかけた
# 眼を	丸くして
# 出鱈目を	いって
# 相手が	読んでいたら
# するつもりだ	欺くのは
# 人を	欺くのは
# 化の皮が	あらわれた
# 時は	困るじゃないかと
# 美学者は	動じない
# なに	云うばかりさと
# 時	云うばかりさと
# 本と	間違えたとか
# 美学者は	掛けているが
# 眼鏡は	掛けているが
# 性質が	似た
# 黒に	似た
# ところが	ある
# 主人は	している
# 日の出を	吹いて
# 輪に	吹いて
# 顔を	している
# 美学者は	あるそうだ
# 画を	かいても
# 目付で	あるそうだ
# 冗談だが	あるそうだ
# ものだよ	あるそうだ
# レオナルド・ダ・ヴィンチは	あるそうだ
# 門下生に	写せと
# しみを	写せと
# 事が	あるそうだ
# なるほど雪隠などに	這入って
# 雨の	漏る
# 壁を	眺めていると
# 模様画が	出来ているぜ
# 自然に	出来ているぜ
# 君	注意して
# 注意して	写生して
# 写生して	出来るから
# 見給え	出来るから
# ものが	出来るから
# 語じゃないか	いいそうな
# ダ・ヴィンチでも	いいそうな
# 相違ないなと	した
# 主人は	した
# 半分降参を	した
# 彼は	せぬようだ
# 雪隠で	せぬようだ
# 写生は	せぬようだ
# 黒は	なった
# その後	なった
# 跛に	なった
# 光沢	ある
# 毛は	抜けて来る
# 色が	褪めて
# 眼には	一杯たまっている
# 眼脂が	一杯たまっている
# 注意を	惹いたのは
# 消沈と	悪くなった
# 体格の	悪くなった
# 吾輩が	逢った
# 茶園で	逢った
# 彼に	逢った
# 日	いった
# 懲だと	いった
# 間に	綴った
# 紅を	綴った
# 紅葉は	尽した
# 夢のごとく	散って
# 近く	こぼした
# 花弁を	こぼした
# 山茶花も	尽した
# 落ち	尽した
# 椽側に	傾いて
# 日脚が	傾いて
# 木枯の	吹かない
# 日は	する
# 稀になってから	狭められたような
# 時間も	狭められたような
# 気が	する
# 主人は	行く
# 毎日学校へ	行く
# 書斎へ	立て籠る
# 人が	来ると
# 厭だと	いう
# 水彩画も	かかない
# 滅多に	かかない
# タカジヤスターゼも	やめてしまった
# 小供は	かよう
# 感心に	休まないで
# 幼稚園へ	かよう
# 唱歌を	歌って
# 毬を	ついて
# 吾輩を	ぶら下げる
# 尻尾で	ぶら下げる
# 吾輩は	食わないから
# 御馳走も	食わないから
# 健康で	ならずに
# 跛にも	ならずに
# 日	暮している
# その日を	暮している
# 鼠は	取らない
# 名前は	つけてくれないが
# 生涯	終るつもりだ
# 猫で	終るつもりだ
# 吾輩は	有名になったので
# 新年来	有名になったので
# 猫ながら	感ぜらるるのは
# 鼻が	感ぜらるるのは
# 元朝	来た
# 許へ	来た
# 絵端書が	来た
# 年始状であるが	書いてある
# 上部を	塗って
# 下部を	塗って
# 深緑りで	塗って
# 真中に	踞っている
# 動物が	踞っている
# 蹲	踞っている
# ところを	書いてある
# パステルで	書いてある
# 主人は	いう
# 書斎で	眺めたりして
# 絵を	眺めたりして
# 横から	見たり
# 竪から	眺めたりして
# うまい色だなと	いう
# ものだから	見たりしている
# やめに	するかと
# 横から	見たり
# 竪から	見たりしている
# からだを	拗じ向けたり
# 手を	延ばして
# 年寄が	見るようにしたり
# 三世相を	見るようにしたり
# 見るようにしたり	見ている
# 方へ	むいて
# 先まで	持って来たりして
# 膝が	揺れて
# 事で	劇しくなくなったと
# 動揺が	劇しくなくなったと
# 劇しくなくなったと	思ったら
# 声で	かいたのだろうと
# 何を	かいたのだろうと
# かいたのだろうと	云う
# 主人は	感服したが
# 色には	感服したが
# 感服したが	見える
# 正体が	分らぬので
# さっきから	した
# 苦心を	した
# ものと	見える
# 絵端書かと	思いながら
# 眼を	開いて
# 上品に	開いて
# 半ば	開いて
# 落ちつき	払って
# 主人のように	極め込んだ
# アンドレア・デル・サルトを	極め込んだ
# ものでもあるまいが	出来ている
# 画家だけに	整って
# 色彩も	整って
# 誰が	見たって
# 眼識の	ある
# ものなら	描いてある
# 事が	わかるように
# 判然と	わかるように
# わかるように	描いてある
# 立派に	描いてある
# 事を	分らずに
# かくまで	苦心するかと
# 苦心するかと	思うと
# 人間が	気の毒になる
# 出来る事なら	知らしてやりたい
# 絵が	云う
# 吾輩であると	云う
# 事を	知らしてやりたい
# 吾輩であると	云う
# 事は	分らないにしても
# 事だけは	分らしてやりたい
# 言語を	解し得る
# 恵に	浴して
# おらん動物であるから	しておいた
# 残念ながら	しておいた
# 読者に	断っておきたいが
# 事もなげに	もって
# 口調を	もって
# 吾輩を	評価する
# 癖が	あるは
# 糟から	出来て
# 馬が	出来て
# 糞から	製造されたごとく
# 猫が	製造されたごとく
# 製造されたごとく	考えるのは
# 無智に	心付かんで
# 顔を	する
# はたから	見て
# 猫だって	出来ぬ
# 粗末簡便には	出来ぬ
# 特色などはないようであるが	出来るのである
# 社会に	這入って
# もので	出来るのである
# 語は	出来るのである
# ここにも	出来るのである
# 応用が	出来るのである
# 足並でも	違う
# みんな	違う
# 張り具合から	至るまで
# 垂れ加減に	至るまで
# 数を	悉くして
# 千差万別と	云っても
# そのように	存しているにもかかわらず
# 区別が	存しているにもかかわらず
# 向上とか	いって
# 空ばかり	見ている
# 性質は	出来ぬのは
# 末を	識別する
# 事すら	出来ぬのは
# 同類相求むとは	分らぬ
# 昔	しから
# そうだが	分らぬ
# その通り	分らぬ
# 猫で	分らぬ
# 事なら	分らぬ
# 猫でなくては	分らぬ
# 人間が	発達したって
# 彼等が	信じているごとく
# 自ら	信じているごとく
# 主人のごときは	解すると
# 相互を	解すると
# ことすら	分らない
# 牡蠣のごとく	吸い付いて
# 書斎に	吸い付いて
# 外界に	向って
# 口を	開いた
# 自分だけは	達観したような
# 面構を	しているのは
# 証拠には	あるのに
# 肖像が	あるのに
# 前に	あるのに
# 今年は	すましているのでも
# 第二年目だから	すましているのでも
# 画だろうなどと	知れぬ
# 気の	知れぬ
# ことを	いって
# すましているのでも	わかる
# 吾輩が	考えていると
# 上で	ねむりながら
# 眼を	ねむりながら
# 下女が	持って来た
# 絵端書を	持って来た
# 活版で	行列して
# 猫が	行列して
# 四五疋ずらりと	行列して
# 行列して	している
# ペンを	握ったり
# 書物を	開いたり
# 勉強を	している
# 一疋は	躍っている
# 席を	離れて
# 角で	躍っている
# 猫じゃ	躍っている
# 猫じゃを	躍っている
# その上に	かいて
# 墨で	かいて
# 吾輩は猫であると	かいて
# 側に	読むや
# 書を	読むや
# 俳句さえ	認められてある
# これは	来たので
# 旧門下生より	来たので
# 誰が	見たって
# 一見して	わかるはずであるのに
# 意味が	わかるはずであるのに
# わかるはずであるのに	悟らないと
# 主人は	悟らないと
# 不思議そうに	捻って
# 首を	捻って
# 今年は	言った
# 年かなと	言った
# 独言を	言った
# 吾輩が	有名になったのを
# これほど	有名になったのを
# 有名になったのを	着かずに
# 気が	着かずに
# ところへ	持ってくる
# 下女が	持ってくる
# 端書を	持ってくる
# 恭賀新年と	かいて
# 傍らに	ある
# 猫へも	ある
# 御伝声	奉
# 願上候と	ある
# 主人でも	あれば
# こう明らさまに	書いて
# ものと	見えて
# 気が	付いたように
# 付いたように	見た
# フンと	言いながら
# 顔を	見た
# 眼付が	思われた
# 今までとは	違って
# 意を	含んでいるように
# 含んでいるように	思われた
# 今まで	認められなかった
# 世間から	認められなかった
# 存在を	認められなかった
# 主人が	こしたのも
# 急に	こしたのも
# 新面目を	こしたのも
# 施	こしたのも
# こしたのも	考える
# 御蔭だと	思えば
# 至当だろうと	考える
# おりから	鳴る
# 格子が	鳴る
# チリリリリンと	鳴る
# 来客なら	出る
# 下女が	出る
# 取次に	出る
# 吾輩は	極めているのだから
# 梅公が	くる
# ほかは	極めているのだから
# 事に	極めているのだから
# 極めているのだから	おった
# 平気で	おった
# もとのごとく	おった
# 膝に	坐って
# 主人は	見る
# 高利貸にでも	飛び込まれたように
# 飛び込まれたように	して
# 顔付を	して
# 方を	見る
# 何でも	するのが
# 客を	するのが
# 相手を	するのが
# 人間も	偏屈になれば
# そんなら	すればよいのに
# 外出でも	すればよいのに
# 根性を	あらわしている
# 下女が	来て
# 寒月さんが	なりましたと
# おいでに	なりましたと
# 旧門下生であったそうだが	話しである
# 今では	卒業して
# 学校を	卒業して
# 卒業して	立派になっているという
# 何でも	立派になっているという
# 主人より	立派になっているという
# 立派になっているという	話しである
# 訳か	来る
# 所へ	来る
# 遊びに	来る
# 自分を	いる
# 恋って	いる
# 女が	有りそうな
# 面白そうな	並べては
# 文句ばかり	並べては
# 人間を	求めて
# 来るのから	して
# 合点が	行かぬが
# 牡蠣的主人が	聞いて
# 談話を	聞いて
# 相槌を	打つのは
# 御無沙汰を	しました
# 暮から	活動している
# 大に	活動している
# ものですから	向かないのでと
# 方角へ	向かないのでと
# 足が	向かないのでと
# 紐を	ひねくりながら
# 謎	見たような
# 事を	いう
# 方角へ	向く
# 足が	向く
# かねと	引張る
# 主人は	引張る
# 顔を	して
# 袖口を	引張る
# 羽織は	はみ出している
# 下から	はみ出している
# べら者が	はみ出している
# 左右へ	はみ出している
# 五分くらいずつ	はみ出している
# エヘヘヘ少し	違った
# 方角でと	笑う
# 寒月君が	笑う
# 今日は	欠けている
# 前歯が	欠けている
# 一枚	欠けている
# 君歯を	どうかしたかねと
# 主人は	転じた
# 問題を	転じた
# 所で	食いましてね
# 椎茸を	食いましてね
# 何を	食ったって
# 椎茸を	食ったんで
# 傘を	噛み切ろうとしたら
# 前歯で	噛み切ろうとしたら
# ぼろりと	欠けましたよ
# 歯が	欠けましたよ
# 椎茸で	かける
# 前歯が	かける
# 俳句には	なるかも知れないが
# 恋には	ならんようだなと
# ならんようだなと	叩く
# 平手で	叩く
# 頭を	叩く
# 例のですか	肥ってるじゃありませんかそれなら
# 黒にだって	負けそうも
# 負けそうも	ありませんね
# 近頃大分	大きくなったのさと
# 大きくなったのさと	なぐる
# 自慢そうに	なぐる
# 頭を	なぐる
# 一昨夜も	やりましてねと
# 合奏会を	やりましてねと
# 寒月君は	戻す
# もとへ	戻す
# どこで	ならんでもよいでしょう
# どこでも	ならんでもよいでしょう
# そりゃ御聞きに	ならんでもよいでしょう
# ヴァイオリンも	なると
# 三挺くらいに	なると
# 下手でも	聞かれる
# 二人は	まじりましたが
# 女で	まじりましたが
# 私が	まじりましたが
# 中へ	まじりましたが
# 自分でも	弾けたと
# 何者かねと	問いかける
# 主人は	問いかける
# 羨ましそうに	問いかける
# 主人は	惚れる
# 顔付は	している
# 実のところは	惚れる
# 方ではない	惚れる
# 小説を	読んだら
# 中に	ある
# 一人物が	出て来て
# それが	惚れる
# 婦人には	惚れる
# 勘定を	して
# 往来を	通る
# 七割弱には	恋着するという
# 事が	書いてあったのを
# 諷刺的に	書いてあったのを
# 書いてあったのを	見て
# 真理だと	感心した
# 男が	送っているかと
# 牡蠣的生涯を	送っているかと
# 云うのは	分らない
# 吾輩猫などには	分らない
# 人は	云うし
# ためだとも	云うし
# 或人は	云うしまた
# せいだとも	云うしまた
# 或人は	云う
# 性質だからだとも	云う
# どっちに	したって
# 歴史に	関係する
# 人物でもないのだから	構わない
# 女連れを	尋ねた
# 気に	尋ねた
# 寒月君は	食い切った
# 面白そうに	挟んで
# 蒲鉾を	挟んで
# 箸で	挟んで
# 半分前歯で	食い切った
# 吾輩はまた	せぬかと
# 欠けは	せぬかと
# なに二人とも	去る
# ありませんと	する
# 余所余所しい返事を	する
# ナールと	引張ったが
# 主人は	引張ったが
# 寒月君は	見る
# 時分だと	思った
# ものか	見る
# 天気ですな	落ちたので
# 御閑なら	もしましょうか
# ごいっしょに	もしましょうか
# 散歩で	もしましょうか
# 旅順が	落ちたので
# 景気ですよと	して
# 促が	して
# 主人は	立つ
# 陥落より	聞きたいと
# 身元を	聞きたいと
# 顔で	考え込んでいたが
# ようやく決心を	した
# ものと	見えて
# それじゃ	出ると
# しようと	思い切って
# 紋付羽織に	着た
# 紀念とかいう	来着古る
# 二十年	来着古る
# 綿入を	着た
# 所々が	薄くなって
# 日に	透かして
# 裏から	当てた
# つぎを	当てた
# 目が	見える
# ときは	出る
# 懐手を	して
# ほかに	着る
# 面倒だから	着換えないのか
# 着換えないのか	分らぬ
# 吾輩には	分らぬ
# これだけは	思われない
# ためとも	思われない
# 両人が	出て
# あとで	頂戴した
# 吾輩は	頂戴した
# 失敬して	頂戴した
# 寒月君の	食い切った
# 残りを	頂戴した
# 猫か	あると
# 資格は	あると
# 一切くらい	頂戴したって
# 頂戴したって	云われる
# 人から	云われる
# 人目を	忍んで
# 間食を	するという
# 何も	限った
# 吾等猫族に	限った
# 御三などは	失敬している
# 留守中に	失敬しては
# 餅菓子などを	失敬しては
# 失敬しては	頂戴し
# 頂戴し	失敬している
# 頂戴しては	失敬している
# 仕付を	受けつつあると
# 細君から	吹聴せられている
# 小児ですら	ある
# 傾向が	ある
# ことであったが	着いた
# 小供が	覚まして
# 馬鹿に	覚まして
# 眼を	覚まして
# 主人夫婦の	寝ている
# 間に	対い合うて
# 対い合うて	着いた
# 食卓に	着いた
# 毎朝主人の	食う
# 幾分に	食うのが
# 砂糖を	つけて
# 例であるが	添えてあった
# 日は	添えてあった
# 砂糖壺が	置かれて
# 上に	置かれて
# 匙さえ	添えてあった
# いつものように砂糖を	分配してくれる
# 方が	すくい出して
# 中から	すくい出して
# 砂糖を	すくい出して
# 上へ	あけた
# 小さいのが	あけた
# した通り	あけた
# 砂糖を	あけた
# 同方法で	あけた
# 上に	あけた
# 少らく両人は	睨み合っていたが
# 大きいのが	加えた
# 匙を	とって
# 一杯を	加えた
# 上に	加えた
# 小さいのも	した
# 匙を	とって
# 分量を	した
# 同一に	した
# 妹も	負けずに
# 一杯を	附加した
# 姉が	とる
# 壺へ	懸ける
# 手を	懸ける
# 妹が	とる
# 匙を	とる
# 間に	重なって
# 一杯一杯一杯と	重なって
# 皿には	堆くなって
# 砂糖が	堆くなって
# 中には	入れてしまった
# 砂糖も	余って
# とき	入れてしまった
# 主人が	寝ぼけ
# 眼を	擦りながら
# 寝室を	出て来て
# 砂糖を	入れてしまった
# 中へ	入れてしまった
# ところを	見ると
# 利己主義から	割り出した
# 念は	優っているかも知れぬが
# 猫より	優っているかも知れぬが
# 智慧は	劣っているようだ
# 猫より	劣っているようだ
# 山盛に	しない
# うちに	しまえばいいにと
# 甞めて	しまえばいいにと
# 例のごとく	通じないのだから
# 吾輩の	言う
# 事などは	通じないのだから
# 通じないのだから	見物していた
# 気の毒ながら	黙って
# 上から	黙って
# 寒月君と	出掛けた
# どこを	歩行いた
# 晩	帰って来て
# 翌日	就いたのは
# 食卓に	就いたのは
# 上から	拝見していると
# 拝見していると	食っている
# 主人は	食っている
# 雑煮を	食っている
# 何でも	七切食って
# 六切か	七切食って
# 七切食って	残して
# 一切れを	残して
# 中へ	残して
# 箸を	置いた
# 他人が	すると
# 我儘を	すると
# 承知しないのであるが	平気ですましている
# 威光を	振り
# 廻わして	平気ですましている
# 彼は	平気ですましている
# 中に	焦げ爛れた
# 死骸を	見て
# 妻君が	出して
# 奥から	出して
# タカジヤスターゼを	出して
# 上に	置くと
# 主人は	飲まんと
# それは	利かないから
# ものには	あるそうですから
# 大変	あるそうですから
# 功能が	あるそうですから
# あるそうですから	召し上ったらいいでしょうと
# 駄目だよと	出る
# 頑固に	出る
# あなたは	厭きっぽいと
# 独言のように	いう
# 薬が	利かんのだ
# 利かんのだ	上ったじゃありませんか
# それだって	上ったじゃありませんか
# せんだってじゅうは	利くと
# 大変に	利く
# 毎日	上ったじゃありませんか
# こないだうちは	利いたのだよ
# 利いたのだよ	利かないのだよと
# 頃は	利かないのだよと
# 利かないのだよと	する
# 返事を	する
# 功能の	ある
# 薬でも	利く
# 気遣いは	直らないわねえと
# 胃弱なんぞは	直らないわねえと
# 病気た	直らないわねえと
# お盆を	持って
# 御三を	顧みる
# ご覧に	ならないと
# 薬か	わかりますまいと
# 御三は	持つ
# 肩を	持つ
# 何でも	いい
# 飲まんのだから	飲まんのだ
# 女なんかに	わかる
# 何が	わかる
# ものか	黙っていろ
# 女ですわと	突き付けて
# 細君が	突き付けて
# タカジヤスターゼを	突き付けて
# 前へ	突き付けて
# 詰腹を	切らせようとする
# 主人は	這入る
# 何にも	云わず
# 書斎へ	這入る
# 御三は	笑う
# 顔を	見合せて
# ときに	付いて行って
# 上へ	乗ると
# 目に	逢わされるから
# 庭から	廻って
# 椽側へ	上って
# 隙から	覗いて
# 主人は	おった
# エピクテタスとか	云う
# 本を	披いて
# 披いて	おった
# それが	わかるなら
# 通り	わかるなら
# ところが	ある
# 五六分	すると
# 本を	叩き付けるように
# 叩き付けるように	抛り出す
# 上へ	抛り出す
# 事だろうと	思いながら
# 注意していると	書きつけた
# 今度は	書きつけた
# 事を	書きつけた
# 前で	きて
# 芸者が	きて
# 春着を	きて
# 羽根を	ついていた
# うちの猫に	似ていた
# 何も	出さなくっても
# 顔の	出さなくっても
# い例に	出さなくっても
# 吾輩を	出さなくっても
# 吾輩だって	ありゃしない
# 喜多床へ	行って
# 顔さえ	剃って
# 貰やあ	ありゃしない
# 人間と	異った
# ところは	ありゃしない
# 人間は	自惚れているから
# 角を	曲るとまた
# 一人芸者が	来た
# これは	見えた
# 恰好よく	出来上った
# 女で	見えた
# 衣服も	着こなされて
# 素直に	着こなされて
# 上品に	見えた
# 歯を	出して
# 忙が	しかった
# もんだからと	云った
# 声は	おったので
# 旅鴉のごとく	皺枯れて
# 皺枯れて	おったので
# 風采も	下落したように
# 大に	下落したように
# 下落したように	感ぜられたから
# 源ちゃんなるものの	人なるかを
# 人なるかを	振り向いて
# 面倒になって	出た
# まま	出た
# 御成道へ	出た
# 寒月は	見えた
# 心理ほど	解し難い
# 心は	怒っているのだか
# 怒っているのだか	浮かれているのだかまたは
# 遺書に	求めつつあるのか
# 慰安を	求めつつあるのか
# 求めつつあるのか	分らない
# 世の中を	冷笑しているのか
# 交りたいのだか	起しているのか
# 事に	起しているのか
# 肝癪を	起しているのか
# 起しているのか	しているのだか
# 物外に	しているのだか
# 超然と	しているのだか
# しているのだか	付かぬ
# 見当が	付かぬ
# 猫などは	行くと
# そこへ	行くと
# ときは	怒り
# 一生懸命に	怒り
# ときは	泣く
# 絶体絶命に	泣く
# ものは	決してつけない
# 主人のように	ある
# 裏表の	ある
# 人間は	あるかも知れないが
# 日記でも	書いて
# 世間に	出されない
# 面目を	発揮する
# 暗室内に	発揮する
# 必要が	あるかも知れないが
# 我等猫属に	至ると
# 日記であるから	及ばぬと
# 手数を	して
# 真面目を	保存するには
# 保存するには	及ばぬと
# 日記を	つける
# ひまが	あるなら
# 椽側に	寝ているまでの
# 某亭で	食う
# 晩餐を	食う
# 久し振りで	飲んだら
# 正宗を	飲んだら
# 二三杯	飲んだら
# 一番だと	思う
# タカジヤスターゼは	いかん
# 誰が	云っても
# 何と	云っても
# ものは	利かないのだ
# タカジヤスターゼを	攻撃する
# 独りで	しているようだ
# 喧嘩を	しているようだ
# 肝癪が	出す
# ここへ	出す
# 尾を	出す
# 本色は	存するのかも知れない
# 云う辺に	存するのかも知れない
# せんだっては	廃すると
# 朝飯を	廃すると
# 胃が	なると
# 二三日	やめて
# 朝飯を	やめて
# 腹が	鳴るばかりで
# 是非香の物を	断てと
# 説に	よると
# すべて	ある
# 源因は	ある
# 漬物に	ある
# 漬物さえ	断てば
# 源を	涸らす訳だから
# 涸らす訳だから	疑なしという
# 本復は	疑なしという
# 一週間ばかり	触れなかったが
# 香の物に	触れなかったが
# 箸を	触れなかったが
# 験も	見えなかったから
# 近頃は	食い出した
# それは	限る
# 按腹揉療治に	限る
# 普通の	ではゆかぬ
# 皆川流という	揉み方で
# 古流な	揉み方で
# 揉み方で	やらせれば
# 一二度	やらせれば
# 胃病は	根治出来る
# 安井息軒も	愛していた
# 大変	愛していた
# 按摩術を	愛していた
# 豪傑でも	うけたと
# 治療を	うけたと
# 上根岸まで	出掛けて
# 骨を	揉まなければ
# 癒らぬとか	顛倒しなければ
# 位置を	顛倒しなければ
# 顛倒しなければ	やる
# 根治が	しにくいとか
# いって	やる
# それは	やる
# それは	やる
# 残酷な	揉み方を
# 揉み方を	やる
# 身体が	したので
# 綿のようになって	したので
# 昏睡病に	かかったような
# 心持ちが	したので
# 一度で	閉口して
# 閉口して	した
# やめに	した
# 君は	食うなと
# 是非固形体を	食うなと
# 一日牛乳ばかり	飲んで
# 時は	眠れなかった
# 中で	して
# 音が	して
# 大水でも	出たように
# 出たように	思われて
# 終夜	眠れなかった
# 横膈膜で	呼吸して
# 呼吸して	運動させれば
# 内臓を	運動させれば
# 運動させれば	健全になる
# 働きが	健全になる
# 試しに	やって
# 御覧と	いう
# これも	やったが
# 不安で	困る
# 思い出したように	する
# 一心不乱に	かかりは
# 五六分	立つと
# 横膈膜が	なって
# 気に	なって
# 本を	読む
# 事も	かく
# 文章を	かく
# 事も	出来ぬ
# 迷亭が	見て
# 体を	見て
# 産気の	ついた
# 男じゃあるまいし	止すがいいと
# 頃は	廃してしまった
# 先生は	云うから
# 蕎麦を	食ったら
# 腹が	下るばかりで
# 胃弱を	直す
# ために	出来得る
# 方法を	講じて
# 昨夜	傾けた
# 寒月と	傾けた
# 正宗は	ある
# 利目が	ある
# 二三杯ずつ	飲む
# 事に	しよう
# これも	続く
# 心は	変化している
# 何を	やっても
# その上	するから
# 上で	心配している
# 胃病を	心配している
# 癖に	するから
# 表向は	するから
# 大に	するから
# 痩我慢を	するから
# せんだって	尋ねて来て
# 友人で	尋ねて来て
# 学者が	尋ねて来て
# 見地から	ほかならないと
# 病気は	ほかならないと
# 結果に	ほかならないと
# 議論を	した
# ものと	見えて
# これを	反駁する
# 自分が	苦しんでいる
# 胃病で	苦しんでいる
# 際だから	した
# かんとか	して
# 弁解を	して
# 面目を	保とうと
# 者と	見えて
# 胃弱だから	云ったような
# 名誉であると	云ったような
# 挨拶を	した
# 友人は	極め付けたので
# 胃弱だって	なれないさと
# 病人が	なれないさと
# カーライルには	なれないさと
# 主人は	していた
# 黙然と	していた
# かくのごとく	富んでいるものの
# 虚栄心に	富んでいるものの
# 今夜から	始めるなどというのは
# 晩酌を	始めるなどというのは
# 今朝	食ったのも
# 雑煮を	食ったのも
# たくさん	食ったのも
# 食ったのも	影響かも知れない
# 昨夜	ひっくり返した
# 正宗を	ひっくり返した
# 吾輩も	見たくなった
# 雑煮が	食って
# 吾輩は	猫ではあるが
# 猫ではあるが	食う
# ものは	食う
# 黒のように	する
# 肴屋まで	する
# 遠征を	する
# 云	える
# 小供の	食いこぼした
# 麺麭も	食うし
# ため	やった
# 沢庵を	やった
# 二切ばかり	やった
# 事が	ある
# もので	食える
# ものは	食える
# 嫌だと	云うのは
# 我儘で	いる
# 家に	いる
# 口に	すべき
# 主人の	話しに
# 仏蘭西に	あった
# 小説家が	あった
# 贅沢屋ではない	尽したという
# 小説家だけに	尽したという
# 贅沢を	尽したという
# バルザックが	書いている
# 日	書いている
# 自分の	書いている
# 名を	つけようと
# ところへ	来たので
# 友人が	来たので
# 遊びに	来たので
# いっしょに	出掛けた
# 散歩に	出掛けた
# 友人は	連れ出されたのであるが
# 何も	知らずに
# 連れ出されたのであるが	歩行いている
# 自分の	苦心している
# 考えだから	歩行いている
# 往来へ	出ると
# 何も	見て
# しないで	見て
# 看板ばかり	見て
# 友人を	連れて
# 友人は	付いて行く
# 訳が	わからず
# 彼等は	探険した
# 朝から	探険した
# 晩まで	探険した
# 巴理を	探険した
# 帰りがけに	ついた
# バルザックは	ついた
# 看板が	ついた
# 目に	ついた
# 看板に	かいてある
# 名が	かいてある
# バルザックは	限る
# 手を	限る
# 拍って	限る
# これに	限る
# 頭文字を	つける
# 名が	出来る
# 自分で	作った
# 名は	つけたつもりでも
# ところが	あって
# 事で	気に入った
# 名が	出来たと
# 迷惑は	忘れて
# 一人	嬉しがったと
# 名前を	つけるに
# 一日巴理を	探険しなくてはならぬようでは
# 手数の	かかる
# 贅沢も	出来れば
# ものだが	出ない
# 吾輩のように	持つ
# 牡蠣的主人を	持つ
# 身の上では	出ない
# 気は	出ない
# 何でも	いい
# 気に	なるのも
# 境遇の	しからし
# 今雑煮が	食いたくなったのも
# 結果ではない	食っておこうという
# 何でも	食える
# 時に	食っておこうという
# 考から	ていはすまいかと
# 主人の	食い剰した
# 雑煮が	残っ
# 台所に	残っ
# ていはすまいかと	思い出したからである
# 台所へ	廻って
# 今朝	見た
# 餅が	膠着している
# 今朝	見た
# 色で	膠着している
# 底に	膠着している
# 今まで	入れた
# 一辺も	入れた
# 口に	入れた
# うまそうにも	あるしまた
# 気味が	わるくもある
# 前足で	かかっている
# 上に	かかっている
# 菜っ葉を	掻き寄せる
# 爪を	見ると
# 上皮が	引き掛って
# 飯を	移す
# 御櫃へ	移す
# 香が	する
# あたりを	見廻す
# 不幸か	いない
# 誰も	いない
# 御三は	ついている
# 春も	して
# 顔を	して
# 羽根を	ついている
# 小供は	歌っている
# 奥座敷で	歌っている
# 兎さんを	歌っている
# 機を	はずすと
# 味を	知らずに
# 吾輩は	感得した
# 刹那に	感得した
# 猫ながら	感得した
# 真理を	感得した
# 機会は	せしむ
# 動物を	して
# 事をも	せしむ
# 吾輩は	食いたくはないのである
# 実を	云うと
# 雑煮を	食いたくはないのである
# 様子を	熟視すれば
# 熟視すれば	する
# 食うのが	厭になったのである
# 時	開けたなら
# 御三でも	開けたなら
# 勝手口を	開けたなら
# 足音が	近付くのを
# こちらへ	近付くのを
# 近付くのを	聞き得たなら
# 吾輩は	浮ばなかったろう
# 椀を	見棄てたろうしかも
# 事は	浮ばなかったろう
# 来年まで	浮ばなかったろう
# 念頭に	浮ばなかったろう
# 誰も	来ない
# いくら躇していても	来ない
# 誰も	来ない
# 心持が	する
# 吾輩は	念じた
# 中を	覗き込みながら
# 誰か	来てくれればいいと
# 誰も	来てくれない
# 吾輩は	食わなければならぬ
# 雑煮を	食わなければならぬ
# 最後に	落すようにして
# 重量を	落すようにして
# 底へ	落すようにして
# 落すようにして	食い込んだ
# 角を	食い込んだ
# 一寸ばかり	食い込んだ
# 力を	込めて
# 食い付いたのだから	噛み切れる訳だが
# ものなら	噛み切れる訳だが
# 噛み切れる訳だが	引けない
# 歯を	引こうとすると
# 一辺	噛み直そうとすると
# 動きが	とれない
# 魔物だなと	疳づいた
# 沼へでも	落ちた
# 人が	抜こうと
# 足を	抜こうと
# たびに	沈むように
# 沈むように	重くなる
# 口が	重くなる
# 歯が	動かなくなる
# 歯答えは	あるが
# 歯答えが	あるだけで
# 始末を	つける
# 事が	出来ない
# 美学者迷亭先生が	評して
# 主人を	評して
# 君は	あるが
# 事が	あるが
# 事を	いった
# 餅も	割り切れない
# 同じように	割り切れない
# 三で	割るごとく
# 十を	割るごとく
# 尽未来際方の	つく
# 際	逢着した
# 吾輩は	逢着した
# 真理に	逢着した
# 動物は	予知す
# 直覚的に	予知す
# 適不適を	予知す
# 予知す	発明したが
# 真理は	発明したが
# 二つまで	発明したが
# 発明したが	感じない
# 餅	付いているので
# 愉快を	感じない
# 歯が	吸収されて
# 肉に	吸収されて
# 御三が	来る
# 唱歌も	やんだようだ
# 台所へ	馳け出して来るに
# 極尻尾を	ぐるぐる振って
# 耳を	立てたり
# 立て損の	寝かし損であると
# 寝かし損であると	気が付いたから
# 事これは	限ると
# 助けを	払い落すに
# 借りて餅を	払い落すに
# 方を	あげて
# 周囲を	撫で廻す
# 今度は	見る
# 左りの方を	伸して
# 中心として	劃して
# 急劇に	劃して
# 円を	劃して
# 呪いで	落ちない
# 魔は	落ちない
# 肝心だと	思って
# 交るに	動かしたが
# 歯は	下っている
# 中に	下っている
# ぶら	下っている
# 面倒だと	使う
# 両足を	使う
# 一度に	使う
# 事に	出来た
# 時だけは	出来た
# 二本で	立つ
# 事が	出来た
# 感じが	する
# 猫であろうが	引っ掻き廻す
# 日	構う
# ものか	引っ掻き廻す
# 何でも	落ちるまで
# 魔が	落ちるまで
# 意気込みで	引っ掻き廻す
# 無茶苦茶に	引っ掻き廻す
# 顔中	引っ掻き廻す
# 猛烈なので	倒れかかる
# 中心を	失って
# たびに	とらなくてはならぬから
# 後足で	とらなくてはならぬから
# 調子を	とらなくてはならぬから
# 一つ所に	いる
# 訳にも	行かんので
# 台所中あちら	廻る
# こちらと	飛んで
# 我ながら	起っていられた
# 器用に	起っていられた
# ものだと	思う
# 真理が	現前する
# 危きに	臨めば
# ものを	為し能う
# 天祐という幸に	戦っていると
# 天祐を	戦っていると
# 吾輩が	戦っていると
# 魔と	戦っていると
# 足音が	して
# 奥より	来るような
# 人が	来るような
# ここで	来られては
# 人に	来られては
# 大変だと	思って
# 躍起と	なって
# 台所を	かけ廻る
# 足音は	近付いてくる
# 残念だが	足りない
# 天祐が	足りない
# 小供に	見付けられた
# あら猫が	食べて
# 御雑煮を	食べて
# 踊を	踊っていると
# 声を	する
# この声を	聞きつけたのが
# 第一に	聞きつけたのが
# 羽子板も	打ち遣って
# 勝手から	飛込んで来る
# 細君は	仰せられる
# 紋付で	仰せられる
# 猫ねえと	仰せられる
# 主人さえ	出て来て
# 書斎から	出て来て
# 馬鹿野郎と	いった
# みんな	申し合せたように
# 申し合せたように	笑っている
# 腹は	立つ
# 踊は	弱った
# 訳に	ゆかぬ
# 笑いが	やみそうになったら
# やみそうになったら	なる
# 五つに	なる
# 女の子が	いったので
# 狂瀾を	するという
# 既倒に	するという
# 勢でまた	笑われた
# 大変	笑われた
# 実行も	大分見聞したが
# 時	感じた
# 天祐も	消え失せて
# どっかへ	消え失せて
# 通り四つ這に	なって
# 眼を	白黒するの
# 醜態を	演ずるまでに
# 見殺しに	するのも
# 気の毒と	見えて
# 餅を	とってやれと
# 主人が	命ずる
# 御三に	命ずる
# 御三は	見る
# 眼付で	見る
# 細君を	見る
# 細君は	見たいが
# 踊は	見たいが
# 取ってやらんと	死んでしまう
# 主人は	顧みる
# 下女を	顧みる
# 御三は	引く
# 御馳走を	食べかけて
# 半分	食べかけて
# 夢から	起された
# 時のように	引く
# 顔を	して
# 餅を	つかんで
# 寒月君じゃないが	思った
# 前歯が	折れるかと
# みんな	折れるかと
# 痛くないのって	引張るのだから
# 中へ	食い込んでいる
# 歯を	引張るのだから
# 吾輩が	経験して
# 安楽は	通過せざるべからずと
# 困苦を	通過せざるべからずと
# 通過せざるべからずと	云う
# 真理を	経験して
# 経験して	見廻した
# あたりを	見廻した
# 時には	おった
# 家人は	おった
# 奥座敷へ	這入ってしまって
# 失敗を	した
# 時には	見られるのも
# 内に	いて
# 御三なんぞに	見られるのも
# 顔を	見られるのも
# 事気を	出た
# 三毛子でも	出た
# 台所から	出た
# 裏へ	出た
# 吾輩は	心得ている
# 相違ないが	心得ている
# 情けは	心得ている
# 一通り	心得ている
# うちで	見たり
# 顔を	見たり
# 険突を	食って
# 気分が	勝れん
# 時は	する
# 許を	訪問して
# 訪問して	する
# 話を	する
# 心が	晴々して
# 晴々して	忘れて
# 苦労も	忘れて
# 心持に	なる
# 隙から	いるかなと
# 正月だから	坐っている
# 新しいのを	して
# 椽側に	坐っている
# 丸さ加減が	言うに
# 美を	尽している
# 尻尾の	曲がり加減
# 曲がり加減	折り具合
# 足の	折り具合
# 物憂げに	振る
# 耳を	振る
# 景色なども	出来ん
# 形容が	出来ん
# 日の	当る
# 暖かそうに	控えている
# ものだから	思われる
# 身体は	思われる
# 態度を	有する
# にも関らず	思われる
# 天鵞毛を	欺く
# 満身の毛は	思われる
# 春の	光りを
# 反射して	微動するごとくに
# 微動するごとくに	思われる
# 吾輩は	眺めていたが
# 恍惚として	眺めていたが
# 我に	帰ると同時に
# 低い声で	いいながら
# 三毛子さんと	いいながら
# 前足で	招いた
# 三毛子は	下りる
# あら先生と	下りる
# 椽を	下りる
# 首輪に	つけた
# 鈴が	鳴る
# ちゃらちゃらと	鳴る
# 正月に	なったら
# 鈴まで	つけたな
# 音だと	感心している
# 間に	振る
# 傍に	来て
# 尾を	振る
# 左りへ	振る
# 吾等猫属間で	する
# 御互に	する
# 挨拶を	する
# ときには	廻すのである
# それを	廻すのである
# 左りへ	廻すのである
# 町内で	呼んでくれるのは
# 吾輩を	呼んでくれるのは
# 先生と	呼んでくれるのは
# 前回	断わった
# 名はないのであるが	いってくれる
# 家に	いる
# ものだから	いってくれる
# 先生先生と	いってくれる
# 吾輩も	云われて
# 先生と	云われて
# 心持ちも	しないから
# はいはいと	している
# 返事を	している
# 立派に	出来ましたね
# 御化粧が	出来ましたね
# 暮御師匠さんに	買って頂いたの
# なるほど善い音ですな	生れてから
# 吾輩などは	生れてから
# いやだ	ぶら下げるのよと
# みんな	ぶら下げるのよと
# ちゃらちゃらちゃらちゃら続け様に	鳴らす
# 御師匠さんは	可愛がっていると
# 大変	可愛がっていると
# あなたを	可愛がっていると
# 吾身に	引きくらべて
# 意を	洩らす
# 三毛子は	笑う
# 小供のようよと	笑う
# 猫だって	笑わないとは
# 人間は	思っているのは
# 自分より	笑える
# ほかに	笑える
# 無いように	思っているのは
# 吾輩が	笑うのは
# 笑うのは	笑うのだから
# 孔を	して
# 三角に	して
# 咽喉仏を	震動させて
# 震動させて	笑うのだから
# 笑うのだから	わからぬはずである
# 人間には	わからぬはずである
# 御師匠さんよ	知っていますがね
# それは	知っていますがね
# 吾輩も	知っていますがね
# 君を	待つ
# 内で	弾き出す
# 御師匠さんが	弾き出す
# 二絃琴を	弾き出す
# 宜い声でしょうと	自慢する
# 三毛子は	自慢する
# ものですか	あれ
# 六十二で	生きている
# 丈夫と	云わねば
# 吾輩は	した
# 返事を	した
# 間が	抜けたようだが
# 抜けたようだが	出て来なかったから
# 名答も	出て来なかったから
# いつでも	おっしゃるの
# 何でも	行った
# 御嫁に	行った
# 娘なんだって	すって
# 御嫁に	いった
# 御嫁に	行った
# 御嫁に	行ったですよ
# そうそう	間違った
# 御嫁に	入った
# 混雑して	得ないですよ
# 要領を	得ないですよ
# ところ	なるんですか
# 何に	なるんですか
# なるんですか	分らないのね
# あなたも	分らないのね
# 御嫁に	行った
# 娘なんだって	言ってるんじゃありませんか
# 言ってるんじゃありませんか	分っているんですがね
# それは	分っているんですがね
# 分っているんですがね	した
# それが	すればいいんでしょう
# 分りさえ	すればいいんでしょう
# 仕方がないから	した
# 降参を	した
# 吾は	ある
# 時と	すると
# 虚言を	吐かねばならぬ
# 事が	ある
# 中で	やむと
# 音が	やむと
# 声で	呼ぶ
# 御飯だよと	呼ぶ
# あら御師匠さんが	呼んでいらっしゃるから
# じゃまた遊びに	いらっしゃいと
# 鈴を	鳴らして
# 庭先まで	かけて
# 急に	戻って来て
# 心配そうに	問いかける
# 雑煮を	食って
# 踊りを	踊ったとも
# 事も	ありませんが
# 考え事を	したら
# 頭痛が	してね
# あなたと	話しでも
# 御大事に	なさいまし
# 気に	見えた
# これで	回復した
# 元気も	回復した
# 心持に	なった
# 帰りに	通り抜けようと
# 茶園を	通り抜けようと
# 霜柱の	融けかかったのを
# 融けかかったのを	踏みつけながら
# 崩れから	出すとまた
# 顔を	出すとまた
# 黒が	して
# 上に	して
# 背を	して
# 山に	して
# 欠伸を	している
# 黒を	見て
# 吾輩ではないが	行き過ぎようとした
# 面倒だから	行き過ぎようとした
# 知らぬ顔を	して
# 性質として	軽侮したと
# 他が	軽侮したと
# 己れを	軽侮したと
# 軽侮したと	黙っていない
# 認むるや否や	黙っていない
# 権兵衛	留ってるじゃあねえか
# 飯を	食ったって
# 面ら	あするねえ
# 面白くもねえ黒は	有名になったのを
# 吾輩の	有名になったのを
# 有名になったのを	知らんと
# 挨拶を	して
# 御免	蒙るに
# いいねと	廻わす
# 尻尾を	廻わす
# 左へ	廻わす
# 黒は	しない
# 尻尾を	立てたぎり
# 挨拶も	しない
# 何	おめでてえ
# 御めえなん	おめでて
# 気を	つけろい
# 向う面め	吹い
# 子の	向うづらという
# 言語であるようだが	出来なかった
# 吾輩には	出来なかった
# 了解が	出来なかった
# 伺が	うが吹い
# 子の	向うづらと
# 手めえが	つかれてる
# 悪体を	つかれてる
# 訳を	聞きゃ
# 意味に	至ると
# ため	聞いておきたいが
# 答弁は	得られぬに
# 面と	対ったまま
# 対ったまま	立って
# 無言で	立って
# 声を	張り揚げて
# おや棚へ	上げて
# 畜生が	取ったんだよ
# 今に	帰って来たら
# 空気を	震動させて
# 無遠慮に	震動させて
# 震動させて	俗了してしまう
# 枝を	鳴らさぬ
# 君が	俗了してしまう
# 御代を	俗了してしまう
# 大に	俗了してしまう
# 黒は	怒鳴るなら
# 顔を	して
# 顋を	出しながら
# 前へ	出しながら
# あれを	聞いたかと
# 合図を	する
# 今までは	つかなかったが
# 応対で	つかなかったが
# 気が	つかなかったが
# 下には	転がっている
# 三厘に	相当する
# 骨が	なって
# 泥だらけに	なって
# 君	やってるなと
# 不相変	やってるなと
# 行き掛りは	忘れて
# 感投詞を	奉呈した
# 黒は	直さない
# 事では	直さない
# 機嫌を	直さない
# 何が	やってるでえ
# しゃけの	相変らずた
# 二切で	相変らずた
# 人を	見縊
# た事を	いうねえ
# 代りに	掻き上げた
# 逆かに	掻き上げた
# 辺まで	掻き上げた
# 君が	云う
# 黒君だと	云う
# 事は	知ってるさ
# 始めから	知ってるさ
# 熱いのを	吹き懸ける
# 人間なら	とられて
# 胸倉を	とられて
# 辟易して	困った
# 内心	困った
# 事に	なったなと
# 大声が	聞える
# 用が	あるんだよ
# 牛肉を	持って来るんだよ
# 一斤	持って来るんだよ
# 一斤だよと	破る
# 声が	破る
# 寂寞を	破る
# へん年に	誂えると
# 一遍	誂えると
# 牛肉を	誂えると
# 声を	出し
# 一斤が	隣り
# 自慢なんだから	阿魔だと
# 始末に	終えねえ
# 阿魔だと	張る
# 黒は	張る
# 四つ足を	張る
# 踏	張る
# 吾輩は	見ている
# 一斤くらいじゃあ	出来ねえんだが
# 承知が	出来ねえんだが
# 今に	食ってやら
# ために	誂えた
# 吾輩は	帰そうとする
# 彼を	帰そうとする
# 御めっちの	知った
# 後足で	崩れた
# 霜柱の	崩れた
# 奴を	浴びせ
# 頭へ	浴びせ
# 吾輩が	驚ろいて
# 驚ろいて	払っている
# 泥を	払っている
# 間に	隠した
# 黒は	隠した
# 垣根を	潜って
# どこかへ	隠した
# 姿を	隠した
# 牛を	行った
# 覘に	行った
# 家へ	帰ると
# 中が	聞える
# 笑い声さえ	聞える
# 陽気に	聞える
# 椽側から	上って
# 傍へ	寄って
# 客が	来ている
# 頭を	分けて
# 奇麗に	分けて
# 羽織に	着けて
# 袴を	着けて
# 主人の	手あぶりの
# 角を	見ると
# 巻煙草入れと	並んで
# 名刺が	あるので
# 事も	知れた
# 途中からであるから	分らんが
# 前後が	分らんが
# 吾輩が	紹介した
# 前回に	紹介した
# 事に	関しているらしい
# 趣向が	あるから
# 是非いっしょに	来いと
# 客は	云う
# 何ですか	食うのについて
# 西洋料理へ	行って
# 午飯を	食うのについて
# 食うのについて	あるというのですかと
# 趣向が	あるというのですかと
# あるというのですかと	押しやる
# 主人は	押しやる
# 茶を	続ぎ足して
# 続ぎ足して	押しやる
# 前へ	押しやる
# 趣向というのが	分らなかったんですが
# 時は	分らなかったんですが
# 私にも	分らなかったんですが
# 分らなかったんですが	あるのだろうと
# 事ですから	あるのだろうと
# 何か	あるのだろうと
# 種が	あるのだろうと
# あるのだろうと	思いまして
# いっしょに	行きましたか
# 主人は	云わぬばかりに
# それ	見たかと
# 上に	乗った
# 頭を	叩く
# ぽかと	叩く
# 茶番	見たような
# 癖でねと	思い出す
# 急に	思い出す
# アンドレア・デル・サルト事件を	思い出す
# 君	変った
# 何か	変った
# ものを	食おうじゃないかと
# 何を	食いました
# 献立を	見ながら
# 料理についての	御話しが
# それから	黙っていましたよ
# 首を	捻って
# 方を	なって
# 御覧に	なって
# ないようだなと	おっしゃると
# ボイは	黙っていましたよ
# 気で	云うと
# チャップなどは	云うと
# 如何ですと	云うと
# 先生は	黙っていましたよ
# 月並を	食いに
# ここまで	おっしゃるんで
# しないと	おっしゃるんで
# 意味が	分らん
# ものですから	黙っていましたよ
# 顔を	して
# 方を	なって
# 御向きに	なって
# 君	行くと
# 英吉利へ	行くと
# 万葉調が	食えるんだが
# 食えるんだが	圧したようで
# 日本じゃ	行ったって
# どこへ	行ったって
# 版で	圧したようで
# 圧したようで	云うような
# 西洋料理へ	這入る
# しないと	云うような
# 大気で全体	あるのですかな
# 方は	あるのですかな
# 事が	あるのですかな
# あるのですかな	行かれるんですがね
# 何迷亭が	する
# 洋行なんか	する
# もんですか	あり
# そりゃ金も	あり
# 時も	あり
# いつでも	行かれるんですがね
# 過去に	見立てた
# 洒落なんでしょうと	する
# 主人は	する
# 事を	言ったつもりで
# 言ったつもりで	誘い出し
# 笑を	する
# 客はさまで	感服した
# 私はまた	洋行なさったかと
# 洋行なさったかと	思って
# 真面目に	拝聴していました
# それに	見て来たように
# 見て来たように	なさる
# 形容を	なさる
# そりゃ誰かに	聞いたんでしょう
# うそを	つく
# そうのようでと	眺める
# 水仙を	眺める
# 気色にも	取られる
# それなんですねと	押す
# 主人が	押す
# 念を	押す
# 主人は	挟む
# 感投詞を	挟む
# ところで	負けとく
# 事に	御相談なさる
# しようじゃないか	御相談なさる
# 君と	御相談なさる
# ものですから	いってしまったので
# ものですから	つきませんでしたと
# 気が	つきませんでしたと
# 主人に	向って
# 麁忽を	詫びているように
# 詫びているように	見える
# 主人は	聞く
# 無頓着に	聞く
# 謝罪には	おらん
# 同情を	表して
# それから	持って来いと
# ボイにおいトチメンボーを	持って来いと
# 二人前	持って来いと
# メンチボーですかと	聞き直しましたが
# 先生は	訂正されました
# トチメンボーだと	訂正されました
# 訂正されました	ある
# 料理は	あるんですか
# 沈着であるし	いらっしゃるし
# その上	いらっしゃるし
# 西洋通で	いらっしゃるし
# ものと	信じ切っていた
# ものですから	教えてやりました
# 私も	添えて
# 口を	添えて
# トチメンボーだと	教えてやりました
# ボイに	教えてやりました
# ボイは	どうしました
# 今	考えると
# 今日は	云うと
# トチメンボーは	出来ますと
# メンチボーなら	出来ますと
# 御二人前	出来ますと
# それじゃ	来た
# ここまで	来た
# トチメンボーを	都合して
# 都合して	食わせてもらう
# 訳には	行くまいかと
# ボイに	やられると
# 二十銭銀貨を	やられると
# ボイは	行きましたよ
# 料理番と	相談して参りましょうと
# 相談して参りましょうと	行きましたよ
# 奥へ	行きましたよ
# 大変トチメンボーが	食いたかったと
# ボイが	出て来て
# 御誂なら	こしらえますが
# 時間が	かかりますと
# ひまなんだから	食って行こうじゃないかと
# ポッケットから	出して
# 葉巻を	出して
# 私しも	読み出しました
# 仕方がないから	読み出しました
# 懐から	出して
# 日本新聞を	出して
# ボイはまた	行きましたよ
# 奥へ	行きましたよ
# 相談に	行きましたよ
# いやに	掛りますなと
# 手数が	掛りますなと
# 通信を	読む
# ボイが	出て来て
# 近頃は	買われませんから
# 材料が	行っても
# 払底で	行っても
# 亀屋へ	行っても
# 十五番へ	行っても
# 間は	云うと
# 御生憎様でと	云うと
# 気の毒そうに	云うと
# 先生は	来たのになあと
# そりゃ	困ったな
# 方を	なって
# 御覧に	なって
# 私も	黙っている
# 訳にも	参りませんから
# 遺憾極るですなと	合せたのです
# 調子を	合せたのです
# ごもっともでと	賛成する
# 主人が	賛成する
# ごもっともだか	わからん
# 吾輩には	わからん
# ボイも	見えて
# 気の毒だと	見えて
# その内	参りましたら
# 材料が	参りましたら
# 先生が	使うかねと
# 材料は	使うかねと
# 何を	使うかねと
# ボイはへへへへと	笑って
# 返事を	しないんです
# 材料は	云いましたよ
# 俳人だろうと	押し返して
# 先生が	押し返して
# えさようで	買われませんので
# ものだから	買われませんので
# 近頃は	買われませんので
# 横浜へ	行っても
# お気の毒様と	云いましたよ
# 主人は	笑う
# 声で	笑う
# 膝が	揺れて
# 吾輩は	落ちかかる
# 主人は	笑う
# アンドレア・デル・サルトに	罹ったのは
# 一人でないと	云う
# 事を	知ったので
# 急に	なった
# 愉快に	なった
# ものと	見える
# 二人で	出ると
# 表へ	出ると
# 君	行ったろう
# 橡面坊を	使った
# 種に	使った
# 至りですと	云って
# ものの	延びたので
# 時刻が	延びたので
# 大変空腹に	なって
# 御迷惑でしたろうと	表する
# 主人は	表する
# 同情を	表する
# 咽喉を	鳴らす
# 音が	入る
# 耳に	入る
# 東風君は	改まる
# 茶を	飲み干して
# 今日	参りましたのは
# 参りましたのは	あって参ったのでと
# 先生に	あって参ったのでと
# 御願が	あって参ったのでと
# 御用でと	負けずに
# 主人も	負けずに
# 結構でと	注す
# 油を	注す
# 同志だけが	よりまして
# 朗読会というのを	組織しまして
# 組織しまして	続けたいつもりで
# 一回	会合して
# 会合して	続けたいつもりで
# 研究を	続けたいつもりで
# 暮に	開いた
# 朗読会と	云うと
# 何か	附けて
# 節奏でも	附けて
# 類を	読むように
# 読むように	聞えますが
# 風に	やるんです
# やるんです	やるつもりです
# 初めは	やるつもりです
# 作から	やるつもりです
# 創作なんかも	やるつもりです
# やるつもりです	ものででもあるんですか
# 作と	いうと
# 琵琶行のような	ものででもあるんですか
# それじゃ	やったんです
# ものを	やったんです
# やったんです	やりました
# せんだっては	やりました
# 心中物を	やりました
# 近松と	いえば
# 近松に	極っている
# それを	聞き直す
# 愚だと	思っていると
# 主人は	撫でている
# 何にも	分らずに
# 頭を	撫でている
# 叮嚀に	撫でている
# 藪睨みから	惚れられたと
# 人間も	ある
# 世の中だから	足らんと
# 誤謬は	足らんと
# ままに	すましていた
# 東風子は	窺う
# 顔色を	窺う
# それじゃ	朗読するのですかまたは
# 一人で	朗読するのですかまたは
# 朗読するのですかまたは	やるんですか
# 役割を	やるんですか
# やるんですか	見ました
# 役を	懸
# 合で	やって
# 主意は	添えます
# 人物に	持って
# 同情を	持って
# 性格を	発揮するのを
# 第一として	添えます
# それに	添えます
# 身振りを	添えます
# 白は	やるんです
# 人を	写し出すのが
# 主で	やるんです
# 丁稚でも	やるんです
# 人物が	やるんです
# 出てきたように	やるんです
# ものですな	行きますか
# 失礼ながら	行きますか
# 第一回としては	成功した
# 方だと	思います
# 前	やったと
# 心中物と	いうと
# 船頭が	行く
# 御客を	乗せて
# 芳原へ	行く
# 所なんで	やりましたなと
# 幕を	やりましたなと
# 教師だけに	傾ける
# 首を	傾ける
# 鼻から	吹き出した
# 日の出の	煙りが
# 耳を	掠めて
# 横手へ	廻る
# 主人は	したが
# 名を	きいて
# 顔を	したが
# 術語について	見えて
# 質問を	呈出した
# 下婢に	あたる
# ものですかな	思います
# 研究は	見ませんが
# 遣手というのが	見たような
# 助役	見たような
# ものだろうと	思います
# 東風子は	おらんらしい
# さっき	出て来るように
# 人物が	出て来るように
# 出て来るように	使うと
# 仮色を	使うと
# 癖に	解して
# 性格を	解して
# 茶屋に	隷属する
# 娼家に	起臥する
# 見番と	云うのは
# 云うのは	指すのですか
# 一定の場所を	指すのですか
# 人間と	すれば
# 女ですか	思います
# 人間だと	思います
# 何を	司どっているんですかな
# 司どっているんですかな	届いておりません
# あそこまでは	届いておりません
# 調べが	届いておりません
# 内	調べて
# 見ましょうこれで	懸
# 合を	やった
# 日には	出来るだろうと
# ものが	出来るだろうと
# 吾輩は	見上げた
# 顔を	見上げた
# 朗読家は	加わったんですか
# ほかに	加わったんですか
# 人が	加わったんですか
# 加わったんですか	おりました
# 口髯を	生やして
# せりふを	かうのですから
# 使	かうのですから
# 花魁が	起す
# 癪を	起す
# ところが	あるので
# 朗読でも	起さなくっちゃ
# 癪を	起さなくっちゃ
# いけないんですかと	尋ねる
# 主人は	尋ねる
# 心配そうに	尋ねる
# 大事ですからと	いる
# 東風子は	いる
# どこまでも	いる
# 気で	いる
# 癪が	起りましたかと
# 主人は	吐く
# 警句を	吐く
# 無理でしたと	吐く
# 東風子も	吐く
# 警句を	吐く
# 役割でしたと	聞く
# 主人が	聞く
# 君が	して
# 船頭君に	して
# 船頭が	務まる
# ものなら	やれると
# 僕にも	やれると
# 見番くらいは	やれると
# 語気を	洩らす
# 無理でしたかと	打ち明ける
# ところを	打ち明ける
# 癪に	障った
# 口調で	終りました
# 船頭で	終りました
# 催しも	終りました
# 竜頭蛇尾に	終りました
# 会場の	隣りに
# 女学生が	下宿していましてね
# 四五人	下宿していましてね
# それが	聞いた
# その日は	あるという
# 朗読会が	あるという
# 事を	探知して
# どこかで	探知して
# 探知して	傍聴していた
# 窓下へ	来て
# ものと	見えます
# 私しが	使って
# 仮色を	使って
# 大丈夫と	思って
# 得意に	やっていると
# 身振りが	あまり過ぎたのでしょう
# 今まで	えていた
# 耐ら	えていた
# 女学生が	笑いだした
# 一度に	笑いだした
# ものですから	驚ろいたし
# 驚ろいた事も	驚ろいたし
# 驚ろいたし	悪るいし
# 極りが	悪るいし
# 悪るい事も	悪るいし
# 悪るいし	折られてから
# 腰を	折られてから
# 後が	つづけられないので
# それ限りで	散会しました
# 成功だと	称する
# ものだろうと	想像すると
# 想像すると	笑わずにはいられない
# 咽喉仏が	鳴る
# 主人は	撫でてくれる
# 柔かに	撫でてくれる
# 頭を	撫でてくれる
# 人を	笑って
# ところも	ある
# 事でと	述べている
# 主人は	述べている
# 正月	述べている
# 弔詞を	述べている
# 第二回からは	やるつもりなので
# 奮発して	やるつもりなので
# 盛大に	やるつもりなので
# やるつもりなので	仰ぎたいので
# 今日	出ましたのも
# 全くそのためで	仰ぎたいので
# 先生にも	仰ぎたいので
# 上	仰ぎたいので
# 御尽力を	仰ぎたいので
# 僕には	起せませんよと
# 癪なんか	起せませんよと
# 主人は	断わりかける
# 名簿がと	云いながら
# 風呂敷から	出す
# 大事そうに	出す
# 帳面を	出す
# これへ	願いたいのでと
# 上	願いたいのでと
# 御捺印を	願いたいのでと
# 帳面を	開いたまま
# 前へ	開いたまま
# 開いたまま	置く
# 名が	している
# 勢揃を	している
# はあ賛成員に	ならん
# 事も	ありませんが
# 義務が	あるのですかと
# あるのですかと	見える
# 牡蠣先生は	見える
# 体に	見える
# 義務と	申して
# 御名前だけを	御記入下さって
# 御記入下さって	御表し被下れば
# 意さえ	御表し被下れば
# 結構です	這入りますと
# そんなら	這入りますと
# 義務の	かからぬ
# 事を	知るや
# 主人は	気軽になる
# 急に	気軽になる
# 事が	分って
# 連判状へでも	書き入れますと
# 名を	書き入れますと
# 顔付を	する
# 加之	列ねている
# 学者が	列ねている
# 名前を	列ねている
# 中に	入籍させるのは
# 姓名だけでも	入籍させるのは
# 今まで	出合った
# 事に	出合った
# 勢の	あるのも
# 失敬と	這入る
# 主人は	這入る
# 書斎へ	這入る
# 印を	とりに
# 吾輩は	落ちる
# 上へ	落ちる
# 東風子は	頬張る
# カステラを	つまんで
# 一口に	頬張る
# 吾輩は	思い出す
# 雑煮事件を	思い出す
# 主人が	出て来た
# 書斎から	持って
# 印形を	持って
# 中に	落ちついた
# カステラが	落ちついた
# 主人は	着かぬらしい
# カステラが	足りなくなった
# 一切	足りなくなった
# 事には	着かぬらしい
# 気が	着かぬらしい
# 気が	つくと
# 第一に	疑われる
# 東風子が	帰ってから
# 主人が	入って
# 書斎に	入って
# 上を	見ると
# 手紙が	来ている
# 真面目だと	思う
# 主人が	思う
# この間などは	云うのが
# 其後別に	着せる
# 恋	着せる
# 婦人も	参らず
# 無之	参らず
# 方より	参らず
# 艶書も	参らず
# 無事に	消光罷り
# 消光罷り	在り
# 乍憚御休心可被下候と	云うのが
# 云うのが	来た
# それに	較べると
# 一寸参堂仕り度	候えども
# 消極主義に	反して
# 毎日	廻る
# 毎日目の	廻る
# 事だから	しいに違いないと
# 正月は	廻るのに
# 遊び	廻るのに
# 忙が	しいに違いないと
# しいに違いないと	同意する
# 主人は	同意する
# 腹の中で	同意する
# 迷亭君に	同意する
# ひまを	偸み
# 偸み	致さんと
# 東風子に	致さんと
# 御馳走を	致さんと
# 存じ候処	果さず
# 為	果さず
# め其意を	果さず
# 通りに	なって来たと
# 主人は	微笑する
# 無言で	微笑する
# 主人は	読みとばす
# 主人は	する
# 手紙に	する
# 返事を	する
# 久し振りにて	供し
# 晩餐でも	供し
# 珍味も	無之候えども
# トチメンボーを	振り廻している
# 失敬なと	むっとする
# 主人は	むっとする
# トチメンボーは	計りがたきにつき
# 為	依ると
# め	依ると
# 兼候も	計りがたきにつき
# 舌でも	入れ
# 御風味に	入れ
# 両天秤を	かけたなと
# 主人は	読みたくなる
# あとが	読みたくなる
# 通り	つき
# 一羽に	つき
# 半ばにも	足らぬ程
# 胃嚢を	充たす
# うそを	打ち遣ったように
# 主人は	打ち遣ったように
# 打ち遣ったように	いう
# 浅草花屋敷等には	見受け候えども
# 独りで	苦心しているのじゃないかと
# 勝手に	苦心しているのじゃないかと
# 苦心しているのじゃないかと	表しない
# 主人は	表しない
# 意を	表しない
# 一時	流行致し
# 非常に	流行致し
# 平生より	動かし
# ひそかに	動かし
# 食指を	動かし
# 宴席に	欠くべからざる
# 好味と	相成
# レスター伯が	招待致し
# エリザベス女皇を	招待致し
# ケニルウォースに	招待致し
# レンブラントが	画き
# 図にも	広げたる
# 孔雀が	広げたる
# 尾を	広げたる
# 儘卓上に	居り候
# 横わり	居り候
# かくくらいなら	こぼす
# 多忙でも	こぼす
# 不平を	こぼす
# 如く御馳走の	食べ続けにては
# うちに	相成るは
# 大兄の如く	相成るは
# 胃弱と	相成るは
# 何も	しなくても
# 僕を	しなくても
# 標準に	しなくても
# 主人は	つぶやいた
# 説に	よれば
# 日に	開き
# 三度も	開き
# 宴会を	開き
# 日に	醸すべく
# 三度も	醸すべく
# 食饌に	就き候えば
# 人にても	醸すべく
# 消化機能に	醸すべく
# 不調を	醸すべく
# 衛生とを	両立せし
# 研究を	尽したる
# 不相当に	貪ると同時に
# 滋味を	貪ると同時に
# 胃腸を	保持するの
# 常態に	保持するの
# 必要を	認め
# 主人は	熱心になる
# 急に	熱心になる
# 方法に	よりて
# 浴前に	下せる
# 嚥	下せる
# ものを	嘔吐し
# 功を	奏したる
# 後	就き
# 食卓に	就き
# 湯に	入りて
# かくの	如くすれば
# 好物は	生ぜず
# 次第	貪り
# 候も	生ぜず
# 諸機関に	生ぜず
# 障害を	生ぜず
# 主人は	する
# 顔を	する
# 増加は	申す迄もなく
# 第二年とも	相成
# 術を	研究せざるべからざる
# 大国民も	心痛罷りあり
# 将来に	相成る
# 於て	相成る
# 大兄の如く	相成る
# 胃病患者と	相成る
# 事と	心痛罷りあり
# 窃かに	心痛罷りあり
# 大兄のごとくか	思う
# 癪に障る男だと	思う
# 主人が	思う
# 此際	通ずる
# 事情に	通ずる
# 者が	考究し
# 古史伝説を	考究し
# 考究し	発見し
# 秘法を	発見し
# 之を	候わば
# 社会に	候わば
# 応用致し	候わば
# 所謂禍を	相成り
# 未萌に	相成り
# 功徳にも	相成り
# 平素逸楽を	致し
# 擅に	致し
# 候御恩返も	相立ち
# 妙だなと	捻る
# 首を	捻る
# 此間中より	居候えども
# 著述を	居候えども
# 渉猟致し	居候えども
# 端緒をも	見出し得ざるは
# 性質に	候えば
# 嘔吐方を	信じ居り
# うちと	信じ居り
# 右は	つき
# 発見次第御報道可	仕
# 候に	つき
# 右発見後に	致し
# 胃弱に	悩み居らるる
# ものだから	読んでいた
# 仕舞まで	本気にして
# 本気にして	読んでいた
# 新年匆々	やる
# 悪戯を	やる
# ひま人だなあと	云った
# 主人は	云った
# 四五日は	過ぎ去った
# 水仙が	凋んで
# 梅が	開きかかるのを
# 瓶ながら	開きかかるのを
# 開きかかるのを	眺め
# 一両度三毛子を	訪問して
# 訪問して	見たが
# 最初は	思ったが
# 留守だと	思ったが
# 二返目には	寝ているという
# 病気で	寝ているという
# 事が	知れた
# 中で	しているのを
# 御師匠さんと	しているのを
# 下女が	しているのを
# しているのを	隠れて
# 影に	隠れて
# 三毛は	たべるかい
# 御飯を	たべるかい
# 今朝から	食べません
# 何にも	食べません
# 御火燵に	寝かしておきました
# 取扱を	受けている
# 境遇と	比べて
# 己が	愛している
# 猫が	受けていると
# かくまで	受けていると
# 厚遇を	受けていると
# 御飯を	たべないと
# 身体が	疲れるばかりだからね
# 私共でさえ	いただかないと
# 一日御を	いただかないと
# 下女は	する
# 返事を	する
# 家では	大切かも知れない
# 下女より	大切かも知れない
# 方が	大切かも知れない
# 御医者様へ	連れて行ったの
# 私が	行くと
# 三毛を	だいて
# 診察場へ	行くと
# 風邪でも	引いたのかって
# 引いたのかって	するんでしょう
# 脈を	するんでしょう
# とろうと	するんでしょう
# これですって	直したら
# 三毛を	直したら
# 上へ	直したら
# 病気は	分らん
# わしにも	分らん
# もの	苛いじゃございませんか
# 腹が	立ったから
# それじゃ	見ていただかなくって
# もよう	ございます
# 猫なんですって	帰って参りました
# 三毛を	入れて
# 懐へ	入れて
# うちなどで	聞かれる
# 雅であると	感心した
# 云うようだが	痛むんでございますよ
# ええきっと風邪を	引いて
# 咽喉が	痛むんでございますよ
# 風邪を	引くと
# どなたでも	出ますからね
# 御咳が	出ますからね
# 下女だけに	使う
# 言葉を	使う
# 近頃は	出来てのう
# 肺病とか	云う
# ものが	出来てのう
# ペストだのって	なり
# 病気ばかり	殖えた
# 日	なり
# 隙も	なり
# ゃしませんのでございますよ	いかんよ
# 御前も	つけないと
# 気を	つけないと
# 下女は	感動している
# 大に	感動している
# 風邪を	引くと
# 出あるきもしないようだったに	出来ましてね
# あなた	出来ましてね
# それが	出来ましてね
# 近頃は	出来ましてね
# 友達が	出来ましてね
# 秘密でも	語る
# 所に	いる
# 雄猫でございますよ	人でござんす
# 教師と	云うのは
# 云うのは	人でござんす
# 声を	出す
# 人かえ	人でござんす
# ええ顔を	洗う
# たんびに	絞め殺されるような
# 鵝鳥が	絞め殺されるような
# 声を	出す
# 鵝鳥が	絞め殺されるような
# 主人は	ある
# 毎朝風呂場で	やる
# 含嗽を	やる
# 時	ある
# 楊枝で	つっ突いて
# 咽喉を	つっ突いて
# 声を	出す
# 無遠慮に	出す
# 癖が	ある
# 時は	やる
# 時は	やる
# 元気	づいて
# 時も	やる
# 細君の	話しでは
# ここへ	引越す
# ある時	やり
# 今日まで	やめた
# 一日も	やめた
# 癖であるが	つかん
# 事を	続けているのか
# 続けているのか	つかん
# 吾等猫などには	つかん
# 想像も	つかん
# それも	聞く
# 酷評を	やる
# ものだと	聞く
# 耳を	聞く
# あとを	聞く
# 声を	出して
# 呪いに	なるか
# もので	おらなかったよ
# 屋敷町などで	する
# 洗い方を	する
# ものは	おらなかったよ
# 一人も	おらなかったよ
# 下女は	使用する
# 感服しては	使用する
# 主人を	持っている
# 猫だから	おやり
# 野良猫さ	来たら
# 今度	来たら
# 病気に	なったのも
# なったのも	とってやります
# もの	とってやります
# 讐を	とってやります
# 冤罪を	蒙った
# こいつは	寄れないと
# 三毛子には	帰った
# 主人は	執っている
# 中で	執っている
# 何か	執っている
# 体で	執っている
# 筆を	執っている
# 所で	聞いた
# 評判を	話したら
# 知らぬが仏とやらで	なりすましている
# 詩人に	なりすましている
# ところへ	行かれないと
# 当分	行かれないと
# 多忙で	行かれないと
# 年始状を	よこした
# 迷亭君が	やって来る
# 飄然と	やって来る
# 新体詩でも	作っているのかね
# 面白いのが	出来たら見せ
# たまえと	云う
# 文章だと	思ったから
# 今	翻訳して
# 翻訳して	見ようと
# 主人は	開く
# 重たそうに	開く
# 口を	開く
# 文章だい	分らんよ
# 誰れのか	分らんよ
# 善いのが	あるから
# 馬鹿に	出来ない
# 全体	あったのかと
# どこに	あったのかと
# あったのかと	問う
# 第二読本と	答える
# 主人は	答える
# 落ちつき	はらって
# 第二読本が	どうしたんだ
# 僕の	翻訳している
# 名文と	云うのは
# 云うのは	あると
# 中に	あると
# 讐を	討とうと
# ところで	討とうと
# 寸法なんだろう	違うさと
# 法螺吹きとは	違うさと
# 口髯を	捻る
# 山陽に	ござらぬかと
# 先生近頃名文は	ござらぬかと
# 山陽が	書いた
# 馬子の	書いた
# 催促状を	示して
# 名文は	云ったという
# これでしょうと	云ったという
# 話が	あるから
# 審美眼も	たしかかも知れん
# どれ	読んで
# 僕が	批評してやるからと
# 批評してやるからと	云う
# 迷亭先生は	云う
# 事を	云う
# 主人は	読み始める
# 禅坊主が	読むような
# 遺誡を	読むような
# 声を	出して
# 引力	云うのは
# 巨人引力と	云うのは
# 巨人引力と	云う
# 題さ	わからんね
# 題だな	わからんね
# 僕には	わからんね
# 意味が	わからんね
# 引力と	云う
# 名を	持っている
# つもりさ	しよう
# 表題だから	負けておくと
# 本文を	読むさ
# 雑ぜ	かえしては
# 予じめ念を	押してまた
# ケートは	眺める
# 窓から	眺める
# 外面を	眺める
# 小児が	投げて
# 球を	投げて
# 彼等は	擲つ
# 球を	擲つ
# 空中に	擲つ
# 球は	のぼる
# 上へと	のぼる
# 彼等はまた	擲つ
# 球を	擲つ
# たびに	落ちてくる
# 球は	落ちてくる
# 落ちるのか	のぼらぬかと
# 上へとのみ	のぼらぬかと
# ケートが	聞く
# 地中に	住む
# 故にと	答える
# 母が	答える
# 彼は	引く
# 万物を	引く
# 方へと	引く
# 彼は	引く
# 家屋を	引く
# 地上に	引く
# 小児も	飛んでしまう
# 葉が	落ちるのを
# 落ちるのを	見たろう
# あれは	呼ぶのである
# 巨人引力が	呼ぶのである
# 本を	落す
# 事が	あろう
# 巨人引力が	来いと
# 球が	あがる
# 空に	あがる
# 巨人引力は	呼ぶ
# これは	恐れ入った
# ところで	預った
# 御返礼に	預った
# なんでもないさ	見たのさ
# うまいから	訳して
# 見たのさ	思わんかねと
# 君は	思わんかねと
# 奥を	見る
# 君に	して
# 伎倆	あらんとは
# 今度は	担がれたよ
# 降参降参と	承知して
# 一人で	承知して
# 主人には	通じない
# 君を	降参させる
# 文章だと	思ったから
# 恐縮だ	及ばん
# 恐縮するには	及ばん
# 僕も	やめたから
# 近頃は	やめたから
# 水彩画を	やめたから
# 代りに	やろうと
# 文章でも	やろうと
# 至りだよ	乗り気になると
# 僕も	乗り気になると
# 乗り気になると	している
# 主人は	している
# 疳違いを	している
# ところへ	失礼しましたと
# 寒月君が	失礼しましたと
# 先日は	失礼しましたと
# 失礼しましたと	這入って来る
# 名文を	拝聴して
# 拝聴して	退治られた
# 亡魂を	退治られた
# ところでと	ほのめかす
# 迷亭先生は	ほのめかす
# 訳の	わからぬ
# 事を	ほのめかす
# これも	する
# 訳の	分らぬ
# 挨拶を	する
# 左のみ	浮かれた
# 先日は	来たよ
# 紹介で	云う
# 越智東風と	云う
# 人が	来たよ
# 越智東風と	云う
# 男ですが	変っている
# ところが	あるのであるいは
# 御迷惑かと	思いましたが
# こちらへ	上っても
# ことについて	弁じて行き
# 何か	弁じて行き
# どこへ	行っても
# 人には	するのが
# 講釈を	するのが
# 癖でしてね	するんだいと
# 講釈を	するんだいと
# かしと	待ち構えた
# 迷亭君は	入れる
# 口を	入れる
# 東風と	云うのを
# 云うのを	読まれると
# 音で	読まれると
# 大変	するので
# 気に	するので
# 迷亭先生は	つまみ出す
# 煙草入から	つまみ出す
# 煙草を	つまみ出す
# 越智こちですと	断りますよ
# 妙だねと	呑み込む
# 雲井を	呑み込む
# 底まで	呑み込む
# それが	来たので
# 全く文学熱から	来たので
# こちと	読むと
# 遠近と	云う
# 成語に	なる
# 姓名が	踏んでいると
# 韻を	踏んでいると
# それだから	読むと
# 東風を	読むと
# 音で	読むと
# 僕が	買ってくれないと
# 苦心を	買ってくれないと
# 人が	買ってくれないと
# 不平を	云うのです
# 云うのです	変ってると
# 迷亭先生は	吐き返す
# 図に	乗って
# 底から	吐き返す
# 雲井を	吐き返す
# 孔まで	吐き返す
# 途中で	して
# 煙が	して
# 戸迷いを	して
# 出口へ	引きかかる
# 先生は	返る
# 煙管を	握って
# 先日	来た
# 時は	笑われたと
# 朗読会で	なって
# 船頭に	なって
# 女学生に	笑われたと
# 主人は	云う
# 迷亭先生が	叩く
# 煙管で	叩く
# 膝頭を	叩く
# 吾輩は	離れる
# 険呑に	なったから
# 傍を	離れる
# せんだって	御馳走した
# トチメンボーを	御馳走した
# 何でも	やるつもりだから
# 第二回には	やるつもりだから
# 文士を	招待して
# 招待して	やるつもりだから
# 大会を	やるつもりだから
# やるつもりだから	願いたいって
# 先生にも	願いたいって
# 是非御臨席を	願いたいって
# 今度も	やる
# 世話物を	やる
# つもりかいと	聞くと
# 次は	しましたと
# 者を	撰んで
# 金色夜叉に	しましたと
# 君にゃ	当ってるかと
# 役が	当ってるかと
# 僕は	思ってるよ
# 是非出席して	喝采しようと
# 喝采しようと	思ってるよ
# 寒月君が	する
# 笑い方を	する
# 大違いだと	とる
# 主人は	とる
# 復讐を	とる
# 一度に	とる
# 迷亭君は	笑う
# 気にも	留めない
# 様子で	笑う
# 俎と	云う
# 格だからなあと	笑う
# ところだろうと	云う
# 主人が	云う
# 俎と	云う
# 語を	解さないのであるが
# 主人は	解さないのであるが
# 解さないのであるが	応用するのである
# 永年教師を	して
# ものだから	応用するのである
# 時には	応用するのである
# 経験を	応用するのである
# 社交上にも	応用するのである
# 事ですかと	聞く
# 寒月が	聞く
# 真率に	聞く
# 主人は	ねじ伏せる
# 方を	見て
# 水仙は	挿したのだが
# 暮に	買って来て
# 僕が	買って来て
# 帰りがけに	買って来て
# 挿したのだが	ねじ伏せる
# 俎を	ねじ伏せる
# 無理に	ねじ伏せる
# 暮と	いえば
# 暮に	したよと
# 僕は	したよと
# 経験を	したよと
# 迷亭が	廻わす
# 煙管を	廻わす
# 大神楽のごとく	廻わす
# 指の	廻わす
# 経験か	聞かし玉えと
# 聞かし玉えと	つく
# 主人は	つく
# 俎を	見捨てた
# 後に	見捨てた
# 気で	つく
# 息を	つく
# 経験というのを	聞くと
# 二十七日と	記憶しているがね
# 東風から	伺いたいから
# 上	伺いたいから
# 御高話を	伺いたいから
# 御在宿を	願うと
# 触れが	あったので
# 朝から	待っていると
# 心待ちに	待っていると
# 先生	来ないやね
# 昼飯を	食って
# 前で	読んでいる
# 滑稽物を	読んでいる
# ところへ	来たから
# 母から	来たから
# 手紙が	来たから
# 年寄だけに	思ってね
# いつまでも僕を	思ってね
# 小供のように	思ってね
# 夜間外出を	するなとか
# ストーブを	焚いて
# 室を	してやらないと
# 煖かに	してやらないと
# 風邪を	引くとか
# 注意が	あるのさ
# ものだ	いかないと
# 他人では	いかないと
# 僕も	感動した
# 時だけは	感動した
# 大に	感動した
# それに	つけても
# 何か	大著述でもして
# 大著述でもして	揚げなくては
# 家名を	揚げなくては
# 母の	生きている
# うちに	して
# 天下を	して
# 文壇に	迷亭先生あるを
# 迷亭先生あるを	知らしめたいと
# 気に	なった
# 戦争が	始まって
# 若い人達は	働らいているのに
# 辛苦を	して
# ために	働らいているのに
# 働らいているのに	遊んでいると
# 節季師走でも	遊んでいると
# お正月のように	遊んでいると
# 気楽に	遊んでいると
# 僕は	遊んじゃいないやね
# これでも	遊んじゃいないやね
# 母の	思ってるように
# 思ってるように	遊んじゃいないやね
# あとへ	以て来て
# 以て来て	負傷した
# 朋友で	出て
# 戦争に	出て
# 名前が	列挙してあるのさ
# 名前を	読んだ
# 時には	つまらないと
# 世の中が	味気なくなって
# 味気なくなって	つまらないと
# 人間も	つまらないと
# 気が	起ったよ
# 私しも	取る
# 年に	候えば
# 御雑煮を	祝い
# 今度限りかと	書いてあるんで
# 事が	書いてあるんで
# なおのこと気が	くさくさしてしまって
# 東風が	来れば
# 先生	来ない
# 晩飯に	なったから
# 母へ	書こうと
# 返事でも	書こうと
# 十二三行	かいた
# 手紙は	あるのだが
# 六尺以上も	あるのだが
# あるのだが	出来んから
# 僕には	出来んから
# 芸は	出来んから
# いつでも	御免蒙る
# 十行内外で	御免蒙る
# 事に	あるのさ
# 一日	動かず
# 東風が	来たら
# 気に	なって
# 郵便を	入れながら
# 散歩に	出掛けたと
# 方へは	出てしまった
# 足が	向かないで
# 方へ	出てしまった
# 我れ知らず	出てしまった
# 晩は	曇ってから
# 風が	向うから
# 御濠の	向うから
# 方から	鳴って
# 汽車が	鳴って
# ヒューと	鳴って
# 土手下を	通り過ぎる
# 感じが	する
# 無常迅速などと	云う
# 奴が	馳け廻る
# 中を	馳け廻る
# 人が	云うが
# 首を	云うが
# 縊ると	云うが
# 時に	誘われて
# 気に	なるのじゃないかと
# なるのじゃないかと	思い出す
# 首を	上げて
# 上を	見ると
# 真下に	来ているのさ
# 何だいと	投げ入れる
# 主人が	投げ入れる
# 断句を	投げ入れる
# 迷亭は	縮める
# 領を	縮める
# 台でしょう寒月が	ひろげる
# 波紋を	ひろげる
# 名が	付いたかと
# 言い伝えで	来ると
# 誰でも	来ると
# 下へ	来ると
# 首が	縊りたくなる
# 上に	あるが
# 松は	あるが
# そら首縊りだと	来て
# 松へ	ぶら下がっている
# 年に	二三返は
# 二三返は	ぶら下がっている
# 松では	ならん
# 気に	ならん
# 具合に	出ている
# 枝が	出ている
# 方へ	出ている
# 横に	出ている
# あのままに	しておくのは
# 所へ	下げて
# 人間を	下げて
# 誰か	来ないかしらと
# 四辺を	見渡すと
# 誰も	来ない
# 自分で	下がろうか
# いやいや自分が	下がっては
# 希臘人は	添えたと
# 席で	して
# 真似を	して
# 余興を	添えたと
# 一人が	登って
# 上へ	登って
# 結び目へ	入れる
# 首を	入れる
# 途端に	蹴返す
# ものが	蹴返す
# 台を	蹴返す
# 首を	入れた
# 当人は	飛び下りるという
# 台を	引かれると同時に
# 縄を	ゆるめて
# 事実なら	及ばん
# 僕も	見ると
# 一つ	試みようと
# 枝へ	懸けて
# 手を	懸けて
# 具合に	撓る
# 首が	かかって
# ところを	想像して
# 想像して	見ると
# 事に	しようと
# 東風が	来て
# 気の毒だと	考え出した
# 東風に	逢って
# 約束通り	して
# 気に	なって
# うちへ	帰ったのさ
# かいと	聞く
# 主人が	聞く
# 寒月が	云う
# しながら	云う
# うちへ	帰って
# 東風は	来ていない
# 今日は	あったので
# 無拠処差支えが	あって
# 永日御面晤を	期すという
# 端書が	あったので
# 安心して	思った
# 首が	縊れる
# 下駄を	引き懸けて
# 急ぎ足で	引き返して
# 所へ	引き返して
# 顔を	見て
# たんだいと	焦れる
# 主人は	焦れる
# 佳境に	入りますねと
# 寒月は	ひねくる
# 紐を	ひねくる
# 誰か	来て
# 先へ	ぶら下がっている
# 一足違いでねえ	したよ
# 君	したよ
# 事を	したよ
# 時は	取り着かれたんだね
# 死神に	取り着かれたんだね
# ゼームスなどに	云わせると
# 僕が	存在している
# 現実界が	感応したんだろう
# 因果法によって	感応したんだろう
# 事が	ある
# ものじゃないか	すまし返っている
# 迷亭は	すまし返っている
# 主人は	やられたと
# 何も	云わずに
# 空也餅を	頬張って
# 口を	云わしている
# 寒月は	笑っていたが
# 灰を	掻き馴らして
# 丁寧に	掻き馴らして
# 俯向いて	笑っていたが
# 口を	開く
# 事で	思われませんが
# 有りそうにも	思われませんが
# 自分で	似たような
# 経験を	近頃した
# ものですから	なりません
# 気に	なりません
# 首を	縊りたくなったの
# これも	思われます
# 同日	起った
# 同刻くらいに	起った
# 出来事ですから	思われます
# 不思議に	思われます
# 迷亭も	頬張る
# 空也餅を	頬張る
# その日は	ありまして
# 家で忘年会兼合奏会が	ありまして
# 私も	携えて行きました
# それへ	携えて行きました
# ヴァイオリンを	携えて行きました
# 令夫人が	集って
# 盛会で	整っていました
# 快事と	思う
# 万事が	整っていました
# 晩餐も	すみ
# 合奏も	すんで
# 四方の	話しが
# 出て時刻も	大分遅くなったから
# 大分遅くなったから	帰ろうかと
# 暇乞いを	して
# 夫人が	来て
# そばへ	来て
# あなたは	聞きますので
# 御承知ですかと	聞きますので
# 小声で	聞きますので
# 両三日前に	逢った
# 時は	見受けませんでしたから
# 悪いようには	見受けませんでしたから
# 私も	驚ろいて
# 驚ろいて	見ますと
# 様子を	聞いて
# 私しの	逢った
# 晩から	発熱して
# 急に	発熱して
# 発熱して	口走るそうで
# 譫語を	口走るそうで
# 口走るそうで	出て来るというのです
# うちに	出て来るというのです
# 名が	出て来るというのです
# 主人は	謹聴している
# 迷亭先生も	云わず
# 月並は	云わず
# 静粛に	謹聴している
# 医者を	呼んで
# わからんが	犯しているから
# 熱が	しいので
# 劇	しいので
# 脳を	犯しているから
# 睡眠剤が	思うように
# 思うように	奏しないと
# 功を	奏しないと
# 危険であると	云う
# 診断だそうで	起ったのです
# 私は	起ったのです
# それを	聞くや
# 感じが	起ったのです
# 夢で	うなされる
# 感じで	なって
# 空気が	なって
# 急に	なって
# 固形体に	なって
# 四方から	しめつけるごとく
# 身を	しめつけるごとく
# 事ばかりが	あって
# 中に	あって
# 失敬だが	待ってくれ
# さっきから	伺っていると
# ○子さんと	云うのが
# 云うのが	聞えるようだが
# 二返ばかり	聞えるようだが
# 君と	顧みると
# 主人を	顧みると
# 主人も	する
# うむと	する
# 生返事を	する
# それだけは	廃しましょう
# 当人の	迷惑になるかも
# 迷惑になるかも	知れませんから
# すべて	行くつもりかね
# 曖然として	行くつもりかね
# かたで	行くつもりかね
# 冷笑なさっては	話しなんですから
# 真面目な	話しなんですから
# 話しなんですから	きかかったのです
# 婦人が	なった
# 急に	なった
# 病気に	なった
# 事を	考えると
# 感慨で	なって
# 胸が	なって
# 一杯に	なって
# 活気が	起したように
# 一度に	起したように
# ストライキを	起したように
# 起したように	滅入ってしまいまして
# 元気が	滅入ってしまいまして
# 蹌として	きかかったのです
# 踉という	きかかったのです
# 形ちで	きかかったのです
# 吾妻橋へ	きかかったのです
# 欄干に	見ると
# 倚って	見ると
# 下を	見ると
# 干潮か	分りませんが
# 水が	かたまって
# 動いているように	見えます
# 方から	通りました
# 人力車が	一台馳けて来て
# 一台馳けて来て	通りました
# 上を	通りました
# 火を	見送っていると
# 処で	消えました
# 私はまた	見る
# 水を	見る
# 方で	呼ぶ
# 名を	呼ぶ
# 声が	聞えるのです
# 今時分人に	呼ばれる
# 誰だろうと	すかして
# 面を	すかして
# 何にも	分りません
# 違いない	帰ろうと
# 二足	あるき出すとまた
# 声で	呼ぶのです
# 遠くから	呼ぶのです
# 名を	呼ぶのです
# 私は	聞きました
# 耳を	聞きました
# 三度目に	呼ばれた
# 時には	出したのです
# 欄干に	捕まっていながら
# 膝頭が	出したのです
# 悸え	出したのです
# 声は	出るようですが
# 方か	出るようですが
# 底から	出るようですが
# 私は	したのです
# 返事を	したのです
# ものですから	見渡しました
# 水に	響いて
# 自分で	驚かされて
# 声に	驚かされて
# 周囲を	見渡しました
# 月も	見えません
# 時に	巻き込まれて
# 私は	巻き込まれて
# 中に	巻き込まれて
# 声の	出る
# 所へ	行きたいと
# 気が	起ったのです
# 声が	刺し通したので
# 苦しそうに	刺し通したので
# 訴えるように	求めるように
# 救を	求めるように
# 求めるように	刺し通したので
# 耳を	刺し通したので
# 今度は	眺めました
# 今直に	行きますと
# 欄干から	眺めました
# 半身を	眺めました
# 水を	眺めました
# 私を	呼ぶ
# 声が	洩れて来るように
# 下から	洩れて来るように
# 無理に	洩れて来るように
# 洩れて来るように	思われましてね
# 下だなと	思いながら
# 私は	乗りましたよ
# 上に	乗りましたよ
# 今度	呼んだら
# 決心して	見つめているとまた
# 流を	見つめているとまた
# 声が	浮いて来る
# 糸のように	浮いて来る
# ここだと	思って
# 力を	込めて
# 一反	飛び上がっておいてそして
# 小石か	落ちてしまいました
# かいと	ぱちつかせて
# 主人が	ぱちつかせて
# 眼を	ぱちつかせて
# そこまで	行こうとは
# 迷亭が	つまむ
# 頭を	つまむ
# 後は	遠くなって
# 気が	遠くなって
# 眼が	さめて
# どこも	濡れた
# 水を	飲んだような
# 感じも	しない
# 変だと	気が付いて
# そこいらを	見渡すと
# 中へ	飛び込んだつもりで
# 飛び込んだつもりで	いた
# 真中へ	飛び下りたので
# 間違だけで	出る
# 声の	出る
# 所へ	行く
# 事が	出来なかったのです
# 寒月は	荷厄介にしている
# 例のごとく	荷厄介にしている
# 紐を	荷厄介にしている
# 経験と	似ている
# 材料に	なるね
# 感応と	云う
# 題で	したら
# 写生文に	したら
# きっと文壇を	驚かすよ
# 病気は	なったかねと
# 迷亭先生が	追窮する
# 二三日前	行きましたら
# 年始に	行きましたら
# 内で	突いていましたから
# 羽根を	突いていましたから
# ものと	見えます
# 体であったが	出す
# 時	開いて
# ようやく口を	開いて
# 僕にも	あると
# 気を	出す
# 何が	あるんだい迷亭の
# 妙ですなと	笑う
# 寒月が	笑う
# うちに	着いている
# 空也餅が	着いている
# 迷亭が	まぜ返す
# いや日は	違うようだ
# 細君が	聞かしてくれろと
# 代りに	聞かしてくれろと
# 摂津大掾を	聞かしてくれろと
# 語り物は	聞いたら
# 何だと	聞いたら
# 細君が	参考して
# 新聞を	参考して
# 参考して	云うのさ
# 鰻谷だと	云うのさ
# 嫌いだから	した
# 今日は	よそうと
# その日は	した
# やめに	した
# 翌日に	なると
# 細君が	云う
# 新聞を	持って来て
# 堀川は	引き下がった
# 細君は	引き下がった
# 顔を	して
# 翌日に	なると
# 細君が	云うには
# 三十三間堂です	聞きたい
# 私は	聞きたい
# 三十三間堂が	聞きたい
# あなたは	知らないが
# 三十三間堂も	知らないが
# 御嫌いか	知らないが
# 私に	聞かせるのだから
# 聞かせるのだから	いでしょうと
# いっしょに	行って
# 談判を	する
# 御前が	行きたいなら
# 一世一代と	云うので
# 大入だから	行ったって
# 突懸けに	行ったって
# 場所へ	行くには
# 茶屋と	云う
# ものが	在って
# それと	交渉して
# 交渉して	予約するのが
# 席を	予約するのが
# 手続きだから	云うと
# それを	踏まないで
# 常規を	脱した
# 事を	するのは
# 残念だが	云うと
# 今日は	やめようと
# 細君は	して
# 眼付を	して
# 女ですから	知りませんが
# 手続きなんか	知りませんが
# 君代さんも	聞いて来たんですから
# 手続きを	踏まないで
# 立派に	聞いて来たんですから
# 聞いて来たんですから	出す
# あなたが	すみましょう
# 教師だからって	しないでも
# 手数の	かかる
# 見物を	しないでも
# あなたは	出す
# 声を	出す
# 駄目でも	行く
# 事に	しよう
# 晩飯を	くって
# 電車で	行こうと
# 降参を	すると
# 四時までに	着くようにしなくっちゃ
# 向うへ	着くようにしなくっちゃ
# 着くようにしなくっちゃ	いけません
# 四時までに	行かなくては
# 駄目なんだと	聞き返すと
# 場所を	とらなくちゃ
# 君代さんから	教えられた
# 通りを	述べる
# それじゃ	過ぎれば
# 四時を	過ぎれば
# 駄目なんだねと	見たら
# 念を	押して
# 駄目ですともと	答える
# 時から	し
# 急に	し
# 悪寒が	し
# 奥さんがですかと	聞く
# 寒月が	聞く
# なに細君は	いらあね
# 穴の	明いた
# 風船玉のように	萎縮する
# 一度に	萎縮する
# 感じが	起ると
# 眼が	ぐらぐらして
# 迷亭が	加える
# 註釈を	加える
# 事に	なった
# 願だから	叶えてやりたい
# 平生	叱りつけたり
# 口を	聞かなかったり
# 苦労を	させたり
# 世話を	させたりするばかりで
# 労に	酬いた
# 今日は	ある
# 時間も	ある
# 嚢中には	ある
# 堵物も	ある
# 細君も	行きたいだろう
# 僕も	連れて行ってやりたい
# 悪寒が	して
# 眼が	くらんでは
# 電車へ	乗るどころか
# 靴脱へ	降りる
# 事も	出来ない
# 気の毒だと	思うと
# 悪寒が	して
# 眼が	くらんでくる
# 医者に	見てもらって
# 服薬でもしたら	全快するだろうと
# 四時前には	全快するだろうと
# 全快するだろうと	帰らない
# 細君と	して
# 相談を	して
# 甘木医学士を	やると
# 迎いに	やると
# 昨夜が	帰らない
# 当番で	帰らない
# 大学から	帰らない
# 二時頃には	なりますから
# 御帰りに	なりますから
# 帰り次第	上げますと
# 今杏仁水でも	飲めば
# 四時前には	いるんだが
# 癒るに	いるんだが
# 極って	いるんだが
# 何事も	思うように
# 思うように	行かん
# もので	外れそうになって来る
# 妻君の	喜ぶ
# 笑顔を	見て
# 予算も	外れそうになって来る
# 細君は	いらっしゃれませんかと
# 顔付を	して
# 四時までには	見せるから
# 顔でも	洗って
# 着物でも	着換えて
# 悪寒は	劇しくなる
# 劇しくなる	ぐらぐらする
# 眼は	ぐらぐらする
# 四時までに	全快して
# 全快して	履行する
# 約束を	履行する
# 事が	出来なかったら
# 事だから	するかも知れない
# 何を	するかも知れない
# 仕儀に	なって来た
# 事を	考えると
# 内に	説き聞かして
# 道を	説き聞かして
# 変が	起った
# 時	取り乱さない
# 覚悟を	させるのも
# 義務ではあるまいかと	考え出した
# 僕は	呼んだよ
# 細君を	呼んだよ
# 書斎へ	呼んだよ
# manyasliptwixtthe cupandthelipと	云う
# 諺くらいは	心得ているだろうと
# 横文字なんか	知るもんですか
# 誰が	知るもんですか
# 知るもんですか	からかうのだから
# あなたは	からかうのだから
# 人が	知らないのを
# 英語を	知らないのを
# 知らないのを	からかうのだから
# 癖に	使って
# 英語を	使って
# 人に	からかうのだから
# からかうのだから	なさらなかったんです
# 英語なんかは	出来ないんですから
# 出来ないんですから	なさらなかったんです
# 御好きなら	なさらなかったんです
# 卒業生かなんかを	なさらなかったんです
# お貰い	なさらなかったんです
# あなたくらい	ありはしないと
# 人は	ありはしないと
# 権幕なんで	折られてしまった
# 僕も	折られてしまった
# 腰を	折られてしまった
# 君等にも	弁解するが
# 悪意で	使った
# 全く妻を	愛する
# 至情から	出たので
# 妻のように	解釈されては
# 眩暈で	乱れていた
# 脳が	乱れていた
# ところへ	もって来て
# 理を	呑み込ませようと
# 英語を	知らないと
# 事を	忘れて
# 気も	付かずに
# 失敗で	強くなる
# 悪寒は	強くなる
# 眼は	ぐらぐらする
# 妻君は	換える
# 通り風呂場へ	行って
# 両肌を	脱いで
# 御化粧を	して
# 箪笥から	換える
# 着物を	換える
# 出して着	換える
# いつでも	出掛けられますと
# 風情で	待ち構えている
# 甘木君が	来てくれれば
# 善いがと	思って
# 時計を	見ると
# 妻君が	出す
# 開き戸を	出す
# 顔を	出す
# 妻を	褒めるのは
# もろ肌を	脱いで
# 石鹸で	磨き上げた
# 皮膚が	ついて
# 羽織と	反映している
# 顔が	聞こうと
# 摂津大掾を	聞こうと
# 二つで	見える
# 両方面から	輝やいて
# 輝やいて	見える
# 希望を	満足させて
# 満足させて	出掛けてやろうと
# 気に	なる
# それじゃ	奮発して行こうかなと
# 奮発して行こうかなと	来た
# 一ぷくふかしているとようやく甘木先生が	来た
# 注文通りに	行った
# 容体を	はなすと
# 甘木先生は	考え込んでいる
# 舌を	眺めて
# 手を	握って
# 胸を	敲いて
# 背を	撫でて
# 目縁を	引っ繰り返して
# 頭蓋骨を	さすって
# 気が	しましてと
# 僕が	云うと
# 先生は	落ちついて
# 外出致しても	ございますまいねと
# 差支えは	ございますまいねと
# 細君が	聞く
# 先生は	考え込む
# 僕が	いう
# 水薬を	上げますから
# 危ないようになりそうですな	なるといけませんよと
# 決して御心配に	なる
# 事じゃございません	なるといけませんよと
# 神経を	なるといけませんよと
# 御起しに	なるといけませんよと
# 先生が	帰る
# 三時は	過ぎた
# 三十分	過ぎた
# 下女を	やる
# 薬取りに	やる
# 厳命で	行って
# 馳け出して	行って
# 馳け出して	返ってくる
# 四時には	ある
# 十五分	ある
# 急に	来た
# 嘔気を	来た
# 催	来た
# 細君は	出てくる
# 水薬を	注いで
# 茶碗へ	注いで
# 前へ	置いてくれたから
# 茶碗を	取り上げて
# 中から	吶喊して
# 者が	吶喊して
# 吶喊して	出てくる
# 茶碗を	置く
# 下へ	置く
# 茶碗を	つけると
# 唇へ	つけると
# ゲーが	する
# 妨害を	する
# 茶碗を	置き
# 茶碗を	置いていると
# 柱時計が	打った
# 四時を	打った
# 四時だ	取り上げると
# はおられんと	取り上げると
# 茶碗を	取り上げると
# 不思議とは	飲めたよ
# 事だろう	飲めたよ
# 音と共に	留まって
# 吐き気が	留まって
# 水薬が	飲めたよ
# 苦なしに	飲めたよ
# 十分頃に	なると
# 事も	始めて
# 事が	出来たんだが
# 背中が	ぞくぞくするのも
# ぞくぞくするのも	ぐらぐらするのも
# 眼が	ぐらぐらするのも
# ぐらぐらするのも	消えて
# 夢のように	消えて
# 当分	立つ
# 事も	出来まいと
# 病気が	全快したのは
# それから	行ったの
# 歌舞伎座へ	行ったの
# いっしょに	行ったの
# かいと	得んと
# 迷亭が	得んと
# 要領を	得んと
# 顔付を	して
# 四時を	過ぎちゃ
# 意見なんだから	したさ
# 仕方がない	したさ
# やめに	したさ
# 十五分ばかり	来てくれたら
# 甘木先生が	来てくれたら
# 義理も	立つし
# 妻も	満足した
# ろうに	した
# 十五分の差でね	した
# 事を	した
# ところだったと	思うのさ
# 今でも	思うのさ
# 主人は	する
# 義務を	すましたような
# 風を	する
# これで	立つと
# 両人に対して	立つと
# 顔が	立つと
# 寒月は	云う
# 例のごとく	欠けた
# 歯を	出して
# 残念でしたなと	云う
# 迷亭は	いう
# 顔を	して
# 夫を	持った
# 独り言のように	いう
# 蔭で	云う
# エヘンと	云う
# 咳払いが	聞える
# 吾輩は	聞いていたが
# 三人の	話しを
# 順番に	聞いていたが
# 時間を	潰す
# ために	強いて
# 口を	運動させて
# 運動させて	嬉しがったりする
# 事を	笑ったり
# 事を	嬉しがったりする
# 者だと	思った
# 我儘で	承知していたが
# 事は	承知していたが
# 前から	承知していたが
# 承知していたが	思われていた
# 言葉数を	使わないので
# 点が	あるように
# あるように	思われていた
# 点に	云う
# 感じも	あったが
# 話を	聞いてから
# 急に	軽蔑したくなった
# 両人の	話しを
# 沈黙して	聞いていられないのだろう
# 気に	なって
# 愚にも	つかぬ
# 駄弁を	弄すれば
# 弄すれば	あるだろう
# 所得が	あるだろう
# エピクテタスに	しろと
# 事を	しろと
# 書いてあるのか	知らん
# 逸民で	ある
# 彼等は	澄し切っているような
# 糸瓜のごとく	澄し切っているような
# 風に吹かれて超然と	澄し切っているような
# 娑婆気も	あり
# 慾気も	ある
# 彼等が	ほのめいて
# 談笑中にも	ほのめいて
# 一歩進めば	罵倒している
# 彼等が	罵倒している
# 俗骨共と	なるのは
# 動物に	なるのは
# 猫より	見て
# 言語動作が	帯びてないのは
# 半可通のごとく	帯びてないのは
# 厭味を	帯びてないのは
# 急に	面白くなくなったので
# 談話が	面白くなくなったので
# 様子でも	見て来ようかと
# 庭口へ	廻る
# 門松注目飾りは	なったが
# すでに	取り払われて
# 正月も	なったが
# 十日と	なったが
# 春日は	呈している
# 雲も	見えぬ
# 空より	照らして
# 四海天下を	照らして
# 一度に	照らして
# 十坪に	足らぬ
# 面も	受けた
# 曙光を	受けた
# 時より	呈している
# 活気を	呈している
# 椽側に	あって
# 座蒲団が	あって
# 一つ	あって
# 人影も	見えず
# 障子も	立て切ってあるのは
# 立て切ってあるのは	知らん
# 御師匠さんは	知らん
# 湯にでも	行ったのか
# 行ったのか	知らん
# 御師匠さんは	構わんが
# 留守でも	構わんが
# 気合も	しないから
# まま	上って
# 椽側へ	上って
# 真中へ	寝
# 転ろんで	見ると
# 事も	忘れて
# うたた寝を	していると
# 急に	する
# うちで	する
# 人声が	する
# 仏師屋へ	参りましたら
# ところだと	申しまして
# どれ	お見せなさい
# 奇麗に	出来た
# これで	浮かばれましょう
# 三毛も	浮かばれましょう
# 金は	剥げる
# ええ念を	押しましたら
# 上等を	使ったから
# これなら	持つと
# 位牌よりも	持つと
# 劃を	申しました
# 御仏壇へ	上げて
# 御線香でも	あげましょう
# 三毛子は	立ち上る
# 変だと	立ち上る
# 上へ	立ち上る
# チーン南無	する
# 声が	する
# 御前も	おやりなさい
# 回向を	して
# チーン南無	する
# 今度は	する
# 声が	する
# 吾輩は	して来た
# 急に	して来た
# 動悸が	して来た
# 上に	立ったまま
# 立ったまま	動かさない
# 猫のように眼も	動かさない
# 事を	致しましたね
# 始めは	引いたんでございましょうがねえ
# 風邪を	引いたんでございましょうがねえ
# 引いたんでございましょうがねえ	よかったかも知れないよ
# 甘木さんが	下さると
# 薬でも	下さると
# 三毛を	馬鹿にし
# 事を	云う
# 三毛子も	貰った
# 甘木先生に	診察して
# 診察して	貰った
# ものと	見える
# 野良猫が	誘い出したからだと
# わたしは	思うよ
# 弁解したかったが	聞いている
# ここが	呑んで
# 唾を	呑んで
# 早死を	するし
# 野良猫は	しているし
# 達者で	しているし
# いたずらを	しているし
# 猫は	はおりませんからね
# 太鼓で	探してある
# 二人と	はおりませんからね
# 二匹と	云う
# 代りに	いった
# 二たりと	いった
# 考えでは	思っているらしい
# 同種族ものと	思っているらしい
# 顔は	類似している
# 吾等猫属と	類似している
# 代りに	参ったんでございますがねえ
# 野良が	死ぬと
# 誂え通りに	参ったんでございますがねえ
# 御誂え通りに	なっては
# 嫌いとも	云え
# 中へ	もぐり込んでいたら
# 下女が	いるのも
# 吾輩が	いるのも
# いるのも	知らんで
# 上から	した
# ...
# みんなが	立ってても
# 平気だったかも	知れませんよと
# 寒月君が	試みた
# 短評を	試みた
# 独仙君は	進行する
# 自覚心が	あるだけ
# 親切を	するにも
# 骨が	折れる
# 訳に	なる
# 文明が	進むに従って
# 気が	なくなる
# 交際が	おだやかになるなどと
# おだやかになるなどと	云うが
# 普通	云うが
# おだやかに	なれる
# 相撲が	組んで
# 真中で	組んで
# 四つに	組んで
# 至極だが	打っているじゃないか
# 腹は	打っているじゃないか
# 波を	打っているじゃないか
# 喧嘩も	圧迫するのだから
# 喧嘩は	圧迫するのだから
# 暴力で	圧迫するのだから
# 巧妙になってるから	増してくるんだねと
# 自覚心が	増してくるんだねと
# 増してくるんだねと	廻って来る
# 番が	廻って来る
# 上に	廻って来る
# 言葉に	従って始めて
# 力に	従って始めて
# 自然に	勝つと
# 喧嘩は	上ってるから
# 格言通りに	出来
# 力を	利用して
# 利用して	考える
# 敵を	考える
# 斃す事を	考える
# 力に	逆らわないで
# これを	変化して
# 電力に	変化して
# 変化して	役に立たせると
# 立派に	役に立たせると
# 寒月君が	言いかけると
# 独仙君が	引き取った
# あとを	引き取った
# 貧時には	縛せられ
# 貧に	縛せられ
# 富時には	縛せられ
# 富に	縛せられ
# 時には	縛せられ
# 憂に	縛せられ
# 喜時には	縛せられるのさ
# 喜に	縛せられるのさ
# 才人は	斃れ
# 才に	斃れ
# 斃れ	敗れ
# 智者は	敗れ
# 智に	敗れ
# 癇癪持ちは	罹る
# 癇癪を	すれば
# 利用さえ	すれば
# ぺてんに	罹る
# ひやひやと	たたくと
# 迷亭君が	たたくと
# 手を	たたくと
# 苦沙弥君は	笑い出した
# これで	行かないのだよと
# 行かないのだよと	答えたら
# 一度に	笑い出した
# 金田のようなのは	斃れるだろう
# 女房は	斃れ
# 鼻で	斃れ
# 主人は	斃れ
# 因業で	斃れ
# 食い倒れもしくは	呑んだくれの
# 卒塔婆小町のように	なるかも知れない
# 行き倒れに	なるかも知れない
# 新体詩を	捧げただけに
# 東風君が	申し立てた
# 異議を	申し立てた
# 応無所住而生其心と	云うのは
# 言葉だ	至らんと
# 境界に	至らんと
# 人間は	ならんと
# 独仙君	悟ったような
# 独り	悟ったような
# 事を	云う
# 君などは	知れないぜ
# 電光影裏に	さか
# 勢で	行った
# 文明が	行った
# 日にや	生きてるのは
# 僕は	生きてるのは
# いやだと	いい出した
# 主人が	いい出した
# 遠慮は	いらないから
# 迷亭が	言下に道破する
# いやだと	張る
# 主人が	張る
# わからん強情を	張る
# 時には	生れる
# 誰も	熟考して
# 熟考して	生れる
# ものは	有りませんが
# 時には	すると
# 誰も	すると
# 苦に	すると
# 寒月君が	のべる
# 格言を	のべる
# 金を	借りる
# ときには	借りるが
# 気なしに	借りるが
# 時には	心配するのと
# みんな	心配するのと
# 事さと	出来るのは
# 時に	出来るのは
# 返事の	出来るのは
# 金を	返す
# 事を	考えない
# 事を	せん
# 苦に	せん
# 君のように	云うと
# 図太いのが	悟ったのだね
# 禅語に	云うのが
# 牛鉄心と	云うのが
# 云うのが	ある
# 標本と	云う
# 死ぬのを	するようになったのは
# 苦に	するようになったのは
# 神経衰弱と	云う
# 病気が	発明されてから
# どこから	見ても
# 独仙が	やっていると
# べつに	やっていると
# 主人は	述べている
# 寒月東風二君を	して
# 相手に	して
# 不平を	述べている
# 金を	返さずに
# 問題は	ありませんよ
# ものは	返さなくちゃなりませんよ
# 議論だから	聞くが
# 金を	返さずに
# 問題であるごとく	済むかが
# 錬金術は	失敗した
# 人間は	分明になった
# 事が	分明になった
# 議論だから	聞いていろ
# 事が	分明になった
# 時に	起る
# 問題が	起る
# 自殺クラブは	有している
# 問題と共に	有している
# 運命を	有している
# 事が	出来なければ
# 死を	する
# 苦に	する
# 厭だから	するのではない
# 苦に	するのではない
# するのではない	死ぬのが
# ものは	殺してくれる
# 智慧が	足りないから
# ままに	放擲しておく
# うちに	殺してくれる
# 世間が	殺してくれる
# いじめ	殺してくれる
# 一と	ある
# 癖	ある
# 世間から	殺されて
# なし崩しに	殺されて
# いじめ	殺されて
# 死に方に	付いて
# 名案を	呈出するに
# 趨勢は	増加して
# 自殺者が	増加して
# 方法を	もって
# この世を	去るに
# 事に	なりますね
# アーサージョーンスと	云う
# 人の	かいた
# なかに	主張する
# 自殺を	主張する
# 哲学者が	あって
# 事に	しないのだがね
# 今から	立てば
# 千年も	立てば
# みんな	実行するに
# 後には	考えられるようになる
# 死と	云えば
# 自殺より	存在しない
# ほかに	存在しない
# もののように	考えられるようになる
# 事に	なりますね
# 自殺も	積んで
# 大分研究が	積んで
# 科学に	なって
# 中学校で	授けるようになる
# 代りに	授けるようになる
# 自殺学を	授けるようになる
# 正科として	授けるようになる
# 妙ですな	出たいくらいの
# 傍聴に	出たいくらいの
# 迷亭先生御聞きに	なりましたか
# 時分に	なると
# 先生は	云うね
# 諸君公徳などと	云う
# 遺風を	墨守してはなりません
# 青年として	注意すべき
# 諸君が	注意すべき
# 第一に	注意すべき
# 好むところはこれを人に	こして
# 施	こして
# 自殺を	展開して
# 一歩	展開して
# 展開して	しても
# 他殺に	しても
# ものは	ござるのが
# 大分苦痛のように	見受けら
# 昔と	違って
# 今日は	してはなりません
# 時節であるから	してはなりません
# 類を	用いるような
# 振舞を	してはなりません
# 技術によって	なるのであります
# からかい殺すのが	功徳にもなりまた
# ため	功徳にもなりまた
# 功徳にもなりまた	なるのであります
# 名誉にも	なるのであります
# 講義を	しますね
# 事が	あるよ
# 現代では	している
# 警察が	保護するのを
# 生命財産を	保護するのを
# 保護するのを	している
# 目的と	している
# 時分に	なると
# 棍棒を	もって
# 公民を	撲殺して
# 撲殺して	あるく
# 大事だから	保護するんだが
# 警察で	保護するんだが
# 国民は	生きてるのが
# 苦痛だから	打ち殺してくれるのさ
# 巡査が	打ち殺してくれるのさ
# ために	打ち殺してくれるのさ
# 気の	利いた
# ものは	大概自殺してしまうから
# 大概自殺してしまうから	限るのさ
# 巡査に	打殺されるような
# 奴は	限るのさ
# 意気地なしか	限るのさ
# 不具者に	限るのさ
# 人間は	しておくのだね
# 門口へ	しておくのだね
# 張札を	しておくのだね
# なにただ	くれるのさ
# 男ありとか	女ありとか
# 女ありとか	巡ってきて
# 巡査が	巡ってきて
# 時に	巡ってきて
# 志望通り	くれるのさ
# 取計って	くれるのさ
# 死骸は	あるくのさ
# 巡査が	引いて
# 車を	引いて
# 事が	出来てくる
# 冗談は	ありませんねと
# 際限が	ありませんねと
# 東風君は	感心している
# 大に	感心している
# 独仙君は	弁じ出した
# 通り山羊髯を	しながら
# 気に	しながら
# 冗談と	云えば
# 冗談だが	予言かも知れない
# 予言と	云えば
# 真理に	徹底しない
# 現象世界に	束縛せられて
# 束縛せられて	認定したがる
# 夢幻を	認定したがる
# 事実と	認定したがる
# ものだから	してしまう
# 事を	云うと
# 冗談に	してしまう
# 燕雀焉んぞ	知らんやですねと
# 志を	知らんやですねと
# 寒月君が	恐れ入ると
# 独仙君は	進める
# 顔付で	進める
# 話を	進める
# 昔し	云う
# スペインに	云う
# コルドヴァと	云う
# 所が	あった
# 今でも	ありゃしないか
# 問題は	やる
# 風習として	鳴ると
# 鐘が	鳴ると
# お寺で	鳴ると
# 女が	出て来て
# 河へ	這入って
# 水泳を	やる
# 冬も	やるんですか
# その辺は	知らんが
# 別なく	飛び込む
# 河へ	飛び込む
# 遠くから	見ている
# 遠くから	見ていると
# 上に	動いている
# 肌が	動いている
# 模糊として	動いている
# 新体詩に	なりますね
# 所ですかと	乗り出してくる
# 東風君は	乗り出してくる
# 裸体が	出さえすれば
# 前へ	乗り出してくる
# ものが	出来ず
# いっしょに	泳ぐ
# 事も	出来ず
# 遠くから	見る
# 姿を	見る
# 事も	許されないのを
# 許されないのを	思って
# 残念に	思って
# いたずらを	した
# 趣向だいと	聞いた
# いたずらと	聞いた
# 迷亭君は	嬉しがる
# 大に	嬉しがる
# 鐘つき番に	使って
# 賄賂を	使って
# 日没を	撞く
# 合図に	撞く
# 鐘を	鳴らした
# 一時間前に	鳴らした
# ものだから	飛び込んだ
# そら鐘が	鳴ったと
# めいめい河岸へ	あつまって
# 服装で	飛び込んだ
# 中へ	飛び込んだ
# 飛び込みは	した
# 日が	暮れない
# 秋の日が	しやしないか
# 上を	見ると
# 男が	眺めている
# 大勢	立って
# 事も	出来ない
# 大に	赤面した
# 人間は	迷わされて
# 習慣に	迷わされて
# 原理を	忘れる
# 気を	つけないと
# 駄目だと	云う
# 習慣に	迷わされの
# この間	ある
# 雑誌を	よんだら
# 小説が	あった
# 僕が	開くと
# ここで	開くと
# 書画骨董店を	開くと
# 店頭に	並べておく
# 道具類を	並べておく
# 贋物じゃない	並べておく
# 上等品ばかり	並べておく
# 上等品だから	きまってる
# みんな	きまってる
# 高価に	きまってる
# そこへ	来て
# 御客さんが	来て
# いくらだねと	聞く
# 六百円と	云うと
# 僕が	云うと
# 手元に	持ち
# 残念だが	見合せよう
# 主人は	云う
# 事を	云う
# 僕が	構いませんから
# なに代は	構いませんから
# お気に	入ったら
# 客は	行かないからと
# それじゃ	いただきましょう
# 月賦で	いただきましょう
# 御贔屓に	なるんですからいえ
# なるんですからいえ	及びません
# 御遠慮には	及びません
# 月に	構いませんと
# 五円でも	構いませんと
# 僕が	云うんだ
# きさくに	云うんだ
# 間に	あって
# 問答が	あって
# 僕が	売渡す
# 幅を	売渡す
# 六百円ただし	売渡す
# 事で	売渡す
# 百科全書	見たようですね
# 詐偽に	取りかかるのだぜ
# 六百円なら	なると
# 何年で	なると
# 皆済に	なると
# かいと	思うか
# 短かくも	あり
# 間	払うのだから
# 十円ずつ	払うのだから
# 払うのだから	払えばいいのだ
# 先方では	払えばいいのだ
# 六十回	払えばいいのだ
# そこが	なる
# ところで	なる
# 六十回も	繰り返していると
# 事を	繰り返していると
# 毎月	繰り返していると
# 六十一回にも	なる
# 十円	払う
# 気に	なる
# 六十二回にも	払う
# 十円	払う
# 気に	なる
# 六十三回	払わなくては
# 回を	重ねるに
# 期日が	くれば
# 十円	払わなくては
# 気が	済まないようになる
# 利口のようだが	ある
# 習慣に	迷って
# 根本を	忘れると
# 大弱点が	ある
# 弱点に	乗じて
# 僕が	するのさ
# 十円ずつ	するのさ
# 毎月得を	するのさ
# 寒月君が	笑うと
# 事は	あるよ
# 僕は	あると
# 貸費を	勘定せずに
# 毎月	勘定せずに
# 勘定せずに	返して
# 向から	断わられた
# 事が	あると
# 恥を	公言した
# 恥のように	公言した
# 人が	いるから
# ここに	いるから
# 先刻	述べた
# 未来記を	聞いて
# 冗談だなどと	笑う
# 六十回で	考える
# 月賦を	払って
# 生涯	払って
# 正当だと	考える
# 青年諸君は	だまされないようにしなくっちゃいけない
# 僕らの	云う
# 事を	聞いて
# 月賦は	致します
# 事に	致します
# 参考に	なる
# 寒月君と	向いだした
# 独仙君は	向いだした
# 寒月君に	向いだした
# 迷亭君が	結婚したのが
# 君が	結婚したのが
# 無断で	結婚したのが
# 穏当でないから	謝罪しろと
# 金田とか	云う
# 人に	謝罪しろと
# 謝罪しろと	忠告したら
# 謝罪は	あずかりたいですね
# 御容赦に	あずかりたいですね
# 向うが	あやまるなら
# 警察が	あやまれと
# 君に	あやまれと
# 御免	蒙ります
# 御免	蒙ります
# それ	見たまえ
# 今とは	変ってる
# 人間が	変ってる
# 御威光なら	出来た
# 何でも	出来た
# 御威光でも	出来ない
# ものが	出来てくる
# 閣下でも	出来ない
# ある程度以上に	のしかかる
# 上に	のしかかる
# 事が	出来ない
# 先方に	あれば
# 権力が	あれば
# 不愉快を	感じて
# 世は	しと
# 昔	しと
# 御威光だから	出来ないのだと
# 出来ないのだと	云う
# 新現象の	あらわれる
# 時代です	考えると
# ものから	考えると
# 事柄が	通る
# 変遷と	云う
# もので	過ぎないのだが
# 未来記も	過ぎないのだが
# 冗談だと	云えば
# 冗談に	過ぎないのだが
# 過ぎないのだが	あるじゃないですか
# 消息を	説明した
# ものと	すれば
# 味が	あるじゃないですか
# 知己が	出てくると
# 続きが	述べたくなるね
# 御説のごとく	きたり
# 世に	きたり
# 御威光を	きたり
# 笠に	きたり
# 二三百本を	して
# 恃に	して
# 無理を	押し通そうとするのは
# カゴへ	乗って
# 何でも	競争しようと
# 蚊でも	競争しようと
# 汽車と	競争しようと
# 競争しようと	あせる
# 頑物まあ	わからずやの
# ものだから	拝見していればいいが
# 御手際を	拝見していればいいが
# 目下	達観して
# 傾向を	達観して
# 達観して	卜すると
# 趨勢を	卜すると
# 卜すると	なる
# 結婚が	なる
# 事に	なる
# 驚ろくな	かれ
# 前	申す
# 一家を	代表し
# 主人が	代表し
# 代表し	代表し
# 一郡を	代表し
# 代官が	代表し
# 代表し	代表した
# 一国を	代表した
# 領主が	代表した
# それが	変ると
# 生存者が	主張し出して
# 個性を	主張し出して
# 主張し出して	するようになる
# だれを	見ても
# 君	するようになる
# 僕は	するようになる
# 僕だよと	云わぬばかりの
# 風を	するようになる
# 人が	逢えばうぬが
# 途中で	逢えばうぬが
# 人間なら	行き違う
# おれも	行き違う
# 人間だぞと	買いながら
# 中で	買いながら
# 喧嘩を	買いながら
# 個人が	強くなった
# 個人が	強くなったから
# 平等に	強くなったから
# 個人が	弱くなった
# 平等に	弱くなった
# 訳に	なる
# 人が	害する
# おのれを	害する
# 事が	出来にくくなった
# 点において	強くなったのだが
# 自分は	強くなったのだが
# 強くなったのだが	弱くなったんだろう
# 滅多に	手出しがならなくなった
# 身の上に	手出しがならなくなった
# 点においては	弱くなったんだろう
# 明かに	弱くなったんだろう
# 昔より	弱くなったんだろう
# 人から	犯されまいと
# 一毫も	犯されまいと
# 点を	固守すると同時に
# 固守すると同時に	拡げたくなる
# 半毛でも	侵して
# 人を	侵して
# ところは	拡げたくなる
# 無理にも	拡げたくなる
# 間に	なくなって
# 空間が	なくなって
# 生きてるのが	窮屈になる
# 自分を	張りつめて
# 方法で	求める
# 間に	求める
# 余裕を	求める
# かくのごとく	苦しんで
# 人間が	苦しんで
# 自業自得で	苦しんで
# 苦し紛れに	案出した
# 方案は	制さ
# 親子別居の	制さ
# 日本でも	見給え
# 中へ	這入って
# 一家一門ことごとく	ごろごろしている
# うちに	ごろごろしている
# 主張しないから	済むのだが
# あれで	済むのだが
# 済むのだが	別居しなければならない
# 民は	なるから
# 間でも	張らなければ
# お互に	張れるだけ
# 我儘を	張れるだけ
# 損に	なるから
# 安全を	保持する
# ためには	別居しなければならない
# 欧洲は	行われている
# 文明が	進んでいるから
# 制度が	行われている
# ものが	あっても
# 息子が	つく
# おやじから	つく
# 利息の	つく
# 金を	借りたり
# 他人のように	払ったりする
# 下宿料を	払ったりする
# 親が	認めて
# 個性を	認めて
# これに	払えばこそ
# 尊敬を	払えばこそ
# 美風が	成立するのだ
# 風は	是非輸入しなければならん
# 早晩	是非輸入しなければならん
# 日本へも	是非輸入しなければならん
# 親類は	離れ
# 親子は	我慢しているような
# 今日に	離れて
# 発展と	のびて行くから
# 発展に	つれて
# 尊敬の念は	のびて行くから
# 無制限に	のびて行くから
# 楽が	出来ない
# 訳だから	なる
# 方案として	分れる
# 夫婦が	分れる
# 事に	なる
# 考では	いるから
# いっしょに	いるから
# 夫婦だと	思ってる
# それが	了見違いさ
# 充分なるだけ	合わなければならないだろう
# 個性が	合わなければならないだろう
# 異体同心とか	云って
# 目には	見えるが
# 二人に	見えるが
# それだから	号して
# 偕老同穴とか	号して
# 号して	化ける
# 狸に	化ける
# 今は	行かないやね
# 妻が	穿いて
# 女学校で	穿いて
# 行灯袴を	穿いて
# 個性を	鍛え上げて
# 束髪姿で	乗り込んでくるんだから
# 夫の	思う
# 通りに	なる
# 思い通りに	なるような
# 賢夫人に	なれば
# 個性は	発達する
# 夫と	合わなくなる
# 勢夫と	衝突する
# 名が	つく
# 以上は	衝突している
# 晩まで	衝突している
# 夫と	衝突している
# 事だが	増してくる
# 賢妻を	迎えれば
# 程度が	増してくる
# 水と油のように	あって
# 間には	あって
# きりが	あって
# それも	落ちついて
# しきりが	保っていれば
# 水平線を	保っていれば
# 水と油が	きかけるのだから
# 双方から	きかけるのだから
# 働ら	きかけるのだから
# きかけるのだから	上がったり下がったりする
# なかは	上がったり下がったりする
# 大地震のように	上がったり下がったりする
# ここにおいて	分ってくる
# 夫婦雑居は	分ってくる
# 損だと	云う
# 事が	分ってくる
# 人間に	分ってくる
# 夫婦が	わかれるんですか
# 心配だなと	云った
# 寒月君が	云った
# 夫婦は	みんな分れる
# 今までは	いたのが
# いっしょに	いたのが
# 夫婦であったが	目されてくる
# ものは	目されてくる
# ないように	目されてくる
# 世間から	目されてくる
# 組へ	編入される
# 訳ですねと	云った
# 寒月君は	云った
# ところで	云った
# のろけを	云った
# 御代に	生れて
# 僕などは	いるんだよ
# 未来記を	作るだけ
# 頭脳が	出ているから
# 時勢より	出ているから
# 一二歩ずつ	出ているから
# 前へ	出ているから
# 今から	いるんだよ
# 独身で	いるんだよ
# 人は	騒ぐが
# 結果だなどと	騒ぐが
# 近眼者の	視る
# 続きを	話すと
# 時	唱道する
# 哲学者が	唱道する
# 天降って	唱道する
# 真理を	唱道する
# 個性を	滅すれば
# 人間を	滅すると
# 同結果に	陥る
# 意義を	しめん
# 完から	しめん
# ためには	構わないから
# 価を	払うとも
# 個性を	発達せしめなければならん
# 保持すると同時に	発達せしめなければならん
# 陋習に	縛せられて
# いやいやながら	執行するのは
# 結婚を	執行するのは
# 傾向に	反した
# 個性の	発達せざる
# 時代は	知らず
# 文明の	顧みないのは
# 今日	陥って
# 弊竇に	陥って
# 高潮度に	達せる
# 今代において	連結され得べき
# 個性が	連結され得べき
# 普通以上に	もって
# 程度を	もって
# 青年男女が	駆られて
# 劣情に	駆られて
# 吾人は	抵抗せざるべからず
# ため	抵抗せざるべからず
# ため	抵抗せざるべからず
# ため	抵抗せざるべからず
# 全力を	挙げ
# 蛮風に	抵抗せざるべからず
# 反対ですと	叩いた
# 東風君は	叩いた
# 時	思い切った
# 調子で	叩いた
# 平手で	叩いた
# 膝頭を	叩いた
# 吾を	慰藉し
# 慰藉し	完全にし
# 吾を	完全にし
# 完全にし	幸福にするのは
# 吾を	幸福にするのは
# 情操を	優美にし
# 優美にし	高潔にし
# 品性を	高潔にし
# 高潔にし	洗錬するのは
# 同情を	洗錬するのは
# 吾人は	出来ないです
# いつの	世いずくに
# 世いずくに	生れても
# ものを	忘れる
# ことが	出来ないです
# 者が	あらわれると
# 現実世界に	あらわれると
# 愛は	なります
# 夫婦と	云う
# 関係に	なります
# 美は	分れます
# 形式に	分れます
# 表面に	存在する
# 芸術は	滅する
# 結構だが	あきらめるさ
# 今哲学者が	云った
# 通り	ちゃんと滅してしまうから
# ちゃんと滅してしまうから	あきらめるさ
# 仕方がないと	あきらめるさ
# 芸術だって	帰着するのさ
# 運命に	帰着するのさ
# 自由と	云う
# 自由と	云う
# 人と	云う
# 芸術なんか	存在出来る
# 芸術が	繁昌するのは
# 繁昌するのは	あるからだろう
# 間に	あるからだろう
# 一致が	あるからだろう
# 君の詩を	読んで
# 君より	なくなる
# ほかに	なくなる
# 読み手は	なくなる
# 鴛鴦歌を	作ったって
# いく篇	作ったって
# 今日に	生れたから
# 天下が	愛読するのだろうが
# 人文の	発達した
# 一大哲学者が	主張する
# 出て非結婚論を	主張する
# 時分には	なくなるぜ
# 誰も	なくなるぜ
# よみ手は	なくなるぜ
# 人々個々おのおの	もってるから
# 個性を	もってるから
# 人の	作った
# 今でも	あらわれている
# 英国などでは	あらわれている
# 傾向が	あらわれている
# 小説家中で	あらわれた
# 作品に	あらわれた
# メレジスを	見給え
# ジェームスを	見給え
# 個性の	ある
# 傾向が	発達して
# 発達して	不道徳になる
# 婚姻が	不道徳になる
# 君の	かいた
# ものは	わからなくなる
# 僕に	わからなくなる
# 僕の	かいた
# 君に	わからなくなった
# そりゃそうですけれども	思われないんです
# 私は	思われないんです
# 直覚的に	思われないんです
# 君が	思われなければ
# 直覚的に	思われなければ
# 僕は	思うまでさ
# 曲覚的に	思うまでさ
# 曲覚的かも知れないがと	出す
# 今度は	出す
# 独仙君が	出す
# 口を	出す
# 人間に	許せば
# 自由を	許せば
# ニーチェが	担ぎ出すのも
# 超人なんか	担ぎ出すのも
# 担ぎ出すのも	変形した
# やりどころが	なくなって
# 仕方なしに	変形した
# 哲学に	変形した
# あれが	見えるが
# 理想のように	見えるが
# 個性の	発展した
# 十九世紀に	すくんで
# 人には	打てないから
# 滅多に	打てないから
# 寝返りも	打てないから
# 大将少し	なって
# やけに	なって
# 乱暴を	かき散らしたのだね
# あれを	読むと
# 壮快と	云うより
# それも	あつまるのだから
# そのはずさ昔は	あつまるのだから
# 人が	あれば
# 天下翕然として	あつまるのだから
# 旗下に	あつまるのだから
# 愉快が	出てくれば
# 事実に	出てくれば
# 何も	見たように
# ニーチェ	見たように
# 見たように	あらわす
# 力で	あらわす
# これを	あらわす
# 上に	あらわす
# チェヴィ・チェーズでも	写しても
# 性格を	写しても
# 感じが	違うからね
# 愉快に	かいてある
# 事実が	あって
# 事実を	かえたのだから
# 紙に	かえたのだから
# 写し	かえたのだから
# 時代は	行かないよ
# 英雄なんか	出やしない
# 一人も	出やしない
# 一人だったから	利かしたのだが
# 孔子も	利かしたのだが
# 幅を	利かしたのだが
# 利かしたのだが	いる
# 今は	いる
# 孔子が	いる
# 天下が	孔子かも知れない
# おれは	利かない
# 孔子だよと	威張っても
# 圧が	利かない
# 不平だから	振り廻すのさ
# 超人などを	振り廻すのさ
# 上だけで	振り廻すのさ
# 吾人は	得た
# 自由を	欲して
# 欲して	得た
# 自由を	得た
# 自由を	得た
# 結果	感じて
# 不自由を	感じて
# これに	反して
# 東洋じゃ	昔しから
# 昔しから	した
# 修行を	した
# 結果	起して
# みんな	起して
# 神経衰弱を	起して
# 始末が	つかなくなった
# 時	発見するから
# 民蕩々たりと	云う
# 価値を	始めて
# 無為にして	化すと
# 馬鹿に	出来ない
# 事を	悟るから
# アルコール中毒に	罹って
# 酒を	飲まなければ
# ものでしょうと	云う
# 寒月君が	云う
# そりゃ妻君を	持ち立てだからさと
# 迷亭君が	解釈した
# 主人が	云い出した
# 事を	云い出した
# 妻を	持って
# ものだなどと	思うと
# 間違に	なる
# ためだから	聞かせる
# 物を	読んで
# 最前書斎から	持って来た
# 本を	取り上げて
# 本だが	分ってると
# 時代から	分ってると
# 事は	分ってると
# 本ですかと	聞く
# タマス・ナッシと	云って
# 時分	云った
# 悪口を	云った
# ものが	あるんですか
# 悪口が	あるが
# 内には	這入る訳だから
# 妻も	這入る訳だから
# 這入る訳だから	聞くがいい
# 事に	なりましたね
# 賢哲が	紹介すべしと
# 女性観を	紹介すべしと
# 紹介すべしと	書いてある
# みんな	聞いてるよ
# 僕まで	聞いてるよ
# アリストートル曰く女は	とるべし
# 碌でなしなれば	とるべし
# 嫁を	とるなら
# 嫁より	とるべし
# 嫁を	とるべし
# 碌で	なしより
# 碌で	なしの
# 碌で	なしの
# さああとを	読んだ
# 賢者	答えて
# 名前は	書いてない
# 次には	出ている
# ダイオジニスが	出ている
# 妻を	娶る
# 時において	すべきか
# ダイオジニス	答えて
# 中で	考えたね
# ピサゴラス曰く天下に	あり
# もの	あり
# 事を	云う
# 僕に	云わせると
# 天下に	恐るべき
# 火に	入って
# 水に	入って
# 女に	逢って
# 迷亭先生が	出る
# 援兵に	出る
# 主人は	読む
# あとを	読む
# 婦女子を	御するは
# デモスセニス曰く人も	せば
# 敵を	苦しめんと
# 女を	与うるより
# 敵に	与うるより
# 得たるは	あらず
# 風波に	困憊起つ
# 彼を	困憊起つ
# むるを	得れば
# セネカは	し
# 婦女と	無学をもって
# 無学をもって	し
# 二大厄と	し
# マーカス・オーレリアスは	似たりと
# 女子は	似たりと
# 点において	似たりと
# 船舶に	似たりと
# 女子が	飾るの
# 綺羅を	飾るの
# 性癖を	もって
# 陋策に	もとづく
# ヴァレリアスかつ	おくって
# て書を	おくって
# 友某に	おくって
# 曰く天下に	ものあらず
# 何事も	ものあらず
# 女子の	忍んで
# 皇天憐を	垂れて
# 君を	して
# 術中に	陥らし
# 敵に	あらずや
# 苦しみに	あらずや
# 害に	あらずや
# 誘惑に	あらずや
# 蜜に	似たる
# 毒に	あらずや
# 不徳ならば	云わざるべからず
# 彼等を	棄てざるは
# 呵責と	云わざるべからず
# わる口を	拝聴すれば
# 四五ページ	あるから
# ついでに	聞いたら
# 迷亭先生が	からかい掛けると
# 清やと	呼ぶ
# 細君が	呼ぶ
# 下女を	呼ぶ
# 声が	する
# ウフフフフと	云った
# 主人は	云った
# ものかと	云った
# 今のを	聞いたんですか
# 今の	はね
# 説ですから	御安心なさい
# 妻君は	した
# 遠くで	した
# 返事を	した
# 寒月君は	笑った
# 私も	存じませんで
# アハハハハと	笑ってると
# 迷亭君は	笑ってると
# 門口を	あけて
# 御免とも	云わず
# 足音が	したと
# 唐紙が	あらわれた
# 乱暴に	あらわれた
# 顔が	あらわれた
# その間から	あらわれた
# 今日は	似ず
# いつに	似ず
# シャツに	着て
# フロックを	着て
# 幾分か	狂わせてる
# 相場を	狂わせてる
# 上へ	置くと同時に
# 手へ	下げた
# 重そうに	下げた
# 麦酒を	置くと同時に
# 傍へ	置くと同時に
# 挨拶も	せず
# 腰を	下ろしてかつ
# 膝を	崩したのは
# 品川から	雇うて
# 舟を	雇うて
# 一艘	雇うて
# 私は	行きました
# 日曜に	行きました
# 何か	釣れたかい
# 何も	釣れません
# 浩然の気を	養うたい
# 釣に	行った
# 事が	ありますか
# 上を	あるくのですからねと
# 小舟で	あるくのですからねと
# 乗り廻わして	あるくのですからねと
# あるくのですからねと	容赦なく話しかける
# 誰彼の	容赦なく話しかける
# 僕は	なる
# 上を	乗り廻してある
# 大船で	乗り廻してある
# きた	いんだと
# 迷亭君が	なる
# 相手に	なる
# 人魚でも	釣らなくっちゃ
# 寒月君が	答えた
# ものが	釣れますか
# ビジネスマンに	なると
# 先生私は	富んで来ました
# 近来	富んで来ました
# 常識に	富んで来ました
# 所に	いると
# 傍だから	なってしまうです
# 敷島を	ふかしていては
# 利かんですと	云いながら
# 吸口に	ついた
# 金箔の	ついた
# 埃及煙草を	出して
# 贅沢を	する
# 金が	あるのかい
# 金は	どうかなるたい
# なかばってんが	どうかなるたい
# 煙草を	吸ってると
# 大変信用が	違います
# 寒月君が	いい
# 珠を	磨くよりも
# 信用で	いい
# 手数が	かからない
# 迷亭が	いうと
# 寒月に	いうと
# 寒月が	答えない
# あなたが	ならん
# 博士に	ならん
# ものだから	しました
# 私が	貰う
# 事に	しました
# 御気の毒と	思うたですたい
# 先方で	是非貰うてくれ
# 是非貰うてくれ	貰うてくれと
# 事に	極めました
# 寒月君が	云うと
# 返事を	する
# 娘を	持っても
# だれか	貰うと
# さっき	云った
# 僕が	云った
# 通り	出来たじゃないか
# 御聟さんが	出来たじゃないか
# 種が	出来た
# 迷亭君が	調子づくと
# 例のごとく	調子づくと
# 東風君ですか	作ってくれませんか
# 時に	作ってくれませんか
# 何か	作ってくれませんか
# 活版に	して
# 方々へ	くばります
# 太陽へも	出してもらいます
# 何か	作りましょう
# いつでも	いいです
# 今まで	作った
# うちでも	いいです
# とき	呼んで
# シャンパンを	飲ませるです
# 君シャンパンを	飲んだ
# 事が	ありますか
# ときに	呼ぶつもりですが
# 楽隊を	呼ぶつもりですが
# 作を	して
# 譜に	して
# 先生	下さらんか
# 譜に	して
# うちに	出来る
# 音楽の	出来る
# ものは	おらんですか
# シャンパンくらいじゃ	承知しそうもない
# 私の	御馳走するのは
# 安いのじゃないですが	作ってくれませんか
# 一つ譜を	作ってくれませんか
# シャンパンでも	作ります
# なんなら	作ります
# ただは	頼みません
# 御礼は	するです
# 上着の	隠袋の
# なかから	出して
# 写真を	出して
# 上へ	落す
# 半身が	ある
# 全身が	ある
# 立ってるのが	ある
# 坐ってるのが	ある
# 袴を	穿いてるが
# 振袖が	ある
# 高島田が	ある
# 先生候補者が	あるです
# これだけ	あるです
# 東風君に	周旋してもいいです
# うち	周旋してもいいです
# どれか	周旋してもいいです
# 御礼に	周旋してもいいです
# 一枚寒月君につき	付ける
# 是非周旋を	願いましょう
# これでも	いいですかと
# 一枚	つきつける
# どれでも	いいです
# これなら	千円あります
# 持参金が	千円あります
# 娘ですと	弁じ立てる
# 一人で	弁じ立てる
# それを	貰う
# みんな	貰う
# 訳にゃ	いかないでしょうか
# みんなですか	張りたい
# それは	張りたい
# 慾	張りたい
# 主人は	言い放ったので
# 叱りつけるように	言い放ったので
# それじゃ	貰わんですねと
# どれも	貰わんですねと
# 念を	押しながら
# 写真を	収めた
# 一枚に	収めた
# ポッケットへ	収めた
# 前祝に	買うて来ました
# 酒屋で	買うて来ました
# 一つ	飲んで下さい
# 主人は	抜かせる
# 手を	呼んで
# 拍って	呼んで
# 下女を	呼んで
# 栓を	抜かせる
# 五君は	祝した
# コップを	捧げて
# 艶福を	祝した
# ここに	いる
# 諸君を	招待しますが
# 披露会に	招待しますが
# 招待しますが	出てくれるでしょうねと
# みんな	出てくれますか
# いやだと	答える
# 主人は	答える
# 不人情じゃないが	出ないよ
# おれは	出ないよ
# 袴くらい	しますたい
# 人中へも	出るがよ
# 人に	紹介して上げます
# 癒らんでも	差支えない
# そげん頑固張りなさるなら	やむを得ません
# あなたは	来てくれますか
# 僕かね	是非行くよ
# そこいらだろうと	思った
# 仲人が	出来ても
# 二人	出来ても
# 人間として	出席するよ
# わからんですか	困りますな
# 寒月君は	出てくれるでしょうね
# 関係も	あるから
# 事に	します
# 僕の	作った
# 曲を	奏するのを
# 楽隊が	奏するのを
# 奏するのを	きき落すのは
# 前で	朗読したいです
# 新体詩を	朗読したいです
# 私は	生れてから
# 一杯ビールを	飲みますと
# 自分で	買って来た
# ビールを	飲んで
# 一人で	飲んで
# 真赤に	なった
# 短かい秋の日は	消えている
# 死骸が	乱す
# 算を	乱す
# なかを	見れば
# 火は	消えている
# 昔に	消えている
# 連中も	尽きたと
# 興が	尽きたと
# 独仙君が	立ち上がる
# 僕も	帰ると
# 口々に	出る
# 玄関に	出る
# 寄席が	はねた
# あとのように	淋しくなった
# 座敷は	淋しくなった
# 主人は	入る
# 夕飯を	すまして
# 書斎に	入る
# 妻君は	縫う
# 襟を	かき合せて
# 不断着を	縫う
# 小供は	寝る
# 枕を	並べて
# 下女は	行った
# 湯に	行った
# 呑気と	見える
# 人々も	見ると
# 底を	叩いて
# 音が	する
# 悟ったようでも	踏まぬ
# 足は	踏まぬ
# ほかは	踏まぬ
# 絵に	かいた
# 寒月君は	連れて来た
# 珠磨りを	やめて
# お国から	連れて来た
# 奥さんを	連れて来た
# 順当が	続くと
# 東風君も	したら
# 十年	したら
# 新体詩を	捧げる
# 非を	悟るだろう
# 三平君に	至っては
# 水に	住む
# 山に	住む
# 三鞭酒を	御馳走して
# 得意と	思う
# 事が	出来れば
# 藤さんは	転がって行く
# どこまでも	転がって行く
# 泥が	つく
# 泥が	ついても
# ものよりも	利く
# 幅が	利く
# 猫と	生れて
# 世に	住む
# 事	なる
# 二年越しに	なる
# 自分では	思うていたが
# 見識家は	思うていたが
# あるまいと	思うていたが
# 先達てカーテル・ムルと	云う
# 同族が	揚げたので
# 大気を	揚げたので
# 百年前に	死んだのだが
# 好奇心から	なって
# 幽霊に	なって
# 吾輩を	驚かせる
# ために	出張したのだ
# 冥土から	出張したのだ
# 猫は	あるそうだ
# 母と	する
# 対面を	する
# とき	出掛けた
# しるしとして	出掛けた
# 肴を	出掛けた
# 啣えて	出掛けた
# ところ	あるそうだ
# 途中で	し切れなくなって
# 我慢が	し切れなくなって
# 自分で	食ってしまったと
# 不孝ものだけ	あって
# 才気も	負けぬ
# 人間に	負けぬ
# ある時などは	あるそうだ
# 詩を	作って
# 主人を	驚かした
# 事も	あるそうだ
# 豪傑が	出現しているなら
# 一世紀も	出現しているなら
# 前に	出現しているなら
# 出現しているなら	帰臥してもいいはずであった
# 碌で	なしは
# 御暇を	頂戴して
# 頂戴して	帰臥してもいいはずであった
# 無何有郷に	帰臥してもいいはずであった
# 主人は	死ぬ
# 早晩	死ぬ
# 胃病で	死ぬ
# じいさんは	死んでいる
# 慾で	死んでいる
# 木の葉は	尽した
# 大概落ち	尽した
# 定業で	役に立たないなら
# 説に	従えば
# 運命は	帰するそうだ
# 自殺に	帰するそうだ
# 油断を	すると
# 猫も	生れなくてはならなくなる
# 世に	生れなくてはならなくなる
# 気が	くさくさして来た
# ビールでも	飲んで
# 景気を	つけてやろう
# 勝手へ	廻る
# 秋風に	がたつく
# 戸が	あいてる
# 細目に	あいてる
# 間から	吹き込んだと
# ランプは	消えているが
# 月夜と	思われて
# 窓から	さす
# 影が	さす
# コップが	並んで
# 上に	並んで
# 三つ	並んで
# 二つに	たまっている
# 水が	たまっている
# 半分ほど	たまっている
# ものは	する
# 気が	する
# 月影に	照らされて
# 静かに	ならんでいる
# 火消壺と	ならんでいる
# 事だから	飲みたくもない
# 唇を	つけぬ
# 先から	飲みたくもない
# 三平などは	した
# あれを	飲んでから
# 真赤に	なって
# 息遣いを	した
# 猫だって	飲めば
# いつ	死ぬか
# 何でも	ある
# 命の	ある
# うちに	しておく事だ
# 残念だと	悔やんでもおっつかない
# 影から	悔やんでもおっつかない
# 舌を	入れて
# 先を	さされたように
# 針で	さされたように
# さされたように	した
# 人間は	わからないが
# 酔興で	飲むのか
# ものを	飲むのか
# 飲むのか	わからないが
# 猫には	飲み切れない
# ビールは	合わない
# 性が	合わない
# 大変だと	見たがまた
# 一度は	見たがまた
# 舌を	引込めて
# 風邪などを	ひくと
# 顔を	しかめて
# ものを	飲む
# 癒るのに	飲むのか
# 問題を	解決してやろう
# ビールで	解決してやろう
# 腹の中まで	にがくなったら
# 事	教えてやってもいい
# 三平のように	忘れる
# 前後を	忘れる
# 愉快になれば	教えてやってもいい
# 儲け者で	教えてやってもいい
# 猫へ	教えてやってもいい
# 運を	任せて
# 天に	任せて
# 決心して	出した
# 舌を	出した
# 眼を	あいていると
# 吾輩は	起った
# 我慢に	重ねて
# 我慢を	重ねて
# 一杯のビールを	飲み干した
# 時	起った
# 現象が	起った
# 舌が	ぴりぴりして
# 口中が	圧迫されるように
# 外部から	圧迫されるように
# 苦しかったのが	折れなくなった
# ようやく楽に	なって
# 一杯目を	片付ける
# 時分には	折れなくなった
# 骨も	折れなくなった
# 二杯目は	やっつけた
# 上に	こぼれたのも
# こぼれたのも	拭うがごとく
# 腹内に	収めた
# 間は	すくんでいた
# 自分で	伺う
# 動静を	伺う
# ため	すくんでいた
# からだが	暖かになる
# ふちが	する
# 耳が	ほてる
# 歌が	うたいたくなる
# 猫じゃ	踊りたくなる
# 猫じゃが	踊りたくなる
# 独仙も	食えと
# 糞を	食えと
# 気に	なる
# じいさんを	引掻いてやりたくなる
# 鼻を	食い欠きたくなる
# 最後に	立ちたくなる
# そとへ	出たくなる
# 御月様今晩はと	挨拶したくなる
# 陶然とは	云うのだろうと
# 事を	云うのだろうと
# 云うのだろうと	思いながら
# かしこと	散歩するような
# 足を	運ばせてゆくと
# 加減に	運ばせてゆくと
# 寝ているのだか	あるいてるのだか
# あるいてるのだか	判然しない
# 眼は	あけるつもりだが
# 海だろうが	出したと
# 驚ろかないんだと	出したと
# 前足を	出したと
# 前へ	出したと
# 途端	して
# 音が	して
# うち	やられた
# やられたのか	考える
# あとは	滅茶苦茶になってしまった
# 我に	帰った
# ときは	浮いている
# 水の上に	浮いている
# 爪で	もって
# 水ばかりで	もぐってしまう
# 仕方がないから	飛び上っておいて
# 後足で	飛び上っておいて
# 前足で	掻いたら
# 音が	して
# 手応が	あった
# 頭だけ	浮くから
# どこだろうと	見廻
# わすと	落ちている
# 吾輩は	落ちている
# 中に	落ちている
# 甕は	使う
# 夏まで	称する
# 水葵と	称する
# 水草が	茂っていたが
# その後	来て
# 勘公が	来て
# 葵を	食い尽した
# 上に	使う
# 行水を	使う
# 行水を	使えば
# 水が	減る
# 近来は	思ったが
# 大分減って	見えないなと
# 烏が	見えないなと
# 先刻	思ったが
# 吾輩自身が	使おうなどとは
# 代りに	使おうなどとは
# 所で	使おうなどとは
# 行水を	使おうなどとは
# 思いも	寄らなかった
# 水から	ある
# 縁までは	ある
# 四寸余も	ある
# 足を	のばしても
# 呑気にしていれば	沈むばかりだ
# 甕に	あたるのみで
# 爪が	あたるのみで
# 気味だが	もぐる
# がりがりを	やる
# からだが	疲れてくる
# 気は	焦るが
# 足は	利かなくなる
# ために	掻くのか
# 甕を	掻くのか
# 掻くのか	もぐるのか
# ために	もぐるのか
# もぐるのか	分りにくくなった
# 自分でも	分りにくくなった
# 呵責に	逢うのは
# 甕から	あがりたいばかりの
# 上へ	あがりたいばかりの
# 山々であるが	知れ切っている
# 上がれないのは	知れ切っている
# 足は	足らぬ
# 三寸に	足らぬ
# 面に	浮いて
# からだが	浮いて
# 所から	のばしたって
# 前足を	のばしたって
# 五寸に	あまる
# 爪の	かかりようが
# 爪の	かかりようが
# いくらも	掻いても
# 間身を	しても
# 粉に	しても
# ものを	出ようとするのは
# 無理を	通そうとするから
# 自ら	苦しんで
# 自ら	好んで
# 拷問に	罹っているのは
# 罹っているのは	馬鹿気ている
# がりがりは	蒙るよと
# これぎりご免	蒙るよと
# 尾も	抵抗しない
# 力に	任せて
# 事に	した
# ありがたいのだか	つかない
# 見当が	つかない
# 中に	いるのだか
# いるのだか	いるのだか
# 上に	いるのだか
# いるのだか	判然しない
# どこに	いても
# 楽そのものすらも	感じ得ない
# 日月を	切り落し
# 天地を	粉韲して
# 粉韲して	入る
# 太平に	入る
# 吾輩は	死ぬ
# 太平を	得る
# 太平は	得られぬ
