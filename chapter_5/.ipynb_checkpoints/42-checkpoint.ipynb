# %%
class Morph:
    def __init__(self, surface, base, pos, pos1):
        self.surface = surface
        self.base = base
        self.pos = pos
        self.pos1 = pos1
        
    def __str__(self):
        return 'surface: {0}, base: {1}, pos: {2}, po1: {3}'.format(self.surface, self.base, self.pos, self.pos1)

# %%
class Chunk:
    def __init__(self, morphs, dst):
        self.morphs = morphs
        self.dst = dst
        self.srcs = []
        self.surfaces2 = ''
        
        for morph in self.morphs:
            if morph.pos != '記号':
                self.surfaces2 += morph.surface
        
    def __str__(self):
        return 'surfaces2: {0}, dst: {1}, srcs: {2}'.format(self.surfaces2, self.dst, self.srcs)

# %%
fname = 'neko.txt.cabocha'
Morphs_list = []
Morphs = []
Chunks_list = []
Chunks = []
Chunk_Morphs = []
EOS_count = 0
src_dst = []

with open(fname) as file:
    for line in file:
        line = line.rstrip('\n')
        if line[0] == '*':
            if len(Chunk_Morphs) > 0:
                Chunks.append(Chunk(Chunk_Morphs, phrase_info[2][:-1]))
            Chunk_Morphs = []
            phrase_info = line.split(' ')
            if EOS_count > 0:
                for s_d in src_dst:
                    if int(s_d[1]) != -1:
                        Chunks[int(s_d[1])].srcs.append(s_d[0])
                src_dst = []
                Chunks_list.append(Chunks)
                Chunks = []
                EOS_count -= 1
            while EOS_count > 0:
                Chunks_list.append([])
                EOS_count -= 1
            src_dst.append([phrase_info[1], phrase_info[2][:-1]])
            continue
        if line == 'EOS':
            Morphs_list.append(Morphs)
            Morphs = []
            EOS_count += 1
            continue
        morpheme = line.split('\t')
        surface = morpheme[0]
        base = morpheme[1].split(',')[6]
        pos = morpheme[1].split(',')[0]
        pos1 = morpheme[1].split(',')[1]
        Morphs.append(Morph(surface, base, pos, pos1))
        Chunk_Morphs.append(Morph(surface, base, pos, pos1))
        
for Chunks in Chunks_list:
    for c in Chunks:
        if c.dst != '-1':
            print('{0}\t{1}'.format(c.surfaces2, Chunks[int(c.dst)].surfaces2))
# Out:
# 名前は	無い
# まだ	無い
# どこで	生れた
# 生れた	かとんと
# かとんと	つかぬ
# 見当が	つかぬ
# 何でも	薄暗い
# 薄暗い	泣いて
# じめじめ	泣いて
# した所で	泣いて
# ニャーニャー	泣いて
# 泣いて	記憶している
# いた事だけは	記憶している
# 吾輩は	見た
# ここで	始めて
# 始めて	人間という
# 人間という	ものを
# ものを	見た
# しかも	そうだ
# あとで	聞くと
# 聞くと	そうだ
# それは	そうだ
# 書生という	人間中で
# 人間中で	種族であった
# 一番	獰悪な
# 獰悪な	種族であった
# 種族であった	そうだ
# この	書生というのは
# 書生というのは	話である
# 時々	捕えて
# 我々を	捕えて
# 捕えて	煮て
# 煮て	食うという
# 食うという	話である
# しかし	思わなかった
# その	当時は
# 当時は	なかったから
# 何という	考も
# 考も	なかったから
# なかったから	思わなかった
# 別段	恐し
# 恐し	思わなかった
# いとも	思わなかった
# ただ	載せられて
# 彼の	掌に
# 掌に	載せられて
# 載せられて	持ち上げられた
# スーと	持ち上げられた
# 持ち上げられた	時
# 時	フワフワした
# 何だか	フワフワした
# フワフワした	感じが
# 感じが	あったばかりである
# 掌の	上で
# 上で	落ちついて
# 少し	落ちついて
# 落ちついて	見たのが
# 書生の	顔を
# 顔を	見たのが
# 見たのが	人間という
# いわゆる	人間という
# 人間という	ものの
# ものの	見始であろう
# この	時
# 時	ものだと
# 妙な	ものだと
# ものだと	思った
# 思った	感じが
# 感じが	残っている
# 今でも	残っている
# 第一毛をもって	装飾されべきはずの
# 装飾されべきはずの	顔が
# 顔が	つるつるして
# つるつるして	薬缶だ
# まるで	薬缶だ
# その後	逢ったが
# 猫にも	逢ったが
# だいぶ	逢ったが
# 逢ったが	ない
# こんな	片輪には
# 片輪には	ない
# 一度も	出会わし
# 出会わし	ない
# た事が	ない
# のみならず	突起している
# 顔の	真中が
# 真中が	突起している
# あまりに	突起している
# そうして	吹く
# その穴の	中から
# 中から	吹く
# 時々	吹く
# ぷうぷうと	吹く
# 煙を	吹く
# どうも	咽せぽくて
# 咽せぽくて	弱った
# 実に	弱った
# これが	ものである
# 人間の	飲む
# 飲む	煙草という
# 煙草という	ものである
# ものである	事は
# 事は	知った
# ようやく	知った
# この	頃
# 頃	知った
# 	おったが
# この	書生の
# 書生の	掌の
# 掌の	裏で
# 裏で	坐って
# しばらくは	よい
# よい	心持に
# 心持に	坐って
# 坐って	おったが
# おったが	運転し始めた
# しばらく	すると
# すると	運転し始めた
# 非常な	速力で
# 速力で	運転し始めた
# 書生が	動くのか
# 動くのか	動くのか
# 自分だけが	動くのか
# 動くのか	分らないが
# 分らないが	廻る
# 無暗に	廻る
# 眼が	廻る
# 胸が	悪くなる
# 到底	助からないと
# 助からないと	思っていると
# 思っていると	出た
# どさりと	して
# 音が	して
# して	出た
# 眼から	出た
# 火が	出た
# それまでは	記憶しているが
# 記憶しているが	分らない
# あとは	分らない
# 何の	事やら
# 事やら	分らない
# いくら	考え出そうとしても
# 考え出そうとしても	分らない
# 	いない
# ふと	付いて
# 気が	付いて
# 付いて	見ると
# 見ると	いない
# 書生は	いない
# たくさん	おった
# おった	兄弟が
# 兄弟が	見えぬ
# 一疋も	見えぬ
# 肝心の	母親さえ
# 母親さえ	隠してしまった
# 姿を	隠してしまった
# その	上今までの
# 上今までの	所とは
# 所とは	違って
# 違って	明るい
# 無暗に	明るい
# 眼を	明いていられぬくらいだ
# はてな	痛い
# 何でも	おかしいと
# 容子が	おかしいと
# おかしいと	痛い
# のそのそ	這い出して
# 這い出して	見ると
# 見ると	痛い
# 非常に	痛い
# 吾輩は	棄てられたのである
# 藁の	上から
# 上から	棄てられたのである
# 急に	棄てられたのである
# 笹原の	中へ
# 中へ	棄てられたのである
# ようやくの	思いで
# 思いで	這い出すと
# 笹原を	這い出すと
# 這い出すと	ある
# 向うに	ある
# 大きな	池が
# 池が	ある
# 吾輩は	見た
# 池の	前に
# 前に	坐って
# 坐って	したら
# どう	したら
# したら	よかろうと
# よかろうと	考えて
# 考えて	見た
# 別に	出ない
# これという	分別も
# 分別も	出ない
# しばらく	して
# して	泣いたら
# 泣いたら	来てくれるかと
# 書生がまた	来てくれるかと
# 迎に	来てくれるかと
# 来てくれるかと	考え付いた
# ニャー	ニャーと
# ニャーと	やって
# 試みに	やって
# やって	見たが
# 見たが	来ない
# 誰も	来ない
# そのうち	渡って
# 池の上を	渡って
# さらさらと	渡って
# 風が	渡って
# 渡って	かかる
# 日が	かかる
# 暮れ	かかる
# 腹が	減って来た
# 非常に	減って来た
# 泣きたくても	声が出ない
# 仕方がない	よいから
# 何でも	よいから
# よいから	所まで
# 食物の	ある
# ある	所まで
# 所まで	ある
# ある	廻り始めた
# こうと	して
# 決心を	して
# して	廻り始めた
# そろりそろりと	廻り始めた
# 池を	廻り始めた
# 左りに	廻り始めた
# どうも	苦しい
# 非常に	苦しい
# そこを	我慢して
# 我慢して	這って行くと
# 無理やりに	這って行くと
# 這って行くと	出た
# ようやくの	事で
# 事で	出た
# 何となく	人間臭い
# 人間臭い	所へ
# 所へ	出た
# ここへ	這入ったら
# 這入ったら	なると
# どうにか	なると
# なると	思って
# 思って	もぐり込んだ
# 竹垣の	崩れた
# 崩れた	穴から
# 穴から	もぐり込んだ
# とある	邸内に
# 邸内に	もぐり込んだ
# 縁は	もので
# 不思議な	もので
# もので	餓死したかも知れんのである
# もし	破れていなかったなら
# この	竹垣が
# 竹垣が	破れていなかったなら
# 破れていなかったなら	餓死したかも知れんのである
# 吾輩は	餓死したかも知れんのである
# ついに	餓死したかも知れんのである
# 路傍に	餓死したかも知れんのである
# 一樹の	蔭とは
# 蔭とは	云った
# よく	云った
# 云った	ものだ
# この	垣根の
# 垣根の	穴は
# 穴は	なっている
# 今日に	至るまで
# 至るまで	訪問する
# 吾輩が	訪問する
# 隣家の	三毛を
# 三毛を	訪問する
# 訪問する	時の
# 時の	通路に
# 通路に	なっている
# さて	分らない
# 邸へは	忍び込んだものの
# 忍び込んだものの	分らない
# これから	善いか
# 先	善いか
# どうして	善いか
# 善いか	分らない
# その	うちに
# うちに	暗くなる
# 暗くなる	減る
# 腹は	減る
# 減る	寒し
# 寒さは	寒し
# 寒し	降って来るという
# 雨が	降って来るという
# 降って来るという	始末で
# 始末で	出来なくなった
# もう	出来なくなった
# 一刻の	猶予が
# 猶予が	出来なくなった
# 仕方がないから	明るくて
# とにかく	明るくて
# 明るくて	暖かそうな
# 暖かそうな	方へ
# 方へ	あるいて行く
# 方へと	あるいて行く
# 今から	考えると
# 考えると	おったのだ
# その	時は
# 時は	おったのだ
# すでに	這入って
# 家の	内に
# 内に	這入って
# 這入って	おったのだ
# ここで	遭遇したのである
# 吾輩は	遭遇したのである
# 彼の	書生以外の
# 書生以外の	人間を
# 人間を	見るべき
# 再び	見るべき
# 見るべき	機会に
# 機会に	遭遇したのである
# 第一に	逢ったのが
# 逢ったのが	おさんである
# これは	抛り出した
# 前の	書生より
# 書生より	見るや
# 一層	乱暴な
# 乱暴な	方で
# 方で	見るや
# 吾輩を	見るや
# 見るや	抛り出した
# 否やいきなり	つかんで
# 頸筋を	つかんで
# つかんで	抛り出した
# 表へ	抛り出した
# いや	思ったから
# これは	駄目だと
# 駄目だと	思ったから
# 思ったから	任せていた
# 眼を	ねぶって
# ねぶって	任せていた
# 運を	任せていた
# 天に	任せていた
# しかし	出来ん
# ひもじいのと	寒いのには
# 寒いのには	出来ん
# どうしても	出来ん
# 我慢が	出来ん
# 吾輩は	這い上った
# 再び	見て
# おさんの	隙を
# 隙を	見て
# 見て	這い上った
# 台所へ	這い上った
# すると	投げ出された
# 間もなくまた	投げ出された
# 吾輩は	這い上り
# 投げ出されては	這い上り
# 這い上り	投げ出され
# 這い上っては	投げ出され
# 投げ出され	記憶している
# 何でも	繰り返したのを
# 同じ	事を
# 事を	繰り返したのを
# 四五遍	繰り返したのを
# 繰り返したのを	記憶している
# その	時に
# 時に	云う
# おさんと	云う
# 云う	者は
# 者は	いやになった
# つくづく	いやになった
# この間	偸んで
# おさんの	三馬を
# 三馬を	偸んで
# 偸んで	してやってから
# この	返報を
# 返報を	してやってから
# してやってから	下りた
# やっと	下りた
# 胸の	痞が
# 痞が	下りた
# 吾輩が	つまみ出されようとした
# 最後に	つまみ出されようとした
# つまみ出されようとした	ときに
# ときに	来た
# この	家の
# 家の	主人が
# 主人が	来た
# 騒々しい	何だと
# 何だと	いいながら
# いいながら	来た
# 出て	来た
# 下女は	困りますと
# 吾輩を	ぶら下げて
# ぶら下げて	困りますと
# 主人の	方へ
# 方へ	向けて
# 向けて	困りますと
# この	宿なしの
# 宿なしの	小猫が
# 小猫が	困りますと
# いくら	上って来て
# 出しても	出しても
# 出しても	上って来て
# 御台所へ	上って来て
# 上って来て	困りますと
# 困りますと	いう
# 主人は	おったが
# 鼻の	下の
# 下の	黒い
# 黒い	毛を
# 毛を	撚りながら
# 撚りながら	眺めて
# 吾輩の	顔を
# 顔を	眺めて
# しばらく	眺めて
# 眺めて	おったが
# おったが	這入ってしまった
# やがて	そんなら
# そんなら	置いてやれといったまま
# 内へ	置いてやれといったまま
# 置いてやれといったまま	這入ってしまった
# 奥へ	這入ってしまった
# 主人は	見えた
# あまり	聞かぬ
# 口を	聞かぬ
# 聞かぬ	人と
# 人と	見えた
# 下女は	抛り出した
# 口惜しそうに	抛り出した
# 吾輩を	抛り出した
# 台所へ	抛り出した
# かくして	したのである
# 吾輩は	したのである
# ついに	したのである
# この	家を
# 家を	極める
# 自分の	住家と
# 住家と	極める
# 極める	事に
# 事に	したのである
# 	ない
# 吾輩の	主人は
# 主人は	ない
# 滅多に	合せる
# 吾輩と	合せる
# 顔を	合せる
# 合せる	事が
# 事が	ない
# 職業は	そうだ
# 教師だ	そうだ
# 学校から	帰ると
# 帰ると	ぎりほとんど出て来る
# 終日	這入った
# 書斎に	這入った
# 這入った	ぎりほとんど出て来る
# ぎりほとんど出て来る	事が
# 事が	ない
# 家の	ものは
# ものは	勉強家だと
# 大変な	勉強家だと
# 勉強家だと	思っている
# 当人も	ごとく
# 勉強家であるかの	ごとく
# ごとく	見せている
# しかし	勤勉家ではない
# 実際は	勤勉家ではない
# うちの	ものが
# ものが	いうような
# いうような	勤勉家ではない
# 吾輩は	見るが
# 時々	覗いて
# 忍び足に	覗いて
# 彼の	書斎を
# 書斎を	覗いて
# 覗いて	見るが
# 見るが	ある
# 彼は	ある
# よく	している
# 昼寝を	している
# している	事が
# 事が	ある
# 時々	読みかけてある
# 読みかけてある	本の
# 本の	上に
# 上に	たらしている
# 涎を	たらしている
# 彼は	あらわしている
# 胃弱で	帯びて
# 皮膚の	色が
# 色が	帯びて
# 淡	黄色を
# 黄色を	帯びて
# 帯びて	あらわしている
# 弾力の	ない
# ない	徴候を
# 不活溌な	徴候を
# 徴候を	あらわしている
# その	癖に
# 癖に	食う
# 大飯を	食う
# 大飯を	食った
# 食った	後で
# 後で	飲む
# タカジヤスターゼを	飲む
# 飲んだ	後で
# 後で	ひろげる
# 書物を	ひろげる
# 二三ページ	読むと
# 読むと	眠くなる
# 涎を	垂らす
# 本の	上へ
# 上へ	垂らす
# これが	繰り返す
# 彼の	毎夜
# 毎夜	繰り返す
# 繰り返す	日課である
# 吾輩は	ある
# 猫ながら	考える
# 時々	考える
# 考える	事が
# 事が	ある
# 教師という	ものは
# ものは	ものだ
# 実に	楽な
# 楽な	ものだ
# 人間と	生れたら
# 生れたら	なるに
# 教師と	なるに
# なるに	限る
# こんなに	寝ていて
# 寝ていて	勤まる
# 勤まる	ものなら
# ものなら	ないと
# 猫にでも	出来ぬ
# 出来ぬ	事は
# 事は	ないと
# それでも	云わせると
# 主人に	云わせると
# 云わせると	ないそうで
# 教師ほど	つらい
# つらい	ものは
# ものは	ないそうで
# ないそうで	鳴らしている
# 彼は	鳴らしている
# 友達が	来る
# 来る	度に
# 度に	鳴らしている
# 何とか	鳴らしている
# かんとか	不平を
# 不平を	鳴らしている
# 吾輩が	住み込んだ
# この	家へ
# 家へ	住み込んだ
# 住み込んだ	当時は
# 当時は	不人望であった
# 主人以外の	ものには
# ものには	不人望であった
# はなはだ	不人望であった
# どこへ	行っても
# 行っても	跳ね付けられて
# 跳ね付けられて	してくれ
# 相手に	してくれ
# してくれ	なかった
# 手が	なかった
# いかに	珍重されなかったかは
# 珍重されなかったかは	分る
# 今日に	至るまで
# 至るまで	つけてくれないのでも
# 名前さえ	つけてくれないのでも
# つけてくれないのでも	分る
# 吾輩は	つとめた
# 仕方がないから	入れてくれた
# 出来得る	限り
# 限り	入れてくれた
# 吾輩を	入れてくれた
# 入れてくれた	主人の
# 主人の	傍に
# 傍に	いる
# いる	事を
# 事を	つとめた
# 朝主人が	読む
# 新聞を	読む
# 読む	ときは
# ときは	乗る
# 必ず	乗る
# 彼の	膝の
# 膝の	上に
# 上に	乗る
# 彼が	する
# 昼寝を	する
# する	ときは
# ときは	乗る
# 必ず	乗る
# その	背中に
# 背中に	乗る
# これは	やむを得んのである
# あながち	好きという
# 主人が	好きという
# 好きという	訳ではないが
# 訳ではないが	なかったから
# 別に	なかったから
# 構い手が	なかったから
# なかったから	やむを得んのである
# その後	した
# いろいろ	した
# 経験の	上
# 上	した
# 朝は	した
# 飯櫃の	上
# 上	した
# 夜は	した
# 炬燵の	上
# 上	した
# 天気の	よい
# よい	昼は
# 昼は	した
# 椽側へ	寝る
# 寝る	事と
# 事と	した
# しかし	事である
# 一番	好いのは
# 心持の	好いのは
# 好いのは	事である
# 夜に	入って
# 入って	ねる
# ここの	うちの
# うちの	小供の
# 小供の	寝床へ
# 寝床へ	もぐり込んで
# もぐり込んで	ねる
# いっしょに	ねる
# ねる	事である
# この	小供というのは
# 小供というのは	寝る
# 五つと	三つで
# 三つで	なると
# 夜に	なると
# なると	寝る
# 二人が	寝る
# 一つ	寝る
# 床へ	入って
# 入って	寝る
# 一間へ	寝る
# 吾輩は	割り込むのであるが
# いつでも	見出して
# 彼等の	中間に
# 中間に	見出して
# 己れを	見出して
# 容るべき	余地を
# 余地を	見出して
# 見出して	割り込むのであるが
# どうにか	割り込むのであるが
# こう	割り込むのであるが
# にか	割り込むのであるが
# 割り込むのであるが	なる
# 運悪く	醒ますが
# 小供の	一人が
# 一人が	醒ますが
# 眼を	醒ますが
# 醒ますが	なる
# 最後大変な	事に
# 事に	なる
# 小供は	泣き出すのである
# ことに	小さい
# 小さい	方が
# 方が	わるい
# 質が	わるい
# わるい	来たと
# 猫が	来た
# 来た	猫が
# 猫が	来たと
# 来たと	いって
# いって	泣き出すのである
# 夜中でも	泣き出すのである
# 何でも	泣き出すのである
# 大きな	声で
# 声で	泣き出すのである
# すると	飛び出してくる
# 例の	神経胃弱性の
# 神経胃弱性の	主人は
# 主人は	飛び出してくる
# 必ず	さまして
# 眼を	さまして
# さまして	飛び出してくる
# 次の	部屋から
# 部屋から	飛び出してくる
# 現に	叩かれた
# せんだってなどは	叩かれた
# 物指で	叩かれた
# 尻ぺたを	叩かれた
# ひどく	叩かれた
# 	断言せざるを得ないようになった
# 吾輩は	断言せざるを得ないようになった
# 人間と	同居して
# 同居して	観察すれば
# 彼等を	観察すれば
# 観察すれば	する
# する	ほど
# ほど	断言せざるを得ないようになった
# 彼等は	断言せざるを得ないようになった
# 我儘な	ものだと
# ものだと	断言せざるを得ないようになった
# ことに	至っては
# 吾輩が	同衾する
# 時々	同衾する
# 同衾する	小供の
# 小供の	ごときに
# ごときに	至っては
# 至っては	言語同断である
# 自分の	時は
# 勝手な	時は
# 時は	押し込んだりする
# 人を	したり
# 逆さに	したり
# したり	かぶせたり
# 頭へ	かぶせたり
# 袋を	かぶせたり
# かぶせたり	抛り出したり
# 抛り出したり	押し込んだりする
# へっついの	中へ
# 中へ	押し込んだりする
# しかも	加える
# 吾輩の	方で
# 方で	しようものなら
# 少しでも	しようものなら
# 手出しを	しようものなら
# しようものなら	加える
# 家内総がかりで	追い廻して
# 追い廻して	加える
# 迫害を	加える
# この間も	磨いだら
# ちょっと	磨いだら
# 畳で	磨いだら
# 爪を	磨いだら
# 磨いだら	入れない
# 細君が	怒って
# 非常に	怒って
# 怒って	入れない
# それから	入れない
# 容易に	入れない
# 座敷へ	入れない
# 台所の	板の間で
# 板の間で	顫えていても
# 他が	顫えていても
# 顫えていても	ものである
# 一向	平気な
# 平気な	ものである
# 吾輩の	尊敬する
# 尊敬する	筋向の
# 筋向の	白君などは
# 白君などは	るる
# 逢う	度毎に
# 度毎に	ないと
# 人間ほど	ないと
# 不人情な	ものは
# ものは	ないと
# ないと	言って
# 言って	るる
# おら	るる
# 白君は	四疋産まれたのである
# 先日玉のような	子猫を
# 子猫を	四疋産まれたのである
# ところが	来たそうだ
# そこの	家の
# 家の	書生が
# 書生が	行って
# 三日目に	行って
# そいつを	持って
# 裏の	池へ
# 池へ	持って
# 持って	行って
# 行って	棄てて
# 四疋ながら	棄てて
# 棄てて	来たそうだ
# 白君は	いわれた
# 涙を	流して
# 流して	話した
# その	一部始終を
# 一部始終を	話した
# 話した	上
# 上	剿滅せねばならぬと
# どうしても	して
# 我等猫族が	して
# 親子の	愛を
# 愛を	して
# 完く	して
# して	するには
# 美しい	家族的生活を
# 家族的生活を	するには
# するには	剿滅せねばならぬと
# 人間と	戦って
# 戦って	剿滅せねばならぬと
# これを	剿滅せねばならぬと
# 剿滅せねばならぬと	いわれた
# 一々	思う
# もっともの	議論と
# 議論と	思う
# また	憤慨している
# 隣りの	三毛君などは
# 三毛君などは	解していないと
# 人間が	所有権という
# 所有権という	事を
# 事を	解していないと
# 解していないと	いって
# いって	憤慨している
# 大に	憤慨している
# 元来	なっている
# 我々	同族間では
# 同族間では	なっている
# 目刺の	頭でも
# 頭でも	臍でも
# 鰡の	臍でも
# 臍でも	見付けた
# 一番	先に
# 先に	見付けた
# 見付けた	ものが
# ものが	食う
# これを	食う
# 食う	権利が
# 権利が	ある
# ある	ものと
# ものと	なっている
# もし	守らなければ
# 相手が	守らなければ
# この	規約を
# 規約を	守らなければ
# 守らなければ	ものだ
# 腕力に	訴えて
# 訴えて	善い
# 善い	くらいの
# くらいの	ものだ
# しかるに	ないと
# 彼等人間は	ないと
# 毫も	ないと
# この	観念が
# 観念が	ないと
# ないと	見えて
# 見えて	見付けた
# 我等が	見付けた
# 見付けた	御馳走は
# 御馳走は	掠奪せらるるのである
# 必ず	掠奪せらるるのである
# 彼等の	ために
# ために	掠奪せらるるのである
# 彼等は	すましている
# その	強力を
# 強力を	頼んで
# 頼んで	食い得べき
# 正当に	食い得べき
# 吾人が	食い得べき
# 食い得べき	ものを
# ものを	奪って
# 奪って	すましている
# 白君は	持っている
# 軍人の	家に
# 家に	おり
# おり	持っている
# 三毛君は	持っている
# 代言の	主人を
# 主人を	持っている
# 吾輩は	楽天である
# 教師の	家に
# 家に	住んでいるだけ
# 住んでいるだけ	楽天である
# こんな	事に関すると
# 事に関すると	両君よりも
# 両君よりも	楽天である
# むしろ	楽天である
# ただ	送られればよい
# その日	送られればよい
# その	日が
# 日が	送られればよい
# どうにか	送られればよい
# こう	送られればよい
# にか	送られればよい
# いくら	あるまい
# 人間だって	あるまい
# そう	栄える
# いつまでも	栄える
# 栄える	事も
# 事も	あるまい
# まあ	待つが
# 気を	待つが
# 永く	待つが
# 猫の	時節を
# 時節を	待つが
# 待つが	よかろう
# 我儘で	思い出したから
# 思い出したから	失敗した
# ちょっと	失敗した
# 吾輩の	家の
# 家の	主人が
# 主人が	失敗した
# この	我儘で
# 我儘で	失敗した
# 失敗した	話を
# 話を	しよう
# 元来	ないが
# この	主人は
# 主人は	ないが
# 何と	勝れて
# いって人に	勝れて
# 勝れて	出来る
# 出来る	事も
# 事も	ないが
# ないが	出したがる
# 何にでも	出したがる
# よく	出したがる
# 手を	出したがる
# 俳句を	やって
# やって	したり
# ほととぎすへ	したり
# 投書を	したり
# したり	出したり
# 新体詩を	出したり
# 明星へ	出したり
# 出したり	かいたり
# 間違い	だらけの
# だらけの	英文を
# 英文を	かいたり
# かいたり	鳴らしたりするが
# 時に	よると
# よると	鳴らしたりするが
# 弓に	凝ったり
# 凝ったり	習ったりまた
# 謡を	習ったりまた
# 習ったりまた	ある
# ある	ときは
# ときは	鳴らしたりするが
# ヴァイオリンなどを	鳴らしたりするが
# ブーブー	鳴らしたりするが
# 鳴らしたりするが	おらん
# 気の毒な	事には
# 事には	おらん
# どれも	おらん
# これも	おらん
# 物に	なって
# なって	おらん
# その	癖
# 癖	やり出すと
# やり出すと	熱心だ
# 胃弱の	癖に
# 癖に	熱心だ
# いやに	熱心だ
# 後架の	中で
# 中で	うたって
# 謡を	うたって
# うたって	もので
# 近所で	つけられている
# 後架先生と	渾名を
# 渾名を	つけられている
# つけられている	にも関せず
# にも関せず	もので
# 一向	平気な
# 平気な	もので
# もので	繰返している
# やはり	繰返している
# これは	繰返している
# 平の	宗盛にて
# 宗盛にて	繰返している
# 候を	繰返している
# みんなが	吹き出す
# そら宗盛だと	吹き出す
# 吹き出す	くらいである
# この	主人が
# 主人が	なった
# どういう	考に
# 考に	なった
# なった	ものか
# ものか	帰って来た
# 吾輩の	住み込んでから
# 住み込んでから	ある
# 一月ばかり後の	ある
# ある	月の
# 月の	月給日に
# 月給日に	帰って来た
# 大きな	包みを
# 包みを	提げて
# 提げて	帰って来た
# あわただしく	帰って来た
# 何を	買って来たのかと
# 買って来たのかと	思うと
# 思うと	見えた
# 水彩絵具と	毛筆と
# 毛筆と	ワットマンという
# ワットマンという	紙で
# 紙で	やめて
# 今日から	やめて
# 謡や	俳句を
# 俳句を	やめて
# やめて	見えた
# 絵を	見えた
# かく	決心と
# 決心と	見えた
# 果して	かいている
# 翌日から	間という
# 当分の	間という
# 間という	ものは
# ものは	かいている
# 毎日	毎日書斎で
# 毎日書斎で	かいている
# 昼寝も	かいている
# しないで	かいている
# 絵ばかり	かいている
# しかし	つかない
# その	かき
# かき	上げた
# 上げた	ものを
# ものを	見ると
# 見ると	つかない
# 何を	かいた
# かいた	ものやら
# ものやら	つかない
# 誰にも	つかない
# 鑑定が	つかない
# 当人も	甘くないと
# あまり	甘くないと
# 甘くないと	思った
# 思った	ものか
# ものか	聞いた
# ある日	友人で
# その	友人で
# 友人で	来た
# 美学とかを	やっている
# やっている	人が
# 人が	来た
# 来た	時に
# 時に	しているのを
# 下のような	話を
# 話を	しているのを
# しているのを	聞いた
# どうも	かけない
# 甘く	かけない
# かけない	ものだね
# 人のを	見ると
# 見ると	ないようだが
# 何でも	ないようだが
# ないようだが	感ずる
# 自ら	とって
# 筆を	とって
# とって	見ると
# 見ると	感ずる
# 今更のように	感ずる
# むずかしく	感ずる
# 感ずる	述懐である
# これは	述懐である
# 主人の	述懐である
# なるほど詐りの	ない
# ない	処だ
# 彼の	友は
# 友は	ものではない
# 金縁の	眼鏡越に
# 眼鏡越に	見ながら
# 主人の	顔を
# 顔を	見ながら
# 見ながら	ものではない
# そう	かけないさ
# 初めから	かけないさ
# 上手には	かけないさ
# かけないさ	ものではない
# 第一室内の	想像ばかりで
# 想像ばかりで	かける
# 画が	かける
# かける	訳の
# 訳の	ものではない
# 昔し	以太利の
# 以太利の	大家
# 大家	アンドレア・デル・サルトが
# アンドレア・デル・サルトが	言った
# 言った	事が
# 事が	ある
# 画を	かくなら
# かくなら	写せ
# 何でも	写せ
# 自然その物を	写せ
# 天に	あり
# 星辰	あり
# 地に	あり
# 露華	あり
# 飛ぶに	あり
# 禽	あり
# 走るに	あり
# 獣	あり
# 池に	あり
# 金魚	あり
# 枯木に	あり
# 寒鴉	あり
# 自然は	大活画なりと
# これ	一幅の
# 一幅の	大活画なりと
# どうだ	君も
# 君も	かこうと
# 画らしい	画を
# 画を	かこうと
# かこうと	思うなら
# 思うなら	したら
# ちと	したら
# 写生を	したら
# へえアンドレア・デル・サルトが	いった
# そんな	事を
# 事を	いった
# いった	事が
# 事が	あるかい
# ちっとも	知らなかった
# なるほどこりゃ	もっともだ
# 実に	その通りだと
# その通りだと	感心している
# 主人は	感心している
# 無暗に	感心している
# 金縁の	裏には
# 裏には	見えた
# 嘲けるような	笑が
# 笑が	見えた
# 	やっている
# その	翌日
# 翌日	やっている
# 吾輩は	やっている
# 例のごとく	していたら
# 椽側に	していたら
# 出て心持	善く
# 善く	していたら
# 昼寝を	していたら
# していたら	やっている
# 主人が	出て来て
# 例に	なく
# なく	出て来て
# 書斎から	出て来て
# 出て来て	やっている
# 吾輩の	後ろで
# 後ろで	やっている
# 何か	やっている
# しきりに	やっている
# ふと	覚めて
# 眼が	覚めて
# 覚めて	しているかと
# 何を	しているかと
# しているかと	あけて
# 一分ばかり	あけて
# 細目に	あけて
# 眼を	あけて
# あけて	見ると
# 見ると	極め込んでいる
# 彼は	極め込んでいる
# 余念も	なく
# なく	極め込んでいる
# アンドレア・デル・サルトを	極め込んでいる
# 吾輩は	禁じ得なかった
# この	有様を
# 有様を	見て
# 見て	失笑するのを
# 覚えず	失笑するのを
# 失笑するのを	禁じ得なかった
# 彼は	写生しつつあるのである
# 彼の	友に
# 友に	揶揄せられたる
# 揶揄せられたる	結果として
# 結果として	写生しつつあるのである
# まず	写生しつつあるのである
# 手初めに	写生しつつあるのである
# 吾輩を	写生しつつあるのである
# 吾輩は	寝た
# すでに	寝た
# 十分	寝た
# 欠伸が	したくて
# したくて	たまらない
# しかし	おった
# せっかく	執っているのを
# 主人が	執っているのを
# 熱心に	執っているのを
# 筆を	執っているのを
# 執っているのを	動いては
# 動いては	気の毒だと
# 気の毒だと	思って
# 思って	おった
# じっと	辛棒して
# 辛棒して	おった
# 彼は	彩っている
# 今	かき上げて
# 吾輩の	輪廓を
# 輪廓を	かき上げて
# かき上げて	彩っている
# 顔の	あたりを
# あたりを	彩っている
# 色	彩っている
# 吾輩は	自白する
# 吾輩は	出来ではない
# 猫として	出来ではない
# 決して	出来ではない
# 上乗の	出来ではない
# 背と	いい
# いい	毛並と
# 毛並と	いい顔の
# いい顔の	造作と
# 造作と	いい
# いい	勝るとは
# あえて	勝るとは
# 他の	猫に
# 猫に	勝るとは
# 勝るとは	おらん
# 決して	思って
# 思って	おらん
# しかし	思われない
# いくら	吾輩でも
# 不器量の	吾輩でも
# 吾輩でも	思われない
# 今	描き出されつつあるような
# 吾輩の	主人に
# 主人に	描き出されつつあるような
# 描き出されつつあるような	姿とは
# 妙な	姿とは
# 姿とは	思われない
# どうしても	思われない
# 第一色が	違う
# 吾輩は	有している
# 波斯産の	猫のごとく
# 猫のごとく	含める
# 黄を	含める
# 含める	灰色に
# 淡	灰色に
# 灰色に	有している
# 漆のごとき	斑入りの
# 斑入りの	皮膚を
# 皮膚を	有している
# これだけは	思う
# 誰が	見ても
# 見ても	思う
# 疑うべからざる	事実と
# 事実と	思う
# しかるに	見ると
# 今主人の	彩色を
# 彩色を	見ると
# 見ると	色でもない
# 黄でもなければ	黒でもない
# 黒でもない	灰色でもなければ
# 灰色でもなければ	褐色でもない
# 褐色でもない	さればとて
# さればとて	交ぜた
# これらを	交ぜた
# 交ぜた	色でもない
# ただ	色である
# 一種の	色であると
# 色であると	いうより
# いうより	ない
# ほかに	ない
# 評し方の	ない
# ない	色である
# その上	ない
# 不思議な	事は
# 事は	ない
# 眼が	ない
# もっとも	写生したのだから
# これは	写生したのだから
# 寝ている	ところを
# ところを	写生したのだから
# 写生したのだから	判然しないのである
# 無理も	ないが
# ないが	判然しないのである
# 眼らしい	所さえ
# 所さえ	見えないから
# 見えないから	寝ている
# 盲猫だか	寝ている
# 寝ている	猫だか
# 猫だか	判然しないのである
# 吾輩は	思った
# 心中ひそかに	ないと
# いくら	ないと
# アンドレア・デル・サルトでも	ないと
# これでは	ないと
# しようが	ないと
# ないと	思った
# しかし	感服せざるを得ない
# その	熱心には
# 熱心には	感服せざるを得ない
# なるべくなら	動かず
# 動かず	におってやりたいと
# におってやりたいと	思ったが
# 思ったが	うしている
# さっきから	うしている
# 小便が	うしている
# 催	うしている
# 身内の	筋肉は
# 筋肉は	むずむずする
# 最早	出来ぬ
# 一分も	出来ぬ
# 猶予が	出来ぬ
# 出来ぬ	仕儀と
# 仕儀と	なったから
# なったから	した
# やむをえず	失敬して
# 失敬して	して
# 両足を	して
# 前へ	して
# 存分の	して
# して	した
# 首を	押し出して
# 低く	押し出して
# 押し出して	した
# あーあと	した
# 大なる	欠伸を
# 欠伸を	した
# さて	仕方がない
# こうなって	見ると
# 見ると	仕方がない
# もう	おとなしくしていても
# おとなしくしていても	仕方がない
# どうせ	打ち壊わしたのだから
# 主人の	予定は
# 予定は	打ち壊わしたのだから
# 打ち壊わしたのだから	這い出した
# ついでに	行って
# 裏へ	行って
# 行って	足そうと
# 用を	足そうと
# 足そうと	思って
# 思って	這い出した
# のそのそ	這い出した
# すると	怒鳴った
# 主人は	怒鳴った
# 失望と	怒りを
# 怒りを	掻き交ぜたような
# 掻き交ぜたような	声を
# 声を	して
# して	怒鳴った
# 座敷の	中から
# 中から	怒鳴った
# この	馬鹿野郎と
# 馬鹿野郎と	怒鳴った
# この	主人は
# 主人は	馬鹿野郎というのが
# 人を	罵る
# 罵る	ときは
# ときは	馬鹿野郎というのが
# 必ず	馬鹿野郎というのが
# 馬鹿野郎というのが	癖である
# ほかに	知らないのだから
# 悪口の	言いようを
# 言いようを	知らないのだから
# 知らないのだから	知らないで
# 仕方がないが	知らないで
# 今まで	知らないで
# 辛棒した人の	気も
# 気も	知らないで
# 知らないで	失敬だと
# 無暗に	失敬だと
# 馬鹿野郎呼わりは	失敬だと
# 失敬だと	思う
# それも	受けるが
# 平生	乗る
# 吾輩が	乗る
# 彼の	背中へ
# 背中へ	乗る
# 乗る	時に
# 時に	するなら
# 少しは	好い
# 好い	顔でも
# 顔でも	するなら
# するなら	受けるが
# この	漫罵も
# 漫罵も	甘んじて
# 甘んじて	受けるが
# 受けるが	酷い
# こっちの	便利になる
# 便利になる	事は
# 事は	ないのに
# 何一つ	快くしてくれた
# 快くしてくれた	事も
# 事も	ないのに
# ないのに	酷い
# 小便に	立ったのを
# 立ったのを	酷い
# 馬鹿野郎とは	酷い
# 元来	増長している
# 人間という	ものは
# ものは	増長している
# 自己の	力量に
# 力量に	慢じて
# 慢じて	増長している
# みんな	増長している
# 少し	強い
# 人間より	強い
# 強い	ものが
# ものが	出て来て
# 出て来て	窘めてやらなくては
# 窘めてやらなくては	分らない
# この	先どこまで
# 先どこまで	増長するか
# 増長するか	分らない
# 我儘も	我慢するが
# この	くらいなら
# くらいなら	我慢するが
# 我慢するが	ある
# 吾輩は	ある
# 人間の	不徳について
# 不徳について	ある
# これよりも	ある
# 数倍	悲しむべき
# 悲しむべき	報道を
# 報道を	した
# 耳に	した
# した	事が
# 事が	ある
# 吾輩の	家の
# 家の	裏に
# 裏に	ある
# 十坪ばかりの	茶園が
# 茶園が	ある
# 広くはないが	所だ
# 瀟洒と	した
# した	心持ち
# 心持ち	好く
# 好く	当る
# 日の	当る
# 当る	所だ
# うちの	小供が
# 小供が	騒いで
# あまり	騒いで
# 騒いで	出来ない
# 楽々	出来ない
# 昼寝の	出来ない
# 出来ない	時や
# 時や	折などは
# あまり	折などは
# 退屈で	折などは
# 腹加減の	よくない
# よくない	折などは
# 折などは	養うのが
# 吾輩は	養うのが
# いつでも	養うのが
# ここへ	養うのが
# 出て浩然の気を	養うのが
# 養うのが	例である
# ある	小春の
# 小春の	穏かな日の
# 穏かな日の	二時頃であったが
# 二時頃であったが	運ばした
# 吾輩は	運ばした
# 昼飯後快よく	一睡した
# 一睡した	後
# 後	運ばした
# 運動かたがた	茶園へと
# この	茶園へと
# 茶園へと	運ばした
# 歩を	運ばした
# 茶の木の	根を
# 根を	一本一本嗅ぎながら
# 一本一本嗅ぎながら	くると
# 西側の	杉垣の
# 杉垣の	そばまで
# そばまで	くると
# くると	寝ている
# 枯菊を	押し倒して
# 押し倒して	寝ている
# その上に	寝ている
# 大きな	猫が
# 猫が	寝ている
# 前後不覚に	寝ている
# 彼は	眠っている
# 吾輩の	近づくのも
# 近づくのも	心付かざるごとくまた
# 一向	心付かざるごとくまた
# 心付かざるごとくまた	無頓着なるごとく
# 心付くも	無頓着なるごとく
# 無頓着なるごとく	眠っている
# 大きな	鼾を
# 鼾を	して
# して	眠っている
# 長々と	眠っている
# 体を	眠っている
# 横えて	眠っている
# 他の	庭内に
# 庭内に	睡られる
# 忍び入りたる	ものが
# ものが	睡られる
# かくまで	睡られる
# 平気に	睡られる
# 睡られる	ものかと
# ものかと	驚かざるを得なかった
# 吾輩は	驚かざるを得なかった
# 窃かに	驚かざるを得なかった
# その	度胸に
# 大胆なる	度胸に
# 度胸に	驚かざるを得なかった
# 彼は	黒猫である
# 純粋の	黒猫である
# わずかに	過ぎたる
# 午を	過ぎたる
# 過ぎたる	太陽は
# 太陽は	思われた
# 透明なる	光線を
# 光線を	かけて
# 彼の	皮膚の
# 皮膚の	上に
# 上に	かけて
# 抛げ	かけて
# かけて	きらきらする
# きらきらする	柔毛の
# 柔毛の	間より
# 間より	見えぬ
# 眼に	見えぬ
# 見えぬ	炎でも
# 炎でも	思われた
# 燃え出ずるように	思われた
# 彼は	有している
# 猫中の	大王とも
# 大王とも	云うべき
# 云うべき	ほどの
# ほどの	体格を
# 偉大なる	体格を
# 体格を	有している
# 吾輩の	倍は
# 倍は	ある
# たしかに	ある
# 吾輩は	落ちた
# 嘆賞の	念と
# 念と	佇立して
# 好奇の	心に
# 心に	忘れて
# 前後を	忘れて
# 忘れて	佇立して
# 彼の	前に
# 前に	佇立して
# 佇立して	眺めていると
# 余念も	なく
# なく	眺めていると
# 眺めていると	落ちた
# 静かなる	小春の
# 小春の	風が
# 風が	落ちた
# 杉垣の	上から
# 上から	出たる
# 出たる	梧桐の
# 梧桐の	枝を
# 枝を	誘って
# 軽く	誘って
# 誘って	落ちた
# ばらばらと	二三枚の
# 二三枚の	葉が
# 葉が	落ちた
# 枯菊の	茂みに
# 茂みに	落ちた
# 大王は	開いた
# かっと	開いた
# その	真丸の
# 真丸の	眼を
# 眼を	開いた
# 今でも	記憶している
# その	眼は
# 眼は	輝いていた
# 人間の	珍重する
# 珍重する	琥珀という
# 琥珀という	ものよりも
# ものよりも	輝いていた
# 遥かに	美しく
# 美しく	輝いていた
# 彼は	しない
# 身動きも	しない
# 双眸の	奥から
# 奥から	射るごとき
# 射るごとき	光を
# 光を	あつめて
# 吾輩の	額の
# 矮小なる	額の
# 額の	上に
# 上に	あつめて
# あつめて	云った
# 御めえは	云った
# 一体	云った
# 何だと	云った
# 大王に	しては
# しては	卑しいと
# 少々	卑しいと
# 言葉が	卑しいと
# 卑しいと	思ったが
# 思ったが	抱いた
# 何しろ	籠っているので
# その	声の
# 声の	底に
# 底に	籠っているので
# 犬をも	籠っているので
# 挫しぐべき	力が
# 力が	籠っているので
# 籠っているので	抱いた
# 吾輩は	抱いた
# 少なからず	抱いた
# 恐れを	抱いた
# しかし	吾輩は猫である
# 挨拶を	しないと
# しないと	険呑だと
# 険呑だと	思ったから
# 思ったから	吾輩は猫である
# 名前は	ないと
# まだ	ないと
# ないと	装って
# なるべく	装って
# 平気を	装って
# 装って	答えた
# 冷然と	答えた
# しかし	おった
# この	時
# 時	おった
# 吾輩の	心臓は
# 心臓は	おった
# たしかに	おった
# 平時よりも	烈しく
# 烈しく	鼓動して
# 鼓動して	おった
# 彼は	猫だ
# 大に	軽蔑せる
# 軽蔑せる	調子で
# 調子で	猫だ
# 何	猫だ
# 	あ
# 猫が	聞いて
# 聞いて	あ
# あきれら	あ
# 全てえ	住んでるんだ
# どこに	住んでるんだ
# 住んでるんだ	傍若無人である
# 随分	傍若無人である
# 吾輩は	いるのだ
# ここの	教師の
# 教師の	家に
# 家に	いるのだ
# いるのだ	事だろうと
# どうせ	事だろうと
# そんな	事だろうと
# 事だろうと	思った
# いやに	瘠せてるじゃねえかと
# 瘠せてるじゃねえかと	吹きかける
# 大王だけに	吹きかける
# 気焔を	吹きかける
# 言葉付から	察すると
# 察すると	思われない
# どうも	思われない
# 良家の	猫とも
# 猫とも	思われない
# しかし	暮しているらしい
# その	膏
# 膏	切って
# 切って	肥満している
# 肥満している	ところを
# ところを	見ると
# 見ると	食ってるらしい
# 御馳走を	食ってるらしい
# 食ってるらしい	暮しているらしい
# 豊かに	暮しているらしい
# 吾輩は	聞かざるを得なかった
# そう	誰だいと
# 云う君は	誰だいと
# 一体	誰だいと
# 誰だいと	聞かざるを得なかった
# 己	れあ車屋の
# れあ車屋の	黒よ昂然たる
# 黒よ昂然たる	ものだ
# 車屋の	黒は
# 黒は	乱暴猫である
# この	近辺で
# 近辺で	知らぬ
# 知らぬ	者
# 者	乱暴猫である
# なき	乱暴猫である
# しかし	交際しない
# 車屋だけに	強いばかりで
# 強いばかりで	ないから
# ちっとも	ないから
# 教育が	ないから
# ないから	交際しない
# あまり	交際しない
# 誰も	交際しない
# 同盟敬遠主義の	的に
# 的に	なっている
# なっている	奴だ
# 吾輩は	起すと同時に
# 彼の	名を
# 名を	聞いて
# 聞いて	起すと同時に
# 少々	こそばゆき
# 尻	こそばゆき
# こそばゆき	感じを
# 感じを	起すと同時に
# 起すと同時に	生じたのである
# 一方では	生じたのである
# 少々	生じたのである
# 軽侮の	念も
# 念も	生じたのである
# 吾輩は	見た
# まず	試してみようと
# 彼が	無学であるかを
# どの	くらい
# くらい	無学であるかを
# 無学であるかを	試してみようと
# 試してみようと	思って
# 思って	見た
# 左の	問答を
# 問答を	して
# して	見た
# 一体	えらいだろう
# 車屋と	教師とは
# 教師とは	えらいだろう
# どっちが	えらいだろう
# 車屋の	方が
# 方が	強いに
# 強いに	あな
# 極って	いら
# いら	あな
# 御めえの	うちの
# うちの	主人を
# 主人を	見ねえ
# 見ねえ	皮ばかりだぜ
# まるで	皮ばかりだぜ
# 骨と	皮ばかりだぜ
# 君も	大分強そうだ
# 車屋の	猫だけに
# 猫だけに	大分強そうだ
# 車屋に	いると
# いると	食えると
# 御馳走が	食えると
# 食えると	見えるね
# 何に	しねえつもりだ
# おれ	なんざ
# なんざ	しねえつもりだ
# どこの	国へ
# 国へ	行ったって
# 行ったって	しねえつもりだ
# 食い物に	しねえつもりだ
# 不自由は	しねえつもりだ
# 御めえなんかも	廻っていねえで
# 茶畠ばかり	廻っていねえで
# ぐるぐる	廻っていねえで
# 廻っていねえで	見ねえ
# ちっと	くっ付いて来て
# 己の	後へ
# 後へ	くっ付いて来て
# くっ付いて来て	見ねえ
# 一と	たたねえ
# 月と	たたねえ
# たたねえ	見違えるように
# うちに	見違えるように
# 見違えるように	太れるぜ
# 追って	しよう
# そう	願う
# 願う	事に
# 事に	しよう
# しかし	思われる
# 家は	思われる
# 教師の	方が
# 方が	大きいのに
# 車屋より	大きいのに
# 大きいのに	住んでいるように
# 住んでいるように	思われる
# 箆棒め	もんか
# うちなんか	たって
# いくら	たって
# 大きく	たって
# たって	なる
# 腹の	足しに
# 足しに	なる
# なる	もんか
# 	立ち去った
# 彼は	立ち去った
# 大に	障った
# 肝癪に	障った
# 障った	様子で
# 様子で	立ち去った
# 寒竹を	そいだような
# そいだような	耳を
# 耳を	し
# し	立ち去った
# きりと	付かせて
# ぴく	付かせて
# 付かせて	立ち去った
# あららかに	立ち去った
# 吾輩が	なったのは
# 車屋の	黒と
# 黒と	なったのは
# 知己に	なったのは
# なったのは	これからである
# その後	邂逅する
# 吾輩は	邂逅する
# 度々	邂逅する
# 黒と	邂逅する
# 邂逅する	毎に
# 毎に	吐く
# 彼は	吐く
# 車屋相当の	気焔を
# 気焔を	吐く
# 先に	したという
# 吾輩が	したという
# 耳に	したという
# したという	不徳事件も
# 不徳事件も	聞いたのである
# 実は	聞いたのである
# 黒から	聞いたのである
# 	質問した
# 或る	日
# 日	例のごとく
# 例のごとく	質問した
# 吾輩と	黒は
# 黒は	していると
# 暖かい	茶畠の
# 茶畠の	中で
# 中で	寝転びながら
# 寝転びながら	していると
# いろいろ	していると
# 雑談を	していると
# していると	質問した
# 彼は	質問した
# いつもの	自慢話しを
# 自慢話しを	繰り返した
# さも	繰り返した
# 新しそうに	繰り返した
# 繰り返した	あとで
# あとで	質問した
# 吾輩に	向って
# 向って	質問した
# 下のごとく	質問した
# 御めえは	ある
# 今までに	とった
# 鼠を	とった
# 何匹	とった
# とった	事が
# 事が	ある
# ある	発達しているつもりだが
# 智識は	発達しているつもりだが
# 黒よりも	発達しているつもりだが
# 余程	発達しているつもりだが
# 発達しているつもりだが	ならないと
# 腕力と	勇気とに
# 勇気とに	至っては
# 至っては	ならないと
# 到底	ならないと
# 黒の	比較には
# 比較には	ならないと
# ならないと	していた
# 覚悟は	していた
# していた	ものの
# ものの	善くはなかった
# この	問に
# 問に	接したる
# 接したる	時は
# 時は	善くはなかった
# さすがに	善くはなかった
# 極りが	善くはなかった
# けれども	答えた
# 事実は	行かないから
# 事実で	詐る
# 詐る	訳には
# 訳には	行かないから
# 行かないから	答えた
# 吾輩は	答えた
# 実は	捕らないと
# とろうとろうと	思って
# 思って	捕らないと
# まだ	捕らないと
# 捕らないと	答えた
# 黒は	笑った
# 彼の	鼻の
# 鼻の	先から
# 先から	張っている
# ぴんと突	張っている
# 張っている	長い髭を
# 長い髭を	震わせて
# びりびりと	震わせて
# 震わせて	笑った
# 非常に	笑った
# 元来	あって
# 黒は	あって
# 自慢を	する
# する	丈に
# 丈に	足りない
# どこか	足りない
# 足りない	ところが
# ところが	あって
# あって	感心したように
# 彼の	気焔を
# 気焔を	感心したように
# 感心したように	謹聴していれば
# 咽喉を	鳴らして
# ころころ	鳴らして
# 鳴らして	謹聴していれば
# 謹聴していれば	御しやすい
# はなはだ	御しやすい
# 御しやすい	猫である
# 吾輩は	定めた
# 彼と	近付に
# 近付に	なってから
# なってから	飲み込んだから
# 直に	飲み込んだから
# この	呼吸を
# 呼吸を	飲み込んだから
# 飲み込んだから	わるくするのも
# この	場合にも
# 場合にも	わるくするのも
# なまじい	弁護して
# 己れを	弁護して
# 弁護して	わるくするのも
# ますます	わるくするのも
# 形勢を	わるくするのも
# わるくするのも	愚である
# 愚である	若くはないと
# いっその	事彼に
# 事彼に	しゃべらして
# 自分の	手柄話を
# 手柄話を	しゃべらして
# しゃべらして	濁すに
# 御茶を	濁すに
# 濁すに	若くはないと
# 若くはないと	定めた
# 思案を	定めた
# そこで	見た
# おとなしく	見た
# 君などは	とったろうと
# 年が	年であるから
# 年であるから	とったろうと
# 大分	とったろうと
# とったろうと	見た
# そそのかして	見た
# 果然	吶喊して来た
# 彼は	吶喊して来た
# 墻壁の	欠所に
# 欠所に	吶喊して来た
# たんとでもねえが	とったろうとは
# 三四十は	とったろうとは
# とったろうとは	答であった
# 得意気なる	彼の
# 彼の	答であった
# 彼は	合わねえ
# なお	つづけて
# 語を	つづけて
# つづけて	合わねえ
# 鼠の	二百は
# 百や	二百は
# 二百は	引き受けるが
# 一人で	引き受けるが
# いつでも	引き受けるが
# 引き受けるが	合わねえ
# いたちってえ	合わねえ
# 奴は	合わねえ
# 手に	合わねえ
# 一度	向って
# いたちに	向って
# 向って	逢った
# 酷い	目に
# 目に	逢った
# 逢った	へえなるほどと
# へえなるほどと	打つ
# 相槌を	打つ
# 黒は	云う
# 大きな	眼を
# 眼を	ぱちつかせて
# ぱちつかせて	云う
# 去年の	大掃除の
# 大掃除の	時だ
# うちの	亭主が
# 亭主が	持って
# 石灰の	袋を
# 袋を	持って
# 持って	這い込んだら
# 椽の	下へ
# 下へ	這い込んだら
# 這い込んだら	飛び出したと
# 御めえ大きな	いたちの
# いたちの	野郎が
# 野郎が	喰って
# 面	喰って
# 喰って	飛び出したと
# 飛び出したと	思いねえ
# 思いねえ	ふんと
# ふんと	感心して
# 感心して	見せる
# いたちってけども	ものだ
# 何鼠の	大きい
# 少し	大きい
# 大きい	ぐれえの
# ぐれえの	ものだ
# こん畜生って	追っかけて
# 気で	追っかけて
# 追っかけて	追い込んだと
# とうとう	追い込んだと
# 泥溝の	中へ
# 中へ	追い込んだと
# 追い込んだと	思いねえ
# 思いねえ	やったねと
# うまく	やったねと
# やったねと	喝采してやる
# ところが	こきゃがった
# 御めえいざって	なると
# え段に	なると
# なると	こきゃがった
# 奴め最後っ屁を	こきゃがった
# 臭えの	臭くねえのって
# 臭くねえのって	あ
# それ	からってえ
# からってえ	あ
# ものは	あ
# いたちを	見ると
# 見ると	あ
# 胸が	悪くなら
# 悪くなら	あ
# あ	なで廻わした
# 彼は	なで廻わした
# ここに	至って
# 至って	感ずるごとく
# あたかも	感ずるごとく
# 去年の	臭気を
# 臭気を	感ずるごとく
# 今なお	感ずるごとく
# 感ずるごとく	なで廻わした
# 前足を	揚げて
# 揚げて	なで廻わした
# 鼻の	頭を
# 頭を	なで廻わした
# 二三遍	なで廻わした
# 吾輩も	する
# 少々	気の毒な
# 気の毒な	感じが
# 感じが	する
# ちっと	付けて
# 景気を	付けて
# 付けて	思って
# やろうと	思って
# 思って	百年目だろう
# しかし	睨まれては
# 鼠なら	睨まれては
# 君に	睨まれては
# 睨まれては	百年目だろう
# 君は	呈出した
# あまり	捕るのが
# 鼠を	捕るのが
# 捕るのが	食う
# 名人で	食う
# 鼠ばかり	食う
# 食う	ものだから
# ものだから	善いのだろう黒の
# そんなに	肥って
# 肥って	善いのだろう黒の
# 色つやが	善いのだろう黒の
# 善いのだろう黒の	御機嫌を
# 御機嫌を	とる
# とる	ための
# ための	質問は
# この	質問は
# 質問は	呈出した
# 不思議にも	呈出した
# 反対の	結果を
# 結果を	呈出した
# 彼は	いう
# 喟然として	大息して
# 大息して	いう
# 考げ	えると
# えると	つまらねえ
# いくら	稼いで
# 稼いで	とったって
# 鼠を	とったって
# とったって	いねえぜ
# 一てえ	ふてえ
# 人間ほど	ふてえ
# ふてえ	いねえぜ
# 奴は	いねえぜ
# 世の中に	いねえぜ
# 人の	とった
# とった	鼠を
# 鼠を	取り上げやがって
# みんな	取り上げやがって
# 取り上げやがって	持って行きゃ
# 交番へ	持って行きゃ
# 持って行きゃ	あがる
# 交番じゃ	捕ったか
# 誰が	捕ったか
# 捕ったか	分らねえから
# 分らねえから	くれるじゃねえか
# その	たんびに
# たんびに	くれるじゃねえか
# 五銭ずつ	くれるじゃねえか
# うちの	亭主なんか
# 亭主なんか	儲けて
# 己の	御蔭で
# 御蔭で	儲けて
# もう	壱円五十銭くらい
# 壱円五十銭くらい	儲けて
# 儲けて	いやがる
# いやがる	癖に
# 癖に	食わせた
# 碌なものを	食わせた
# 食わせた	事も
# 事も	ありゃしねえ
# おい	泥棒だぜさすが
# 人間て	泥棒だぜさすが
# ものあ体の	善い
# 善い	泥棒だぜさすが
# 泥棒だぜさすが	わかると
# 無学の	黒も
# 黒も	わかると
# この	くらいの
# くらいの	理窟は
# 理窟は	わかると
# わかると	見えて
# 見えて	怒った
# すこぶる	怒った
# 怒った	容子で
# 容子で	逆立てている
# 背中の	毛を
# 毛を	逆立てている
# 吾輩は	帰った
# 少々	気味が悪くなったから
# 気味が悪くなったから	帰った
# 善い	加減に
# 加減に	胡魔化して
# その	場を
# 場を	胡魔化して
# 胡魔化して	帰った
# 家へ	帰った
# この	時から
# 時から	決心した
# 吾輩は	とるまいと
# 決して	とるまいと
# 鼠を	とるまいと
# とるまいと	決心した
# しかし	しなかった
# 黒の	子分に
# 子分に	なって
# なって	あるく
# 鼠以外の	御馳走を
# 御馳走を	あるく
# 猟って	あるく
# あるく	事も
# 事も	しなかった
# 御馳走を	食うよりも
# 食うよりも	寝ていた
# 寝ていた	方が
# 方が	気楽で
# 気楽で	いい
# 教師の	家に
# 家に	いると
# いると	なると
# 猫も	教師のような
# 教師のような	性質に
# 性質に	なると
# なると	見える
# 要心しないと	なるかも知れない
# 今に	なるかも知れない
# 胃弱に	なるかも知れない
# 教師と	いえば
# いえば	至っては
# 吾輩の	主人も
# 主人も	至っては
# 近頃に	至っては
# 至っては	かきつけた
# 到底	悟った
# 水彩画において	悟った
# 望の	ない
# ない	事を
# 事を	悟った
# 悟った	ものと
# ものと	見えて
# 見えて	かきつけた
# 十二月一日の	日記に
# 日記に	かきつけた
# こんな	事を
# 事を	かきつけた
# と	云う
# 云う	人に
# 人に	始めて
# 今日の	会で
# 会で	始めて
# 始めて	出逢った
# あの	人は
# 人は	している
# 大分放蕩を	した
# した	人だと
# 人だと	云うが
# 云うが	なる
# なる	ほど
# ほど	通人らしい
# 通人らしい	風采を
# 風采を	している
# こう	云う
# 云う	質の
# 質の	人は
# 人は	適当であろう
# 女に	好かれる
# 好かれる	ものだからが
# ものだからが	したと
# 放蕩を	したと
# したと	云うよりも
# 云うよりも	するべく
# 放蕩を	するべく
# するべく	せられたと
# 余儀なく	せられたと
# せられたと	云うのが
# 云うのが	適当であろう
# あの	人の
# 人の	妻君は
# 妻君は	事である
# 芸者だ	そうだ
# そうだ	事である
# 羨ましい	事である
# 元来放蕩家を	いう
# 悪く	いう
# いう	人の
# 人の	大部分は
# 大部分は	多い
# 放蕩を	する
# する	資格の
# 資格の	ない
# ない	ものが
# ものが	多い
# また	多い
# 放蕩家をもって	自任する
# 自任する	連中の
# 連中の	うちにも
# うちにも	多い
# 放蕩する	資格の
# 資格の	ない
# ない	ものが
# ものが	多い
# これらは	余儀なくされないのに
# 余儀なくされないのに	進んでやるのである
# 無理に	進んでやるのである
# あたかも	ない
# 吾輩の	水彩画に
# 水彩画に	於ける
# 於ける	きもので
# がごと	きもので
# きもので	卒業する
# 到底	卒業する
# 卒業する	気づかいは
# 気づかいは	ない
# しかる	にも関せず
# にも関せず	通人だと
# 自分だけは	通人だと
# 通人だと	思って
# 思って	済している
# 料理屋の	酒を
# 酒を	飲んだり
# 飲んだり	這入るから
# 待合へ	這入るから
# 這入るから	なり得るという
# 通人と	なり得るという
# なり得るという	論が
# 論が	立つなら
# 立つなら	なり得る
# 吾輩も	なり得る
# 一廉の	水彩画家に
# 水彩画家に	なり得る
# なり得る	理窟だ
# 吾輩の	はかか
# 水彩画のごとき	はかか
# はかか	ない
# ない	方が
# 方が	同じように
# ましであると	同じように
# 同じように	上等だ
# 愚昧なる	通人よりも
# 通人よりも	上等だ
# 山出しの	大野暮の
# 大野暮の	方が
# 方が	上等だ
# 遥かに	上等だ
# 通人論は	首肯しかねる
# ちょっと	首肯しかねる
# また	ものだ
# 芸者の	妻君を
# 妻君を	羨しいなどという
# 羨しいなどという	ところは
# ところは	考であるが
# 教師としては	考であるが
# 口に	すべからざる
# すべからざる	愚劣の
# 愚劣の	考であるが
# 考であるが	ものだ
# 自己の	水彩画における
# 水彩画における	批評眼だけは
# 批評眼だけは	ものだ
# たしかな	ものだ
# 主人は	抜けない
# かくのごとく	にも関せず
# 自知の	にも関せず
# 明	にも関せず
# ある	にも関せず
# にも関せず	抜けない
# その	自惚心は
# 自惚心は	抜けない
# なかなか	抜けない
# 中二日	置いて
# 置いて	書いている
# 十二月四日の	日記に
# 日記に	書いている
# こんな	事を
# 事を	書いている
# 昨夜は	ならんと
# 僕が	かいて
# 水彩画を	かいて
# かいて	ならんと
# 到底	ならんと
# 物に	ならんと
# ならんと	思って
# 思って	見た
# そこらに	抛って
# 抛って	置いたのを
# 置いたのを	して
# 誰かが	して
# 立派な	額に
# 額に	して
# して	懸けてくれた
# 欄間に	懸けてくれた
# 懸けてくれた	夢を
# 夢を	見た
# さて	上手になった
# 額に	なった
# なった	ところを
# ところを	見ると
# 見ると	上手になった
# 我ながら	上手になった
# 急に	上手になった
# 非常に	嬉しい
# これなら	眺め暮らしていると
# 立派な	ものだと
# ものだと	眺め暮らしていると
# 独りで	眺め暮らしていると
# 眺め暮らしていると	明瞭になってしまった
# 夜が	覚めて
# 明けて	覚めて
# 眼が	覚めて
# 覚めて	下手である
# やはり	下手である
# 元の	通り
# 通り	下手である
# 下手である	事が
# 事が	明瞭になってしまった
# 朝日と共に	明瞭になってしまった
# 主人は	背負ってあるいていると
# 夢の	裡まで
# 裡まで	背負ってあるいていると
# 水彩画の	未練を
# 未練を	背負ってあるいていると
# 背負ってあるいていると	見える
# これでは	質だ
# 水彩画家は	質だ
# 無論	なれない
# 夫子の	所謂通人にも
# 所謂通人にも	なれない
# なれない	質だ
# 主人が	見た
# 水彩画を	見た
# 夢に	見た
# 見た	翌日例の
# 翌日例の	金縁眼鏡の
# 金縁眼鏡の	美学者が
# 美学者が	訪問した
# 久し振りで	訪問した
# 主人を	訪問した
# 彼は	切った
# 座に	つくと
# つくと	切った
# 劈頭第一に	切った
# 画は	どうかねと
# どうかねと	切った
# 口を	切った
# 主人は	分るようだ
# 平気な	顔を
# 顔を	して
# して	分るようだ
# 君の	忠告に従って
# 忠告に従って	力めているが
# 写生を	力めているが
# 力めているが	分るようだ
# なるほど	分るようだ
# 写生を	すると
# すると	分るようだ
# 今まで	つかなかった
# 気の	つかなかった
# つかなかった	物の
# 物の	形や
# 形や	変化などが
# 色の	変化などが
# 精細な	変化などが
# 変化などが	分るようだ
# よく	分るようだ
# 西洋では	しから
# 昔	しから
# しから	主張した
# 写生を	主張した
# 主張した	結果
# 結果	今日のように
# 今日のように	発達した
# 発達した	ものと
# ものと	思われる
# さすが	アンドレア・デル・サルトだと
# アンドレア・デル・サルトだと	出さないでまた
# 日記の	事は
# 事は	出さないでまた
# おくびにも	出さないでまた
# 出さないでまた	感心する
# アンドレア・デル・サルトに	感心する
# 美学者は	掻く
# 笑いながら	掻く
# 実は	出鱈目だよと
# 君	出鱈目だよと
# あれは	出鱈目だよと
# 出鱈目だよと	掻く
# 頭を	掻く
# 何がと	つかない
# 主人は	つかない
# まだ	つかない
# わられ	つかない
# た事に	つかない
# 気が	つかない
# 何がって	アンドレア・デル・サルトさ
# 君の	感服している
# しきりに	感服している
# 感服している	アンドレア・デル・サルトさ
# あれは	話だ
# 僕の	捏造した
# ちょっと	捏造した
# 捏造した	話だ
# 君が	信じようとは
# そんなに	信じようとは
# 真面目に	信じようとは
# 信じようとは	思わなかった
# 思わなかった	ハハハハと
# ハハハハと	体である
# 大喜悦の	体である
# 吾輩は	想像せざるを得なかった
# 椽側で	聞いて
# この	対話を
# 対話を	聞いて
# 聞いて	想像せざるを得なかった
# 彼の	今日の
# 今日の	日記には
# 日記には	記さるるであろうかと
# いかなる	事が
# 事が	記さるるであろうかと
# 記さるるであろうかと	想像せざるを得なかった
# 予め	想像せざるを得なかった
# この	美学者は
# 美学者は	男である
# こんな	事を
# 好加減な	事を
# 事を	吹き散らして
# 吹き散らして	担ぐのを
# 人を	担ぐのを
# 担ぐのを	楽にしている
# 唯一の	楽にしている
# 楽にしている	男である
# 彼は	饒舌った
# アンドレア・デル・サルト事件が	伝えたかを
# 主人の	情線に
# 情線に	伝えたかを
# いかなる	響を
# 響を	伝えたかを
# 伝えたかを	顧慮せざるもののごとく
# 毫も	顧慮せざるもののごとく
# 顧慮せざるもののごとく	なって
# 得意に	なって
# なって	饒舌った
# 下のような	事を
# 事を	饒舌った
# いや	受けるので
# 時々	言うと
# 冗談を	言うと
# 言うと	受けるので
# 人が	受けるので
# 真に	受けるので
# 受けるので	挑撥するのは
# 大に	挑撥するのは
# 滑稽的美感を	挑撥するのは
# 挑撥するのは	面白い
# せんだって	ある
# ある	学生に
# 学生に	忠告して
# ニコラス・ニックルベーが	忠告して
# ギボンに	忠告して
# 忠告して	大著述なる
# 彼の	一世の
# 一世の	大著述なる
# 大著述なる	仏国革命史を
# 仏国革命史を	書くのを
# 仏語で	書くのを
# 書くのを	やめにして
# やめにして	出版させたと
# 英文で	出版させたと
# 出版させたと	言ったら
# 言ったら	滑稽であった
# その	学生がまた
# 学生がまた	男で
# 馬鹿に	男で
# 記憶の	善い
# 善い	男で
# 男で	繰り返したのは
# 日本文学会の	演説会で
# 演説会で	話した
# 真面目に	話した
# 僕の	話した
# 話した	通りを
# 通りを	繰り返したのは
# 繰り返したのは	滑稽であった
# ところが	おった
# その	時の
# 時の	傍聴者は
# 傍聴者は	約百名ばかりであったが
# 約百名ばかりであったが	おった
# 皆	傾聴して
# 熱心に	傾聴して
# それを	傾聴して
# 傾聴して	おった
# それから	ある
# まだ	面白い
# 面白い	話が
# 話が	ある
# せんだって	出たから
# 或る	文学者の
# 文学者の	いる
# いる	席で
# 席で	出たから
# ハリソンの	歴史小説セオファーノの
# 歴史小説セオファーノの	話しが
# 話しが	出たから
# 出たから	白眉である
# 僕は	白眉である
# あれは	白眉である
# 歴史小説の	中で
# 中で	白眉である
# ことに	評したら
# 女主人公が	死ぬ
# 死ぬ	ところは
# ところは	襲うようだと
# 鬼気人を	襲うようだと
# 襲うようだと	評したら
# 評したら	いった
# 僕の	向うに
# 向うに	坐っている
# 坐っている	知らんと
# 知らんと	云った
# 云った	事の
# 事の	ない
# ない	先生が
# 先生が	いった
# そうそうあすこは	名文だと
# 実に	名文だと
# 名文だと	いった
# それで	知った
# 僕は	知った
# この	男も
# 男も	読んでおらないという
# やはり	読んでおらないという
# 僕同様	読んでおらないという
# この	小説を
# 小説を	読んでおらないという
# 読んでおらないという	事を
# 事を	知った
# 知った	主人は
# 神経胃弱性の	主人は
# 主人は	問いかけた
# 眼を	丸くして
# 丸くして	問いかけた
# そんな	出鱈目を
# 出鱈目を	いって
# いって	読んでいたら
# もし	読んでいたら
# 相手が	読んでいたら
# 読んでいたら	するつもりだ
# どう	するつもりだ
# するつもりだ	欺くのは
# あたかも	欺くのは
# 人を	欺くのは
# 欺くのは	ない
# 差支	ない
# ない	困るじゃないかと
# ただ	あらわれた
# 化の皮が	あらわれた
# あらわれた	時は
# 時は	困るじゃないかと
# 困るじゃないかと	感じた
# 感じた	もののごとくである
# 美学者は	動じない
# 少しも	動じない
# なに	云うばかりさと
# その	時
# 時	云うばかりさと
# ゃ別の	本と
# 本と	間違えたとか
# 間違えたとか	云うばかりさと
# 何とか	云うばかりさと
# 云うばかりさと	云って
# 云って	笑っている
# けらけら	笑っている
# この	美学者は
# 美学者は	掛けているが
# 金縁の	眼鏡は
# 眼鏡は	掛けているが
# 掛けているが	ある
# その	性質が
# 性質が	似た
# 車屋の	黒に
# 黒に	似た
# 似た	ところが
# ところが	ある
# 主人は	している
# 黙って	ないと
# 日の出を	吹いて
# 輪に	吹いて
# 吹いて	ないと
# 吾輩には	ないと
# そんな	勇気は
# 勇気は	ないと
# ないと	云わんばかりの
# 云わんばかりの	顔を
# 顔を	している
# 美学者は	あるそうだ
# それだから	駄目だという
# 画を	かいても
# かいても	駄目だという
# 駄目だという	目付で
# 目付で	あるそうだ
# しかし	冗談だが
# 冗談は	冗談だが
# 冗談だが	あるそうだ
# 画という	ものは
# ものは	ものだよ
# 実際	むずかしい
# むずかしい	ものだよ
# ものだよ	あるそうだ
# レオナルド・ダ・ヴィンチは	あるそうだ
# 門下生に	写せと
# 寺院の	壁の
# 壁の	しみを
# しみを	写せと
# 写せと	教えた
# 教えた	事が
# 事が	あるそうだ
# なるほど雪隠などに	這入って
# 這入って	眺めていると
# 雨の	漏る
# 漏る	壁を
# 壁を	眺めていると
# 余念	なく
# なく	眺めていると
# 眺めていると	出来ているぜ
# なかなか	うまい
# うまい	模様画が
# 模様画が	出来ているぜ
# 自然に	出来ているぜ
# 君	注意して
# 注意して	写生して
# 写生して	出来るから
# 見給え	出来るから
# きっと	面白い
# 面白い	ものが
# ものが	出来るから
# 出来るから	欺すのだろう
# また	欺すのだろう
# 欺すのだろう	たしかだよ
# いえ	たしかだよ
# これだけは	たしかだよ
# 実際	奇警な
# 奇警な	語じゃないか
# 語じゃないか	いいそうな
# ダ・ヴィンチでも	いいそうな
# いいそうな	事だあね
# 事だあね	相違ないなと
# なるほど奇警には	相違ないなと
# 相違ないなと	した
# 主人は	した
# 半分降参を	した
# しかし	せぬようだ
# 彼は	せぬようだ
# まだ	せぬようだ
# 雪隠で	せぬようだ
# 写生は	せぬようだ
# 車屋の	黒は
# 黒は	なった
# その後	なった
# 跛に	なった
# 彼の	光沢
# 光沢	ある
# ある	毛は
# 毛は	抜けて来る
# 漸々	褪めて
# 色が	褪めて
# 褪めて	抜けて来る
# 吾輩が	美しいと
# 琥珀よりも	美しいと
# 美しいと	評した
# 評した	眼には
# 彼の	眼には
# 眼には	一杯たまっている
# 眼脂が	一杯たまっている
# ことに	惹いたのは
# 著	るしく
# るしく	吾輩の
# 吾輩の	注意を
# 注意を	惹いたのは
# 惹いたのは	事である
# 彼の	元気の
# 元気の	消沈と
# 消沈と	悪くなった
# その	体格の
# 体格の	悪くなった
# 悪くなった	事である
# 吾輩が	逢った
# 例の	茶園で
# 茶園で	逢った
# 彼に	逢った
# 逢った	最後の
# 最後の	日
# 日	いった
# どうだと	云って
# 云って	尋ねたら
# 尋ねたら	いった
# いたちの	最後屁と
# 最後屁と	天秤棒には
# 肴屋の	天秤棒には
# 天秤棒には	懲だと
# 懲だと	いった
# 	尽した
# 赤松の	間に
# 間に	綴った
# 二三段の	紅を
# 紅を	綴った
# 綴った	紅葉は
# 紅葉は	尽した
# 昔しの	夢のごとく
# 夢のごとく	散って
# 散って	こぼした
# つくばいに	こぼした
# 近く	こぼした
# 代る代る	こぼした
# 花弁を	こぼした
# こぼした	紅白の
# 紅白の	山茶花も
# 山茶花も	尽した
# 残り	なく
# なく	尽した
# 落ち	尽した
# 三間半の	南向の
# 南向の	椽側に
# 椽側に	傾いて
# 冬の	日脚が
# 日脚が	傾いて
# 早く	傾いて
# 傾いて	する
# 木枯の	吹かない
# 吹かない	日は
# 日は	する
# ほとんど	稀になってから
# 稀になってから	狭められたような
# 吾輩の	昼寝の
# 昼寝の	時間も
# 時間も	狭められたような
# 狭められたような	気が
# 気が	する
# 主人は	行く
# 毎日学校へ	行く
# 帰ると	立て籠る
# 書斎へ	立て籠る
# 人が	来ると
# 来ると	厭だと
# 教師が	厭だ
# 厭だ	厭だと
# 厭だと	いう
# 水彩画も	かかない
# 滅多に	かかない
# タカジヤスターゼも	やめてしまった
# 功能が	ないと
# ないと	いって
# いって	やめてしまった
# 小供は	かよう
# 感心に	休まないで
# 休まないで	かよう
# 幼稚園へ	かよう
# 帰ると	歌って
# 唱歌を	歌って
# 歌って	ついて
# 毬を	ついて
# ついて	ぶら下げる
# 時々	ぶら下げる
# 吾輩を	ぶら下げる
# 尻尾で	ぶら下げる
# 	食わないから
# 吾輩は	食わないから
# 御馳走も	食わないから
# 食わないから	肥りもしないが
# 別段	肥りもしないが
# 肥りもしないが	暮している
# まずまず	健康で
# 健康で	ならずに
# 跛にも	ならずに
# ならずに	暮している
# その	日
# 日	暮している
# その日を	暮している
# 鼠は	取らない
# 決して	取らない
# おさんは	嫌いである
# 未だに	嫌いである
# 名前は	つけてくれないが
# まだ	つけてくれないが
# つけてくれないが	終るつもりだ
# 欲を	ないから
# いっても	ないから
# 際限が	ないから
# ないから	終るつもりだ
# 生涯	終るつもりだ
# この	教師の
# 教師の	家で無名の
# 家で無名の	猫で
# 猫で	終るつもりだ
# 	ありがたい
# 吾輩は	有名になったので
# 新年来	有名になったので
# 多少	有名になったので
# 有名になったので	ありがたい
# 猫ながら	感ぜらるるのは
# ちょっと	感ぜらるるのは
# 鼻が	感ぜらるるのは
# 高く	感ぜらるるのは
# 感ぜらるるのは	ありがたい
# 	来た
# 元朝	来た
# 早々	来た
# 主人の	許へ
# 許へ	来た
# 一枚の	絵端書が
# 絵端書が	来た
# これは	年始状であるが
# 彼の	交友某画家からの
# 交友某画家からの	年始状であるが
# 年始状であるが	書いてある
# 上部を	塗って
# 赤	下部を
# 下部を	塗って
# 深緑りで	塗って
# 塗って	踞っている
# その	真中に
# 真中に	踞っている
# 一の	動物が
# 動物が	踞っている
# 蹲	踞っている
# 踞っている	ところを
# ところを	書いてある
# パステルで	書いてある
# 主人は	いう
# 例の	書斎で
# 書斎で	眺めたりして
# この	絵を
# 絵を	眺めたりして
# 横から	見たり
# 見たり	眺めたりして
# 竪から	眺めたりして
# 眺めたりして	いう
# うまい色だなと	いう
# すでに	感服した
# 一応	感服した
# 感服した	ものだから
# ものだから	見たりしている
# もう	するかと
# やめに	するかと
# するかと	思うと
# 思うと	見たりしている
# やはり	見たりしている
# 横から	見たり
# 見たり	見たりしている
# 竪から	見たりしている
# からだを	拗じ向けたり
# 拗じ向けたり	見るようにしたり
# 手を	延ばして
# 延ばして	見るようにしたり
# 年寄が	見るようにしたり
# 三世相を	見るようにしたり
# 見るようにしたり	見ている
# または	むいて
# 窓の	方へ
# 方へ	むいて
# むいて	持って来たりして
# 鼻の	先まで
# 先まで	持って来たりして
# 持って来たりして	見ている
# 早く	やめてくれないと
# やめてくれないと	たまらない
# 膝が	揺れて
# 揺れて	たまらない
# 険呑で	たまらない
# ようやくの	事で
# 事で	劇しくなくなったと
# 動揺が	劇しくなくなったと
# あまり	劇しくなくなったと
# 劇しくなくなったと	思ったら
# 思ったら	云う
# 小さな	声で
# 声で	かいたのだろうと
# 一体	かいたのだろうと
# 何を	かいたのだろうと
# かいたのだろうと	云う
# 主人は	感服したが
# 絵端書の	色には
# 色には	感服したが
# 感服したが	見える
# かいてある	動物の
# 動物の	正体が
# 正体が	分らぬので
# 分らぬので	見える
# さっきから	した
# 苦心を	した
# した	ものと
# ものと	見える
# そんな	絵端書かと
# 分らぬ	絵端書かと
# 絵端書かと	思いながら
# 思いながら	肖像だ
# 寝ていた	眼を
# 眼を	開いて
# 上品に	開いて
# 半ば	開いて
# 開いて	肖像だ
# 落ちつき	払って
# 払って	見ると
# 見ると	ない
# 紛れも	ない
# ない	肖像だ
# 自分の	肖像だ
# 主人のように	極め込んだ
# アンドレア・デル・サルトを	極め込んだ
# 極め込んだ	ものでもあるまいが
# ものでもあるまいが	出来ている
# 画家だけに	整って
# 形体も	色彩も
# 色彩も	整って
# ちゃんと	整って
# 整って	出来ている
# 誰が	見たって
# 見たって	相違ない
# 猫に	相違ない
# 少し	ある
# 眼識の	ある
# ある	ものなら
# ものなら	描いてある
# 猫の	中でも
# 中でも	猫じゃない
# 他の	猫じゃない
# 猫じゃない	吾輩である
# 吾輩である	事が
# 事が	わかるように
# 判然と	わかるように
# わかるように	描いてある
# 立派に	描いてある
# この	くらい
# くらい	苦心するかと
# 明瞭な	事を
# 事を	分らずに
# 分らずに	苦心するかと
# かくまで	苦心するかと
# 苦心するかと	思うと
# 思うと	気の毒になる
# 少し	気の毒になる
# 人間が	気の毒になる
# 出来る事なら	知らしてやりたい
# その	絵が
# 絵が	云う
# 吾輩であると	云う
# 云う	事を
# 事を	知らしてやりたい
# 吾輩であると	云う
# 云う	事は
# 事は	分らないにしても
# よし	分らないにしても
# 分らないにしても	分らしてやりたい
# せめて	分らしてやりたい
# 猫であるという	事だけは
# 事だけは	分らしてやりたい
# しかし	しておいた
# 人間という	ものは
# ものは	おらん動物であるから
# 到底	解し得る
# 吾輩	猫属の
# 猫属の	言語を
# 言語を	解し得る
# 解し得る	くらいに
# くらいに	浴して
# 天の	恵に
# 恵に	浴して
# 浴して	おらん動物であるから
# おらん動物であるから	しておいた
# 残念ながら	しておいた
# そのままに	しておいた
# 	断っておきたいが
# ちょっと	断っておきたいが
# 読者に	断っておきたいが
# 断っておきたいが	よくない
# 元来	何ぞと
# 人間が	何ぞと
# 何ぞと	いうと
# いうと	よくない
# 猫々と	癖が
# 事もなげに	もって
# 軽侮の	口調を
# 口調を	もって
# もって	評価する
# 吾輩を	評価する
# 評価する	癖が
# 癖が	あるは
# あるは	よくない
# はなはだ	よくない
# 人間の	糟から
# 糟から	出来て
# 牛と	馬が
# 馬が	出来て
# 出来て	考えるのは
# 牛と	馬の
# 馬の	糞から
# 糞から	製造されたごとく
# 猫が	製造されたごとく
# 製造されたごとく	考えるのは
# 考えるのは	事でもあろうが
# 自分の	無智に
# 無智に	心付かんで
# 心付かんで	する
# 高慢な	顔を
# 顔を	する
# する	教師などには
# 教師などには	事でもあろうが
# ありがちの	事でもあろうが
# 事でもあろうが	者じゃない
# はたから	見て
# 見て	見っとも
# あまり	見っとも
# 見っとも	者じゃない
# いい	者じゃない
# いくら	出来ぬ
# 猫だって	出来ぬ
# そう	出来ぬ
# 粗末簡便には	出来ぬ
# よそ目には	特色などはないようであるが
# 一列一体	平等無差別
# 平等無差別	猫も
# どの	猫も
# 猫も	特色などはないようであるが
# 自家固有の	特色などはないようであるが
# 特色などはないようであるが	出来るのである
# 猫の	社会に
# 社会に	這入って
# 這入って	見ると
# 見ると	出来るのである
# なかなか	複雑な
# 複雑な	もので
# もので	出来るのである
# 十人十色という	人間界の
# 人間界の	語は
# 語は	出来るのである
# そのまま	出来るのである
# ここにも	出来るのである
# 応用が	出来るのである
# 目付でも	鼻付でも
# 鼻付でも	足並でも
# 毛並でも	足並でも
# 足並でも	違う
# みんな	違う
# 髯の	張り具合から
# 張り具合から	至るまで
# 耳の	立ち按排
# 立ち按排	垂れ加減に
# 尻尾の	垂れ加減に
# 垂れ加減に	至るまで
# 至るまで	ない
# 同じ	ものは
# ものは	ない
# 一つも	ない
# 器量	不器量
# 不器量	好き嫌い
# 好き嫌い	粋無粋の
# 粋無粋の	数を
# 数を	悉くして
# 悉くして	云っても
# 千差万別と	云っても
# 云っても	差支えない
# 差支えない	くらいである
# そのように	存しているにもかかわらず
# 判然たる	区別が
# 区別が	存しているにもかかわらず
# 存しているにもかかわらず	ものだから
# 人間の	眼は
# 眼は	ものだから
# ただ	いって
# 向上とか	いって
# 何とか	いって
# いって	見ている
# 空ばかり	見ている
# 見ている	ものだから
# ものだから	気の毒だ
# 吾輩の	性質は
# 性質は	出来ぬのは
# 無論	識別する
# 相貌の	末を
# 末を	識別する
# 識別する	事すら
# 事すら	出来ぬのは
# 到底	出来ぬのは
# 出来ぬのは	気の毒だ
# 同類相求むとは	分らぬ
# 昔	しから
# しから	語だ
# ある	語だ
# 語だ	そうだが
# そうだが	分らぬ
# その通り	分らぬ
# 餅屋は	餅屋
# 餅屋	猫で
# 猫は	猫で
# 猫で	分らぬ
# 猫の	事なら
# 事なら	分らぬ
# やはり	分らぬ
# 猫でなくては	分らぬ
# いくら	発達したって
# 人間が	発達したって
# 発達したって	駄目である
# こればかりは	駄目である
# いわんや	いうと
# 実際を	いうと
# いうと	ないのだから
# 彼等が	信じているごとく
# 自ら	信じているごとく
# 信じているごとく	ないのだから
# えらくも	ないのだから
# 何とも	ないのだから
# ないのだから	むずかしい
# なおさら	むずかしい
# また	仕方がない
# いわんや	乏しい
# 同情に	乏しい
# 乏しい	吾輩の
# 吾輩の	主人のごときは
# 主人のごときは	解すると
# 相互を	解すると
# 残り	なく
# なく	解すると
# 解すると	いうが
# いうが	仕方がない
# 愛の	第一義であるという
# 第一義であるという	ことすら
# ことすら	分らない
# 分らない	男なのだから
# 男なのだから	仕方がない
# 彼は	ない
# 性の	悪い
# 悪い	牡蠣のごとく
# 牡蠣のごとく	吸い付いて
# 書斎に	吸い付いて
# 吸い付いて	ない
# かつて	向って
# 外界に	向って
# 向って	開いた
# 口を	開いた
# 開いた	事が
# 事が	ない
# それで	達観したような
# 自分だけは	達観したような
# すこぶる	達観したような
# 達観したような	面構を
# 面構を	しているのは
# しているのは	おかしい
# ちょっと	おかしい
# 達観しない	証拠には
# 証拠には	あるのに
# 現に	あるのに
# 吾輩の	肖像が
# 肖像が	あるのに
# 眼の	前に
# 前に	あるのに
# あるのに	悟った
# 少しも	悟った
# 悟った	様子も
# 様子も	なく
# なく	すましているのでも
# 今年は	すましているのでも
# 征露の	第二年目だから
# 第二年目だから	すましているのでも
# 大方熊の	画だろうなどと
# 画だろうなどと	知れぬ
# 気の	知れぬ
# 知れぬ	ことを
# ことを	いって
# いって	すましているのでも
# すましているのでも	わかる
# 	持って来た
# 吾輩が	考えていると
# 主人の	膝の
# 膝の	上で
# 上で	ねむりながら
# 眼を	ねむりながら
# ねむりながら	考えていると
# かく	考えていると
# 考えていると	持って来た
# やがて	持って来た
# 下女が	持って来た
# 第二の	絵端書を
# 絵端書を	持って来た
# 見ると	している
# 活版で	行列して
# 舶来の	猫が
# 猫が	行列して
# 四五疋ずらりと	行列して
# 行列して	している
# ペンを	握ったり
# 握ったり	開いたり
# 書物を	開いたり
# 開いたり	している
# 勉強を	している
# その	内の
# 内の	一疋は
# 一疋は	躍っている
# 席を	離れて
# 離れて	躍っている
# 机の	角で
# 角で	躍っている
# 西洋の	猫じゃ
# 猫じゃ	躍っている
# 猫じゃを	躍っている
# その上に	かいて
# 日本の	墨で
# 墨で	かいて
# 吾輩は猫であると	かいて
# 黒々と	かいて
# かいて	認められてある
# 右の	側に
# 側に	読むや
# 書を	読むや
# 読むや	認められてある
# 躍るや	猫の
# 猫の	春一日という
# 春一日という	俳句さえ
# 俳句さえ	認められてある
# これは	来たので
# 主人の	旧門下生より
# 旧門下生より	来たので
# 来たので	見たって
# 誰が	見たって
# 見たって	一見して
# 一見して	わかるはずであるのに
# 意味が	わかるはずであるのに
# わかるはずであるのに	悟らないと
# 迂	主人は
# 濶な	主人は
# 主人は	悟らないと
# まだ	悟らないと
# 悟らないと	見えて
# 見えて	捻って
# 不思議そうに	捻って
# 首を	捻って
# 捻って	言った
# はてな	言った
# 今年は	言った
# 猫の	年かなと
# 年かなと	言った
# 独言を	言った
# 吾輩が	有名になったのを
# これほど	有名になったのを
# 有名になったのを	着かずに
# 未だ	着かずに
# 気が	着かずに
# 着かずに	いると
# いると	見える
# ところへ	持ってくる
# 下女が	持ってくる
# また	持ってくる
# 第三の	端書を
# 端書を	持ってくる
# 今度は	絵端書ではない
# 恭賀新年と	かいて
# かいて	ある
# 傍らに	ある
# 乍恐縮かの	猫へも
# 猫へも	ある
# 宜しく	奉
# 御伝声	奉
# 奉	願上候と
# 願上候と	ある
# いかに	迂遠な
# 迂遠な	主人でも
# 主人でも	あれば
# こう明らさまに	書いて
# 書いて	あれば
# あれば	分る
# 分る	ものと
# ものと	見えて
# 見えて	付いたように
# ようやく	付いたように
# 気が	付いたように
# 付いたように	見た
# フンと	言いながら
# 言いながら	見た
# 吾輩の	顔を
# 顔を	見た
# その	眼付が
# 眼付が	思われた
# 今までとは	違って
# 違って	含んでいるように
# 多少	含んでいるように
# 尊敬の	意を
# 意を	含んでいるように
# 含んでいるように	思われた
# 今まで	認められなかった
# 世間から	認められなかった
# 存在を	認められなかった
# 認められなかった	主人が
# 主人が	こしたのも
# 急に	こしたのも
# 一個の	新面目を
# 新面目を	こしたのも
# 施	こしたのも
# こしたのも	考える
# 全く	御蔭だと
# 吾輩の	御蔭だと
# 御蔭だと	思えば
# 思えば	至当だろうと
# この	くらいの
# くらいの	眼付は
# 眼付は	至当だろうと
# 至当だろうと	考える
# おりから	鳴る
# 門の	格子が
# 格子が	鳴る
# チリン	チリン
# チリン	チリリリリンと
# チリリリリンと	鳴る
# 大方	来客であろう
# 来客であろう	来客なら
# 来客なら	出る
# 下女が	出る
# 取次に	出る
# 吾輩は	極めているのだから
# 肴屋の	梅公が
# 梅公が	くる
# くる	時の
# 時の	ほかは
# ほかは	極めているのだから
# 出ない	事に
# 事に	極めているのだから
# 極めているのだから	おった
# 平気で	おった
# もとのごとく	おった
# 主人の	膝に
# 膝に	坐って
# 坐って	おった
# すると	見る
# 主人は	見る
# 高利貸にでも	飛び込まれたように
# 飛び込まれたように	して
# 不安な	顔付を
# 顔付を	して
# して	見る
# 玄関の	方を
# 方を	見る
# 何でも	するのが
# 年賀の	客を
# 客を	するのが
# 受けて酒の	相手を
# 相手を	するのが
# するのが	厭らしい
# 人間も	偏屈になれば
# この	くらい
# くらい	偏屈になれば
# 偏屈になれば	ない
# 申し分は	ない
# そんなら	すればよいのに
# 早くから	すればよいのに
# 外出でも	すればよいのに
# すればよいのに	無い
# それほどの	勇気も
# 勇気も	無い
# いよいよ	あらわしている
# 牡蠣の	根性を
# 根性を	あらわしている
# しばらく	すると
# すると	なりましたと
# 下女が	来て
# 来て	なりましたと
# 寒月さんが	なりましたと
# おいでに	なりましたと
# なりましたと	いう
# この	寒月という
# 寒月という	男は
# 男は	旧門下生であったそうだが
# やはり	旧門下生であったそうだが
# 主人の	旧門下生であったそうだが
# 旧門下生であったそうだが	話しである
# 今では	卒業して
# 学校を	卒業して
# 卒業して	立派になっているという
# 何でも	立派になっているという
# 主人より	立派になっているという
# 立派になっているという	話しである
# この	男が
# 男が	訳か
# どういう	訳か
# 訳か	来る
# よく	来る
# 主人の	所へ
# 所へ	来る
# 遊びに	来る
# 来ると	いる
# 自分を	いる
# 恋って	いる
# いる	女が
# 女が	有りそうな
# 有りそうな	無さそうな
# 無さそうな	面白そうな
# 世の中が	面白そうな
# 面白そうな	並べては
# つまらなそうな	艶っぽいような
# 凄いような	艶っぽいような
# 艶っぽいような	文句ばかり
# 文句ばかり	並べては
# 並べては	帰る
# 主人のような	人間を
# しなびかけた	人間を
# 人間を	求めて
# 求めて	行かぬが
# わざわざ	来るのから
# こんな	話しを
# 話しを	しに
# しに	来るのから
# 来るのから	して
# して	行かぬが
# 合点が	行かぬが
# 行かぬが	面白い
# あの	牡蠣的主人が
# 牡蠣的主人が	聞いて
# そんな	談話を
# 談話を	聞いて
# 聞いて	打つのは
# 時々	打つのは
# 相槌を	打つのは
# 打つのは	面白い
# なお	面白い
# しばらく	しました
# 御無沙汰を	しました
# 実は	向かないのでと
# 去年の	暮から
# 暮から	活動している
# 大に	活動している
# 活動している	ものですから
# ものですから	向かないのでと
# 出よう出ようと	思っても
# 思っても	向かないのでと
# つい	向かないのでと
# この	方角へ
# 方角へ	向かないのでと
# 足が	向かないのでと
# 向かないのでと	見たような
# 羽織の	紐を
# 紐を	ひねくりながら
# ひねくりながら	見たような
# 謎	見たような
# 見たような	事を
# 事を	いう
# どっちの	方角へ
# 方角へ	向く
# 足が	向く
# 向く	かねと
# かねと	引張る
# 主人は	引張る
# 真面目な	顔を
# 顔を	して
# して	引張る
# 黒木綿の	紋付羽織の
# 紋付羽織の	袖口を
# 袖口を	引張る
# この	羽織は
# 羽織は	はみ出している
# 木綿で	短かい
# ゆきが	短かい
# 短かい	はみ出している
# 下から	はみ出している
# べん	はみ出している
# べら者が	はみ出している
# 左右へ	はみ出している
# 五分くらいずつ	はみ出している
# エヘヘヘ少し	違った
# 違った	方角でと
# 方角でと	笑う
# 寒月君が	笑う
# 見ると	欠けている
# 今日は	欠けている
# 前歯が	欠けている
# 一枚	欠けている
# 君歯を	どうかしたかねと
# どうかしたかねと	転じた
# 主人は	転じた
# 問題を	転じた
# ええ実は	食いましてね
# ある	所で
# 所で	食いましてね
# 椎茸を	食いましてね
# 食いましてね	食ったって
# 何を	食ったって
# 	食ったんで
# その	食ったんで
# 少し	食ったんで
# 椎茸を	食ったんで
# 椎茸の	傘を
# 傘を	噛み切ろうとしたら
# 前歯で	噛み切ろうとしたら
# 噛み切ろうとしたら	欠けましたよ
# ぼろりと	欠けましたよ
# 歯が	欠けましたよ
# 欠けましたよ	爺臭いね
# 椎茸で	かける
# 前歯が	かける
# かける	なんざ
# なんざ	爺臭いね
# 何だか	爺臭いね
# 俳句には	なるかも知れないが
# なるかも知れないが	ならんようだなと
# 恋には	ならんようだなと
# ならんようだなと	叩く
# 平手で	叩く
# 吾輩の	頭を
# 頭を	叩く
# 軽く	叩く
# ああ	例のですか
# その	猫が
# 猫が	例のですか
# 例のですか	肥ってるじゃありませんかそれなら
# なかなか	肥ってるじゃありませんかそれなら
# 肥ってるじゃありませんかそれなら	黒にだって
# 車屋の	黒にだって
# 黒にだって	負けそうも
# 負けそうも	ありませんね
# ありませんね	ものだと
# 立派な	ものだと
# ものだと	賞める
# 寒月君は	賞める
# 大に	賞める
# 吾輩を	賞める
# 近頃大分	大きくなったのさと
# 大きくなったのさと	なぐる
# 自慢そうに	なぐる
# 頭を	なぐる
# ぽかぽか	なぐる
# 賞められたのは	得意であるが
# 得意であるが	痛い
# 頭が	痛い
# 少々	痛い
# 一昨夜も	やりましてねと
# ちょいと	やりましてねと
# 合奏会を	やりましてねと
# やりましてねと	戻す
# 寒月君は	戻す
# また	戻す
# 話しを	戻す
# もとへ	戻す
# どこで	ならんでもよいでしょう
# どこでも	ならんでもよいでしょう
# そりゃ御聞きに	ならんでもよいでしょう
# ヴァイオリンが	面白かったです
# 三挺と	ピヤノの
# ピヤノの	伴奏で
# 伴奏で	面白かったです
# なかなか	面白かったです
# ヴァイオリンも	なると
# 三挺くらいに	なると
# なると	聞かれる
# 下手でも	聞かれる
# 聞かれる	ものですね
# 二人は	まじりましたが
# 女で	まじりましたが
# 私が	まじりましたが
# その	中へ
# 中へ	まじりましたが
# まじりましたが	思いました
# 自分でも	弾けたと
# 善く	弾けたと
# 弾けたと	思いました
# 思いました	何者かねと
# ふんそして	女というのは
# その	女というのは
# 女というのは	何者かねと
# 何者かねと	問いかける
# 主人は	問いかける
# 羨ましそうに	問いかける
# 元来	惚れる
# 主人は	惚れる
# 平常	枯木寒巌のような
# 枯木寒巌のような	顔付は
# 顔付は	している
# している	ものの
# ものの	実のところは
# 実のところは	惚れる
# 決して	方ではない
# 婦人に	方ではない
# 冷淡な	方ではない
# 方ではない	惚れる
# かつて	読んだら
# 西洋の	小説を
# 或る	小説を
# 小説を	読んだら
# 読んだら	出て来て
# その	中に
# 中に	ある
# ある	一人物が
# 一人物が	出て来て
# 出て来て	惚れる
# それが	惚れる
# 大抵の	婦人には
# 婦人には	惚れる
# 必ず	惚れる
# ちょっと	惚れる
# 勘定を	して
# して	見ると
# 見ると	通る
# 往来を	通る
# 通る	婦人の
# 婦人の	七割弱には
# 七割弱には	恋着するという
# 恋着するという	事が
# 事が	書いてあったのを
# 諷刺的に	書いてあったのを
# 書いてあったのを	見て
# 見て	男である
# これは	真理だと
# 真理だと	感心した
# 感心した	男である
# くらいな	男である
# そんな	男が
# 浮気な	男が
# 男が	送っているかと
# 何故	送っているかと
# 牡蠣的生涯を	送っているかと
# 送っているかと	云うのは
# 云うのは	分らない
# 吾輩猫などには	分らない
# 到底	分らない
# 或	人は
# 人は	云うし
# 失恋の	ためだとも
# ためだとも	云うし
# 云うし	云うしまた
# 或人は	云うしまた
# 胃弱の	せいだとも
# せいだとも	云うしまた
# 云うしまた	云う
# 或人は	云う
# 金が	なくて
# なくて	云う
# 臆病な	性質だからだとも
# 性質だからだとも	云う
# どっちに	したって
# したって	関係する
# 明治の	歴史に
# 歴史に	関係する
# 関係する	人物でもないのだから
# ほどな	人物でもないのだから
# 人物でもないのだから	構わない
# しかし	事実である
# 寒月君の	女連れを
# 女連れを	尋ねた
# 羨まし	気に
# 気に	尋ねた
# 尋ねた	事だけは
# 事だけは	事実である
# 寒月君は	食い切った
# 面白そうに	挟んで
# 口取の	蒲鉾を
# 蒲鉾を	挟んで
# 箸で	挟んで
# 挟んで	食い切った
# 半分前歯で	食い切った
# 吾輩はまた	せぬかと
# 欠けは	せぬかと
# せぬかと	心配したが
# 心配したが	大丈夫であった
# 今度は	大丈夫であった
# なに二人とも	去る
# 去る	所の
# 所の	令嬢ですよ
# 令嬢ですよ	ありませんと
# 御存じの	方じゃ
# 方じゃ	ありませんと
# ありませんと	する
# 余所余所しい返事を	する
# ナールと	引張ったが
# 主人は	引張ったが
# 引張ったが	考えている
# ほどを	略して
# 略して	考えている
# 寒月君は	見る
# もう	善い
# 善い	時分だと
# 加減な	時分だと
# 時分だと	思った
# 思った	ものか
# ものか	見る
# どうも	好い
# 好い	天気ですな
# 天気ですな	落ちたので
# 御閑なら	もしましょうか
# ごいっしょに	もしましょうか
# 散歩で	もしましょうか
# もしましょうか	落ちたので
# 旅順が	落ちたので
# 落ちたので	景気ですよと
# 市中は	景気ですよと
# 大変な	景気ですよと
# 景気ですよと	して
# 促が	して
# して	見る
# 主人は	立つ
# 旅順の	陥落より
# 陥落より	聞きたいと
# 女連の	身元を
# 身元を	聞きたいと
# 聞きたいと	云う
# 云う	顔で
# 顔で	考え込んでいたが
# しばらく	考え込んでいたが
# 考え込んでいたが	した
# ようやく決心を	した
# した	ものと
# ものと	見えて
# 見えて	立つ
# それじゃ	出ると
# 出ると	しようと
# しようと	思い切って
# 思い切って	立つ
# やはり	着た
# 黒木綿の	紋付羽織に
# 紋付羽織に	着た
# 兄の	紀念とかいう
# 紀念とかいう	来着古る
# 二十年	来着古る
# 来着古る	した結城紬の
# した結城紬の	綿入を
# 綿入を	着た
# 着た	ままである
# いくら	丈夫だって
# 結城紬が	丈夫だって
# 丈夫だって	たまらない
# こう	着つづけでは
# 着つづけでは	たまらない
# 所々が	薄くなって
# 薄くなって	透かして
# 日に	透かして
# 透かして	見ると
# 見ると	見える
# 裏から	当てた
# つぎを	当てた
# 当てた	針の
# 針の	目が
# 目が	見える
# 主人の	服装には
# 服装には	ない
# 師走も	正月も
# 正月も	ない
# ふだん着も	余所ゆきも
# 余所ゆきも	ない
# 出る	ときは
# ときは	出る
# 懐手を	して
# して	出る
# ぶらりと	出る
# ほかに	着る
# 着る	物が
# 物が	ないからか
# ないからか	着換えないのか
# 有っても	面倒だから
# 面倒だから	着換えないのか
# 着換えないのか	分らぬ
# 吾輩には	分らぬ
# ただし	思われない
# これだけは	思われない
# 失恋の	ためとも
# ためとも	思われない
# 	あとで
# 両人が	出て
# 出て	行った
# 行った	あとで
# あとで	頂戴した
# 吾輩は	頂戴した
# ちょっと	失敬して
# 失敬して	頂戴した
# 寒月君の	食い切った
# 食い切った	蒲鉾の
# 蒲鉾の	残りを
# 残りを	頂戴した
# 吾輩も	猫ではない
# この	頃では
# 頃では	猫ではない
# 普通一般の	猫ではない
# まず	あると
# 桃川如燕以後の	猫か
# 猫か	あると
# グレーの	金魚を
# 金魚を	偸んだ
# 偸んだ	猫くらいの
# 猫くらいの	資格は
# 資格は	あると
# 充分	あると
# あると	思う
# 車屋の	黒などは
# 黒などは	ない
# 固より	ない
# 眼中に	ない
# 蒲鉾の	一切くらい
# 一切くらい	頂戴したって
# 頂戴したって	云われる
# 人から	云われる
# かれこれ	云われる
# 云われる	事も
# 事も	なかろう
# それに	事ではない
# この	人目を
# 人目を	忍んで
# 忍んで	するという
# 間食を	するという
# するという	癖は
# 癖は	事ではない
# 何も	限った
# 吾等猫族に	限った
# 限った	事ではない
# うちの	御三などは
# 御三などは	失敬している
# よく	失敬しては
# 細君の	留守中に
# 留守中に	失敬しては
# 餅菓子などを	失敬しては
# 失敬しては	頂戴し
# 頂戴し	失敬している
# 頂戴しては	失敬している
# 御三ばかりじゃない	仕付を
# 現に	上品な
# 上品な	仕付を
# 仕付を	受けつつあると
# 受けつつあると	吹聴せられている
# 細君から	吹聴せられている
# 吹聴せられている	小児ですら
# 小児ですら	ある
# この	傾向が
# 傾向が	ある
# 四五日前の	ことであったが
# ことであったが	着いた
# 二人の	小供が
# 小供が	覚まして
# 馬鹿に	覚まして
# 早くから	覚まして
# 眼を	覚まして
# 覚まして	着いた
# まだ	寝ている
# 主人夫婦の	寝ている
# 寝ている	間に
# 間に	対い合うて
# 対い合うて	着いた
# 食卓に	着いた
# 彼等は	例であるが
# 毎朝主人の	食う
# 食う	麺麭の
# 麺麭の	幾分に
# 幾分に	食うのが
# 砂糖を	つけて
# つけて	食うのが
# 食うのが	例であるが
# 例であるが	添えてあった
# この	日は
# 日は	添えてあった
# ちょうど	置かれて
# 砂糖壺が	置かれて
# 卓の	上に
# 上に	置かれて
# 置かれて	添えてあった
# 匙さえ	添えてあった
# いつものように砂糖を	分配してくれる
# 分配してくれる	ものが
# ものが	ないので
# ないので	あけた
# 大きい	方が
# 方が	すくい出して
# やがて	すくい出して
# 壺の	中から
# 中から	すくい出して
# 一匙の	砂糖を
# 砂糖を	すくい出して
# すくい出して	あけた
# 自分の	皿の
# 皿の	上へ
# 上へ	あけた
# すると	小さいのが
# 小さいのが	あけた
# 姉の	した通り
# した通り	あけた
# 同分量の	砂糖を
# 砂糖を	あけた
# 同方法で	あけた
# 自分の	皿の
# 皿の	上に
# 上に	あけた
# 少らく両人は	睨み合っていたが
# 睨み合っていたが	加えた
# 大きいのが	加えた
# また	加えた
# 匙を	とって
# とって	加えた
# 一杯を	加えた
# わが	皿の
# 皿の	上に
# 上に	加えた
# 小さいのも	した
# すぐ	とって
# 匙を	とって
# とって	した
# わが	分量を
# 分量を	した
# 姉と	同一に
# 同一に	した
# すると	すくった
# 姉がまた	すくった
# 一杯	すくった
# 妹も	負けずに
# 負けずに	附加した
# 一杯を	附加した
# 姉が	とる
# また	とる
# 壺へ	懸ける
# 手を	懸ける
# 懸ける	とる
# 妹が	とる
# また	とる
# 匙を	とる
# 見ている	間に
# 間に	重なって
# 一杯一杯一杯と	重なって
# 重なって	入れてしまった
# ついには	入れてしまった
# 両人の	皿には
# 皿には	堆くなって
# 山盛の	砂糖が
# 砂糖が	堆くなって
# 堆くなって	入れてしまった
# 壺の	中には
# 中には	入れてしまった
# 一匙の	砂糖も
# 砂糖も	余って
# 余って	おらんようになった
# おらんようになった	とき
# とき	入れてしまった
# 主人が	寝ぼけ
# 寝ぼけ	出て来て
# 眼を	擦りながら
# 擦りながら	出て来て
# 寝室を	出て来て
# 出て来て	しゃくい出した
# せっかく	しゃくい出した
# しゃくい出した	砂糖を
# 砂糖を	入れてしまった
# 元のごとく	壺の
# 壺の	中へ
# 中へ	入れてしまった
# こんな	ところを
# ところを	見ると
# 見ると	劣っているようだ
# 人間は	公平という
# 利己主義から	割り出した
# 割り出した	公平という
# 公平という	念は
# 念は	優っているかも知れぬが
# 猫より	優っているかも知れぬが
# 優っているかも知れぬが	劣っているようだ
# 智慧は	劣っているようだ
# かえって	劣っているようだ
# 猫より	劣っているようだ
# そんなに	しない
# 山盛に	しない
# しない	うちに
# うちに	しまえばいいにと
# 早く	しまえばいいにと
# 甞めて	しまえばいいにと
# しまえばいいにと	思ったが
# 思ったが	見物していた
# 例のごとく	通じないのだから
# 吾輩の	言う
# 言う	事などは
# 事などは	通じないのだから
# 通じないのだから	見物していた
# 気の毒ながら	黙って
# 御櫃の	上から
# 上から	黙って
# 黙って	見物していた
# 寒月君と	出掛けた
# 出掛けた	主人は
# 主人は	九時頃であった
# どこを	歩行いた
# どう	歩行いた
# 歩行いた	ものか
# ものか	九時頃であった
# その	晩
# 晩	帰って来て
# 遅く	帰って来て
# 帰って来て	就いたのは
# 翌日	就いたのは
# 食卓に	就いたのは
# 就いたのは	九時頃であった
# 例の	御櫃の
# 御櫃の	上から
# 上から	拝見していると
# 拝見していると	食っている
# 主人は	食っている
# だまって	食っている
# 雑煮を	食っている
# 代えては	食い
# 食い	食う
# 代えては	食う
# 餅の	切れは
# 切れは	小さいが
# 小さいが	置いた
# 何でも	七切食って
# 六切か	七切食って
# 七切食って	残して
# 最後の	一切れを
# 一切れを	残して
# 椀の	中へ
# 中へ	残して
# 残して	置いた
# もう	よそうと
# よそうと	置いた
# 箸を	置いた
# 他人が	すると
# そんな	我儘を
# 我儘を	すると
# すると	承知しないのであるが
# なかなか	承知しないのであるが
# 承知しないのであるが	平気ですましている
# 主人の	威光を
# 威光を	振り
# 振り	平気ですましている
# 廻わして	平気ですましている
# 得意なる	彼は
# 彼は	平気ですましている
# 濁った	汁の
# 汁の	中に
# 中に	焦げ爛れた
# 焦げ爛れた	餅の
# 餅の	死骸を
# 死骸を	見て
# 見て	平気ですましている
# 妻君が	出して
# 袋戸の	奥から
# 奥から	出して
# タカジヤスターゼを	出して
# 出して	置くと
# 卓の	上に
# 上に	置くと
# 置くと	飲まんと
# 主人は	飲まんと
# それは	利かないから
# 利かないから	飲まんと
# 飲まんと	いう
# でも	あるそうですから
# あなた澱粉質の	ものには
# ものには	あるそうですから
# 大変	あるそうですから
# 功能が	あるそうですから
# あるそうですから	召し上ったらいいでしょうと
# 召し上ったらいいでしょうと	飲ませたがる
# 澱粉だろうが	駄目だよと
# 何だろうが	駄目だよと
# 駄目だよと	出る
# 頑固に	出る
# あなたは	厭きっぽいと
# ほんとに	厭きっぽいと
# 厭きっぽいと	いう
# 細君が	独言のように
# 独言のように	いう
# 厭きっぽいのじゃない	薬が
# 薬が	利かんのだ
# 利かんのだ	上ったじゃありませんか
# それだって	上ったじゃありませんか
# せんだってじゅうは	利くと
# 大変に	利く
# よく	利く
# 利く	利くと
# よく	利くと
# 利くと	おっしゃって
# おっしゃって	上ったじゃありませんか
# 毎日	毎日
# 毎日	上ったじゃありませんか
# 上ったじゃありませんか	利かないのだよと
# こないだうちは	利いたのだよ
# 利いたのだよ	利かないのだよと
# この	頃は
# 頃は	利かないのだよと
# 利かないのだよと	する
# 対句のような	返事を
# 返事を	する
# そんなに	飲んだり
# 飲んだり	止めたりしちゃ
# 止めたりしちゃ	直らないわねえと
# いくら	ある
# 功能の	ある
# ある	薬でも
# 薬でも	利く
# 利く	気遣いは
# 気遣いは	直らないわねえと
# ありません	よくなくっちゃあ
# もう少し	よくなくっちゃあ
# 辛防が	よくなくっちゃあ
# よくなくっちゃあ	直らないわねえと
# 胃弱なんぞは	直らないわねえと
# ほかの	病気た
# 病気た	直らないわねえと
# あ	違って
# 違って	直らないわねえと
# 直らないわねえと	顧みる
# お盆を	持って
# 持って	控えた
# 控えた	御三を
# 御三を	顧みる
# それは	ところでございます
# 本当の	ところでございます
# もう少し	召し上って
# 召し上って	ならないと
# ご覧に	ならないと
# ならないと	わかりますまいと
# とても	善い
# 善い	薬か
# 薬か	薬か
# 悪い	薬か
# 薬か	わかりますまいと
# わかりますまいと	持つ
# 御三は	持つ
# 一も	二も
# 二も	なく
# なく	持つ
# 細君の	肩を
# 肩を	持つ
# 何でも	いい
# いい	飲まんのだから
# 飲まんのだから	飲まんのだ
# 飲まんのだ	ものか
# 女なんかに	わかる
# 何が	わかる
# わかる	ものか
# ものか	黙っていろ
# 黙っていろ	女ですわと
# どうせ	女ですわと
# 女ですわと	突き付けて
# 細君が	突き付けて
# タカジヤスターゼを	突き付けて
# 主人の	前へ
# 前へ	突き付けて
# 突き付けて	切らせようとする
# 是非	切らせようとする
# 詰腹を	切らせようとする
# 主人は	這入る
# 何にも	云わず
# 云わず	這入る
# 立って	這入る
# 書斎へ	這入る
# 細君と	御三は
# 御三は	笑う
# 顔を	見合せて
# 見合せて	笑う
# にやにやと	笑う
# こんな	ときに
# ときに	付いて行って
# 後	からくっ
# からくっ	付いて行って
# 付いて行って	乗ると
# 膝の	上へ
# 上へ	乗ると
# 乗ると	逢わされるから
# 大変な	目に
# 目に	逢わされるから
# 逢わされるから	見ると
# そっと	廻って
# 庭から	廻って
# 廻って	上って
# 書斎の	椽側へ
# 椽側へ	上って
# 上って	見ると
# 障子の	隙から
# 隙から	覗いて
# 覗いて	見ると
# 見ると	おった
# 主人は	おった
# エピクテタスとか	云う
# 云う	人の
# 人の	本を
# 本を	披いて
# 披いて	おった
# 見て	おった
# もし	わかるなら
# それが	わかるなら
# 平常の	通り
# 通り	わかるなら
# わかるなら	ある
# ちょっと	えらい
# えらい	ところが
# ところが	ある
# 五六分	すると
# すると	叩き付けるように
# その	本を
# 本を	叩き付けるように
# 叩き付けるように	抛り出す
# 机の	上へ
# 上へ	抛り出す
# 大方	事だろうと
# そんな	事だろうと
# 事だろうと	思いながら
# 思いながら	注意していると
# なお	注意していると
# 注意していると	書きつけた
# 今度は	書きつけた
# 日記帳を	出して下のような
# 出して下のような	事を
# 事を	書きつけた
# 寒月と	神田辺を
# 根津	上野
# 上野	池の
# 池の	端
# 端	神田辺を
# 神田辺を	散歩
# 池の	端の
# 端の	待合の
# 待合の	前で
# 前で	きて
# 芸者が	きて
# 裾模様の	春着を
# 春着を	きて
# きて	ついていた
# 羽根を	ついていた
# 衣装は	美しいが
# 美しいが	まずい
# 顔は	まずい
# すこぶる	まずい
# 何となく	似ていた
# うちの猫に	似ていた
# 	ものだ
# 何も	出さなくっても
# 顔の	出さなくっても
# まず	出さなくっても
# い例に	出さなくっても
# 特に	出さなくっても
# 吾輩を	出さなくっても
# 出さなくっても	ものだ
# よさそうな	ものだ
# 吾輩だって	ありゃしない
# 喜多床へ	行って
# 行って	剃って
# 顔さえ	剃って
# 剃って	貰やあ
# 貰やあ	ありゃしない
# そんなに	異った
# 人間と	異った
# 異った	ところは
# ところは	ありゃしない
# 人間は	自惚れているから
# こう	自惚れているから
# 自惚れているから	困る
# 宝丹の	角を
# 角を	曲るとまた
# 曲るとまた	来た
# 一人芸者が	来た
# これは	見えた
# 背の	すらりと
# すらりと	した
# した	撫肩の
# 撫肩の	恰好よく
# 恰好よく	出来上った
# 出来上った	女で
# 女で	見えた
# 着ている	薄紫の
# 薄紫の	衣服も
# 衣服も	着こなされて
# 素直に	着こなされて
# 着こなされて	見えた
# 上品に	見えた
# 白い	歯を
# 歯を	出して
# 出して	笑いながら
# 笑いながら	云った
# 源ちゃん昨夕は	もんだからと
# つい	しかった
# 忙が	しかった
# しかった	もんだからと
# もんだからと	云った
# ただし	出た
# その	声は
# 声は	おったので
# 旅鴉のごとく	皺枯れて
# 皺枯れて	おったので
# おったので	感ぜられたから
# せっかくの	風采も
# 風采も	下落したように
# 大に	下落したように
# 下落したように	感ぜられたから
# 感ぜられたから	出た
# いわゆる	源ちゃんなるものの
# 源ちゃんなるものの	人なるかを
# いかなる	人なるかを
# 人なるかを	振り向いて
# 振り向いて	面倒になって
# 見るも	面倒になって
# 面倒になって	出た
# 懐手の	まま
# まま	出た
# 御成道へ	出た
# 寒月は	見えた
# 何となく	そわそわしているごとく
# そわそわしているごとく	見えた
# 人間の	心理ほど
# 心理ほど	解し難い
# 解し難い	ものは
# ものは	ない
# この	主人の
# 主人の	心は
# 今の	心は
# 心は	怒っているのだか
# 怒っているのだか	浮かれているのだかまたは
# 浮かれているのだかまたは	遺書に
# 哲人の	遺書に
# 遺書に	求めつつあるのか
# 一道の	慰安を
# 慰安を	求めつつあるのか
# 求めつつあるのか	分らない
# ちっとも	分らない
# 世の中を	冷笑しているのか
# 冷笑しているのか	交りたいのだか
# 世の中へ	交りたいのだか
# 交りたいのだか	起しているのか
# くだらぬ	事に
# 事に	起しているのか
# 肝癪を	起しているのか
# 起しているのか	しているのだか
# 物外に	しているのだか
# 超然と	しているのだか
# しているのだか	付かぬ
# さっぱり	付かぬ
# 見当が	付かぬ
# 猫などは	行くと
# そこへ	行くと
# 行くと	ものだ
# 単純な	ものだ
# 食いたければ	食い
# 食い	寝る
# 寝たければ	寝る
# 寝る	怒り
# 怒る	ときは
# ときは	怒り
# 一生懸命に	怒り
# 怒り	泣く
# 泣く	ときは
# ときは	泣く
# 絶体絶命に	泣く
# 第一日記などという	無用の
# 無用の	ものは
# ものは	決してつけない
# つける	必要が
# 必要が	ないからである
# 主人のように	ある
# 裏表の	ある
# ある	人間は
# 人間は	あるかも知れないが
# 日記でも	書いて
# 書いて	出されない
# 世間に	出されない
# 出されない	自己の
# 自己の	面目を
# 面目を	発揮する
# 暗室内に	発揮する
# 発揮する	必要が
# 必要が	あるかも知れないが
# あるかも知れないが	及ばぬと
# 我等猫属に	至ると
# 至ると	日記であるから
# 行住坐臥	日記であるから
# 行屎送尿ことごとく	日記であるから
# 真正の	日記であるから
# 日記であるから	及ばぬと
# 別段	して
# そんな	手数を
# 面倒な	手数を
# 手数を	して
# して	保存するには
# 己れの	真面目を
# 真面目を	保存するには
# 保存するには	及ばぬと
# 及ばぬと	思う
# 日記を	つける
# つける	ひまが
# ひまが	あるなら
# あるなら	事さ
# 椽側に	寝ているまでの
# 寝ているまでの	事さ
# 神田の	某亭で
# 某亭で	食う
# 晩餐を	食う
# 久し振りで	飲んだら
# 正宗を	飲んだら
# 二三杯	飲んだら
# 飲んだら	いい
# 今朝は	いい
# 胃の	具合が
# 具合が	いい
# 大変	いい
# 胃弱には	一番だと
# 晩酌が	一番だと
# 一番だと	思う
# タカジヤスターゼは	いかん
# 無論	いかん
# 誰が	云っても
# 何と	云っても
# 云っても	駄目だ
# どうしたって	利かない
# 利かない	ものは
# ものは	利かないのだ
# 無暗に	攻撃する
# タカジヤスターゼを	攻撃する
# 独りで	しているようだ
# 喧嘩を	しているようだ
# 今朝の	肝癪が
# 肝癪が	出す
# ちょっと	出す
# ここへ	出す
# 尾を	出す
# 人間の	日記の
# 日記の	本色は
# 本色は	存するのかも知れない
# こう	存するのかも知れない
# 云う辺に	存するのかも知れない
# せんだっては	廃すると
# 朝飯を	廃すると
# 廃すると	なると
# 胃が	なると
# よく	なると
# なると	云うたから
# 云うたから	見たが
# 二三日	やめて
# 朝飯を	やめて
# やめて	見たが
# 見たが	ない
# 腹が	鳴るばかりで
# ぐうぐう	鳴るばかりで
# 鳴るばかりで	ない
# 功能は	ない
# は	忠告した
# 是非香の物を	断てと
# 断てと	忠告した
# 彼の	説に
# 説に	よると
# よると	ある
# すべて	ある
# 胃病の	源因は
# 源因は	ある
# 漬物に	ある
# 漬物さえ	断てば
# 断てば	涸らす訳だから
# 胃病の	源を
# 源を	涸らす訳だから
# 涸らす訳だから	疑なしという
# 本復は	疑なしという
# 疑なしという	論法であった
# それから	触れなかったが
# 一週間ばかり	触れなかったが
# 香の物に	触れなかったが
# 箸を	触れなかったが
# 触れなかったが	食い出した
# 別段の	験も
# 験も	見えなかったから
# 見えなかったから	食い出した
# 近頃は	食い出した
# また	食い出した
# に	聞くと
# 聞くと	限る
# それは	限る
# 按腹揉療治に	限る
# ただし	ではゆかぬ
# 普通の	ではゆかぬ
# 皆川流という	揉み方で
# 古流な	揉み方で
# 揉み方で	やらせれば
# 一二度	やらせれば
# やらせれば	根治出来る
# 大抵の	胃病は
# 胃病は	根治出来る
# 安井息軒も	愛していた
# 大変	愛していた
# この	按摩術を
# 按摩術を	愛していた
# 坂本竜馬のような	豪傑でも
# 豪傑でも	うけたと
# 時々は	うけたと
# 治療を	うけたと
# うけたと	云うから
# 云うから	見た
# 早速	出掛けて
# 上根岸まで	出掛けて
# 出掛けて	揉まして
# 揉まして	見た
# ところが	やる
# 骨を	揉まなければ
# 揉まなければ	顛倒しなければ
# 癒らぬとか	顛倒しなければ
# 臓腑の	位置を
# 位置を	顛倒しなければ
# 一度	顛倒しなければ
# 顛倒しなければ	やる
# 根治が	しにくいとか
# しにくいとか	いって
# いって	やる
# それは	やる
# それは	やる
# 残酷な	揉み方を
# 揉み方を	やる
# 後で	したので
# 身体が	したので
# 綿のようになって	したので
# 昏睡病に	かかったような
# かかったような	心持ちが
# 心持ちが	したので
# したので	した
# 一度で	閉口して
# 閉口して	した
# やめに	した
# 君は	食うなと
# 是非固形体を	食うなと
# 食うなと	いう
# それから	見たが
# 一日牛乳ばかり	飲んで
# 飲んで	暮して
# 暮して	見たが
# 見たが	眠れなかった
# この	時は
# 時は	眠れなかった
# 腸の	中で
# 中で	して
# どぼりど	ぼりと
# ぼりと	して
# 音が	して
# して	出たように
# 大水でも	出たように
# 出たように	思われて
# 思われて	眠れなかった
# 終夜	眠れなかった
# 氏は	御覧と
# 横膈膜で	呼吸して
# 呼吸して	運動させれば
# 内臓を	運動させれば
# 運動させれば	健全になる
# 自然と	胃の
# 胃の	働きが
# 働きが	健全になる
# 健全になる	訳だから
# 訳だから	御覧と
# 試しに	やって
# やって	御覧と
# 御覧と	いう
# これも	やったが
# 多少	やったが
# やったが	困る
# 何となく	不安で
# 腹中が	不安で
# 不安で	困る
# それに	する
# 時々	思い出したように
# 思い出したように	する
# 一心不乱に	かかりは
# かかりは	する
# する	ものの
# ものの	立つと
# 五六分	立つと
# 立つと	忘れてしまう
# 忘れまいと	すると
# すると	かく
# 横膈膜が	なって
# 気に	なって
# なって	読む
# 本を	読む
# 読む	事も
# 事も	かく
# 文章を	かく
# かく	事も
# 事も	出来ぬ
# 美学者の	迷亭が
# 迷亭が	見て
# この	体を
# 体を	見て
# 見て	廃してしまった
# 産気の	ついた
# ついた	男じゃあるまいし
# 男じゃあるまいし	止すがいいと
# 止すがいいと	冷かしたから
# 冷かしたから	廃してしまった
# この	頃は
# 頃は	廃してしまった
# 先生は	云うから
# 蕎麦を	食ったら
# 食ったら	よかろうと
# よかろうと	云うから
# 云うから	食ったが
# 早速	食ったが
# かけともりを	食ったが
# かわるがわる	食ったが
# 食ったが	なかった
# これは	なかった
# 腹が	下るばかりで
# 下るばかりで	なかった
# 何等の	功能も
# 功能も	なかった
# 余は	駄目である
# 年来の	胃弱を
# 胃弱を	直す
# 直す	ために
# ために	出来得る
# 出来得る	限りの
# 限りの	方法を
# 方法を	講じて
# 講じて	見たが
# 見たが	駄目である
# すべて	駄目である
# ただ	ある
# 昨夜	傾けた
# 寒月と	傾けた
# 傾けた	三杯の
# 三杯の	正宗は
# 正宗は	ある
# たしかに	ある
# 利目が	ある
# これからは	しよう
# 毎晩	二三杯ずつ
# 二三杯ずつ	飲む
# 飲む	事に
# 事に	しよう
# 	あるまい
# これも	続く
# 決して	続く
# 長く	続く
# 続く	事は
# 事は	あるまい
# 主人の	心は
# 心は	変化している
# 吾輩の	眼球のように
# 眼球のように	なく
# 間断	なく
# なく	変化している
# 何を	やっても
# やっても	しない男である
# 永持の	しない男である
# その上	するから
# 日記の	上で
# 上で	心配している
# 胃病を	心配している
# こんなに	心配している
# 心配している	癖に
# 癖に	するから
# 表向は	するから
# 大に	するから
# 痩我慢を	するから
# するから	おかしい
# せんだって	尋ねて来て
# その	友人で
# 友人で	尋ねて来て
# 某という	学者が
# 学者が	尋ねて来て
# 尋ねて来て	ほかならないと
# 一種の	見地から
# 見地から	ほかならないと
# すべての	病気は
# 病気は	ほかならないと
# 父祖の	罪悪と
# 罪悪と	罪悪の
# 自己の	罪悪の
# 罪悪の	結果に
# 結果に	ほかならないと
# ほかならないと	云う
# 云う	議論を
# 議論を	した
# 大分研究した	ものと
# ものと	見えて
# 見えて	説であった
# 条理が	明晰で
# 明晰で	説であった
# 秩序が	説であった
# 整然として	説であった
# 立派な	説であった
# 気の毒ながら	ないのである
# うちの	主人などは
# 主人などは	ないのである
# 到底	反駁する
# これを	反駁する
# 反駁する	ほどの
# ほどの	頭脳も
# 頭脳も	学問も
# 学問も	ないのである
# しかし	した
# 自分が	苦しんでいる
# 胃病で	苦しんでいる
# 苦しんでいる	際だから
# 際だから	した
# 何とか	して
# かんとか	して
# 弁解を	して
# して	保とうと
# 自己の	面目を
# 面目を	保とうと
# 保とうと	思った
# 思った	者と
# 者と	見えて
# 見えて	胃弱だから
# 君の	説は
# 説は	面白いが
# 面白いが	胃弱だったぜと
# あの	カーライルは
# カーライルは	胃弱だったぜと
# 胃弱だったぜと	胃弱だから
# あたかも	胃弱だから
# カーライルが	胃弱だから
# 胃弱だから	云ったような
# 自分の	胃弱も
# 胃弱も	名誉であると
# 名誉であると	云ったような
# 云ったような	挨拶を
# 見当違いの	挨拶を
# 挨拶を	した
# すると	していた
# 友人は	極め付けたので
# カーライルが	胃弱だって
# 胃弱だって	なれないさと
# 胃弱の	病人が
# 病人が	なれないさと
# 必ず	なれないさと
# カーライルには	なれないさと
# なれないさと	極め付けたので
# 極め付けたので	していた
# 主人は	していた
# 黙然と	していた
# かくのごとく	富んでいるものの
# 虚栄心に	富んでいるものの
# 富んでいるものの	いいと
# 実際は	胃弱でない
# やはり	胃弱でない
# 胃弱でない	方が
# 方が	いいと
# いいと	見えて
# 見えて	始めるなどというのは
# 今夜から	始めるなどというのは
# 晩酌を	始めるなどというのは
# 始めるなどというのは	滑稽だ
# ちょっと	滑稽だ
# 考えて	見ると
# 見ると	影響かも知れない
# 今朝	食ったのも
# 雑煮を	食ったのも
# あんなに	食ったのも
# たくさん	食ったのも
# 食ったのも	影響かも知れない
# 昨夜	ひっくり返した
# 寒月君と	正宗を
# 正宗を	ひっくり返した
# ひっくり返した	影響かも知れない
# 吾輩も	見たくなった
# ちょっと	食って
# 雑煮が	食って
# 食って	見たくなった
# 	猫ではあるが
# 吾輩は	猫ではあるが
# 猫ではあるが	食う
# 大抵の	ものは
# ものは	食う
# 車屋の	黒のように
# 黒のように	する
# 横丁の	肴屋まで
# 肴屋まで	する
# 遠征を	する
# する	気力は
# 気力は	ないし
# ないし	身分でない
# 新道の	二絃琴の
# 二絃琴の	師匠の
# 師匠の	所の
# 所の	三毛のように
# 三毛のように	身分でない
# 贅沢は	身分でない
# 無論	身分でない
# 云	える
# える	身分でない
# 従って	方だ
# 存外	少ない
# 嫌は	少ない
# 少ない	方だ
# 小供の	食いこぼした
# 食いこぼした	麺麭も
# 麺麭も	食うし
# 食うし	なめる
# 餅菓子の	も
# も	なめる
# 香の物は	まずいが
# すこぶる	まずいが
# まずいが	ある
# 経験の	ため
# ため	やった
# 沢庵を	やった
# 二切ばかり	やった
# やった	事が
# 事が	ある
# 食って	見ると
# 見ると	もので
# 妙な	もので
# もので	食える
# 大抵の	ものは
# ものは	食える
# あれは	嫌だ
# 嫌だ	嫌だと
# これは	嫌だと
# 嫌だと	云うのは
# 云うのは	ところでない
# 贅沢な	我儘で
# 我儘で	いる
# 到底	いる
# 教師の	家に
# 家に	いる
# いる	猫などの
# 猫などの	口に
# 口に	すべき
# すべき	ところでない
# 主人の	話しに
# 話しに	よると
# よると	そうだ
# 仏蘭西に	あった
# バルザックという	小説家が
# 小説家が	あった
# あった	そうだ
# この	男が
# 男が	事である
# 大の	贅沢屋で
# 贅沢屋で	事である
# もっとも	事である
# これは	事である
# 口の	贅沢屋ではない
# 贅沢屋ではない	尽したという
# 小説家だけに	尽したという
# 文章の	贅沢を
# 贅沢を	尽したという
# 尽したという	事である
# バルザックが	書いている
# 或る	日
# 日	書いている
# 自分の	書いている
# 書いている	小説中の
# 小説中の	人間の
# 人間の	名を
# 名を	つけようと
# つけようと	思って
# 思って	見たが
# いろいろ	つけて
# つけて	見たが
# 見たが	気に入らない
# どうしても	気に入らない
# ところへ	来たので
# 友人が	来たので
# 遊びに	来たので
# 来たので	出掛けた
# いっしょに	出掛けた
# 散歩に	出掛けた
# 友人は	連れ出されたのであるが
# 固より	連れ出されたのであるが
# 何も	知らずに
# 知らずに	連れ出されたのであるが
# 連れ出されたのであるが	歩行いている
# バルザックは	考えだから
# 兼ねて	苦心している
# 自分の	苦心している
# 苦心している	名を
# 名を	目付ようという
# 目付ようという	考えだから
# 考えだから	歩行いている
# 往来へ	出ると
# 出ると	歩行いている
# 何も	見て
# しないで	見て
# 店先の	看板ばかり
# 看板ばかり	見て
# 見て	歩行いている
# ところが	ない
# やはり	気に入った
# 気に入った	名が
# 名が	ない
# 友人を	連れて
# 連れて	無暗にあるく
# 友人は	付いて行く
# 訳が	わからず
# わからず	付いて行く
# にくっ	付いて行く
# 彼等は	探険した
# ついに	探険した
# 朝から	探険した
# 晩まで	探険した
# 巴理を	探険した
# その	帰りがけに
# 帰りがけに	ついた
# バルザックは	ついた
# ふと	ある
# ある	裁縫屋の
# 裁縫屋の	看板が
# 看板が	ついた
# 目に	ついた
# 見ると	かいてある
# その	看板に
# 看板に	かいてある
# マーカスという	名が
# 名が	かいてある
# バルザックは	限る
# 手を	限る
# 拍って	限る
# これだ	これに
# これだ	これに
# これに	限る
# マーカスは	好い名じゃないか
# マーカスの	上へ
# 上へ	という
# という	頭文字を
# 頭文字を	つける
# つける	出来る
# すると	出来る
# 申し分の	ない
# ない	名が
# 名が	出来る
# でなくては	いかん
# ZMarcusは	うまい
# 実に	うまい
# どうも	作った
# 自分で	作った
# 作った	名は
# 名は	つけたつもりでも
# うまく	つけたつもりでも
# つけたつもりでも	故意とらしい
# 何となく	故意とらしい
# 故意とらしい	ところが
# ところが	あって
# あって	面白くない
# ようやくの	事で
# 事で	気に入った
# 気に入った	名が
# 名が	出来たと
# 出来たと	忘れて
# 友人の	迷惑は
# 迷惑は	忘れて
# まるで	忘れて
# 忘れて	嬉しがったと
# 一人	嬉しがったと
# 嬉しがったと	いうが
# いうが	話だ
# 小説中の	人間の
# 人間の	名前を
# 名前を	つけるに
# つけるに	探険しなくてはならぬようでは
# 一日巴理を	探険しなくてはならぬようでは
# 探険しなくてはならぬようでは	話だ
# 随分	かかる
# 手数の	かかる
# かかる	話だ
# 贅沢も	出来れば
# この	くらい
# くらい	出来れば
# 出来れば	ものだが
# 結構な	ものだが
# ものだが	出ない
# 吾輩のように	持つ
# 牡蠣的主人を	持つ
# 持つ	身の上では
# 身の上では	出ない
# とても	出ない
# そんな	気は
# 気は	出ない
# 何でも	いい
# いい	食えさえすればという
# 食えさえすればという	気に
# 気に	なるのも
# なるのも	むるところであろう
# 境遇の	しからし
# しからし	むるところであろう
# だから	思い出したからである
# 今雑煮が	食いたくなったのも
# ...
# 自由を	得た
# 得た	結果
# 結果	感じて
# 不自由を	感じて
# 感じて	困っている
# それだから	ものさ
# 西洋の	文明などは
# 文明などは	ものさ
# ちょっと	いいようでも
# いいようでも	ものさ
# つまり	ものさ
# 駄目な	ものさ
# これに	反して
# 反して	昔しから
# 東洋じゃ	昔しから
# 昔しから	した
# 心の	修行を
# 修行を	した
# その	方が
# 方が	正しいのさ
# 見給え	起して
# 個性発展の	結果
# 結果	起して
# みんな	起して
# 神経衰弱を	起して
# 起して	つかなくなった
# 始末が	つかなくなった
# つかなくなった	時
# 時	発見するから
# 王者の	民蕩々たりと
# 民蕩々たりと	云う
# 云う	句の
# 句の	価値を
# 価値を	始めて
# 始めて	発見するから
# 無為にして	化すと
# 化すと	云う
# 云う	語の
# 語の	馬鹿に
# 馬鹿に	出来ない
# 出来ない	事を
# 事を	悟るから
# しかし	ない
# 悟ったって	ない
# その	時は
# 時は	ない
# もう	ない
# しようが	ない
# アルコール中毒に	罹って
# 罹って	考えるような
# ああ	飲まなければ
# 酒を	飲まなければ
# 飲まなければ	よかったと
# よかったと	考えるような
# 考えるような	ものさ
# 先生方は	御説のようだが
# 大分厭世的な	御説のようだが
# 御説のようだが	妙ですね
# 私は	妙ですね
# いろいろ	伺っても
# 伺っても	感じません
# 何とも	感じません
# どう	云う
# 云う	ものでしょうと
# ものでしょうと	云う
# 寒月君が	云う
# そりゃ妻君を	持ち立てだからさと
# 持ち立てだからさと	迷亭君が
# 迷亭君が	解釈した
# すぐ	解釈した
# すると	云い出した
# 主人が	云い出した
# 突然	云い出した
# こんな	事を
# 事を	云い出した
# 妻を	持って
# 持って	ものだなどと
# 女は	ものだなどと
# いい	ものだなどと
# ものだなどと	思うと
# 思うと	飛んだ
# 飛んだ	間違に
# 間違に	なる
# 参考の	ためだから
# ためだから	聞かせる
# おれが	面白い
# 面白い	物を
# 物を	読んで
# 読んで	聞かせる
# よく	聴くがいいと
# 聴くがいいと	取り上げて
# 最前書斎から	持って来た
# 持って来た	本を
# 古い	本を
# 本を	取り上げて
# 取り上げて	云うと
# この	本は
# 本は	本だが
# 古い	本だが
# 本だが	分ってると
# この	時代から
# 時代から	分ってると
# 女の	わるい
# わるい	事は
# 事は	分ってると
# 歴然と	分ってると
# 分ってると	云うと
# 云うと	寒月君が
# 少し	驚きましたな
# 元来	本ですかと
# いつ	頃の
# 頃の	本ですかと
# 本ですかと	聞く
# タマス・ナッシと	云って
# 云って	著書だ
# 十六世紀の	著書だ
# いよいよ	驚ろいた
# その	時分
# 時分	云った
# すでに	云った
# 私の	妻の
# 妻の	悪口を
# 悪口を	云った
# 云った	ものが
# ものが	あるんですか
# いろいろ	あるが
# 女の	悪口が
# 悪口が	あるが
# あるが	聞くがいい
# その	内には
# 内には	這入る訳だから
# 是非君の	妻も
# 妻も	這入る訳だから
# 這入る訳だから	聞くがいい
# ええ	聞きますよ
# ありがたい	事に
# 事に	なりましたね
# まず	紹介すべしと
# 古来の	賢哲が
# 賢哲が	紹介すべしと
# 女性観を	紹介すべしと
# 紹介すべしと	書いてある
# みんな	聞いてるよ
# 独身の	僕まで
# 僕まで	聞いてるよ
# アリストートル曰く女は	とるべし
# どうせ	碌でなしなれば
# 碌でなしなれば	とるべし
# 嫁を	とるなら
# とるなら	とるべし
# 大きな	嫁より
# 嫁より	とるべし
# 小さな	嫁を
# 嫁を	とるべし
# 大きな	碌で
# 碌で	なしより
# なしより	災少なし
# 小さな	碌で
# 碌で	なしの
# なしの	方が
# 方が	災少なし
# 寒月君の	妻君は
# 妻君は	大きいかい
# 大きいかい	小さいかい
# 大きな	碌で
# 碌で	なしの
# なしの	部ですよ
# ハハハハ	こりゃ面白い本だ
# さああとを	読んだ
# 或る	人問う
# 人問う	これ最大奇蹟
# いかなるか	これ最大奇蹟
# 賢者	答えて
# 答えて	貞婦
# 曰く	貞婦
# 賢者って	だれですか
# 名前は	書いてない
# どうせ	振られた
# 振られた	賢者に
# 賢者に	相違ないね
# 次には	出ている
# ダイオジニスが	出ている
# 或る	人問う
# 人問う	時において
# 妻を	娶る
# 娶る	いずれの
# いずれの	時において
# 時において	すべきか
# ダイオジニス	答えて
# 答えて	遅し
# 曰く青年は	未だし
# 未だし	遅し
# 老年は	遅し
# すでに	遅し
# 先生樽の	中で
# 中で	考えたね
# ピサゴラス曰く天下に	あり
# 三の	もの
# 恐るべき	もの
# もの	あり
# あり	曰く女
# 曰く火	曰く水
# 曰く水	曰く女
# 希臘の	哲学者などは
# 哲学者などは	ものだね
# 存外	迂
# 迂	事を
# 濶な	事を
# 事を	云う
# 云う	ものだね
# 僕に	云わせると
# 云わせると	恐るべき
# 天下に	恐るべき
# 恐るべき	もの
# もの	なし
# 火に	入って
# 入って	焼けず
# 焼けず	溺れずだけで
# 水に	入って
# 入って	溺れずだけで
# 溺れずだけで	行き詰る
# 独仙君	ちょっと
# ちょっと	行き詰る
# 女に	逢って
# 逢って	とろけずだろうと
# とろけずだろうと	出る
# 迷亭先生が	出る
# 援兵に	出る
# 主人は	読む
# さっさと	読む
# あとを	読む
# ソクラチスは	云えり
# 婦女子を	御するは
# 御するは	云えり
# 人間の	最大難事と
# 最大難事と	云えり
# デモスセニス曰く人も	せば
# しその	敵を
# 敵を	苦しめんと
# 苦しめんと	せば
# せば	あらず
# わが	女を
# 女を	与うるより
# 敵に	与うるより
# 与うるより	あらず
# 策の	得たるは
# 得たるは	あらず
# 家庭の	風波に
# 風波に	困憊起つ
# 日と	なく
# なく	なく
# 夜と	なく
# なく	困憊起つ
# 彼を	困憊起つ
# 困憊起つ	むるを
# あたわざるに至らし	むるを
# むるを	得れば
# 得れば	なりと
# セネカは	し
# 婦女と	無学をもって
# 無学をもって	し
# 世界における	二大厄と
# 二大厄と	し
# し	云い
# マーカス・オーレリアスは	似たりと
# 女子は	似たりと
# 制御し難き	点において
# 点において	似たりと
# 船舶に	似たりと
# 似たりと	云い
# 云い	せり
# プロータスは	せり
# 女子が	飾るの
# 綺羅を	飾るの
# 飾るの	性癖を
# 性癖を	もって
# もって	蔽うの
# その	天稟の
# 天稟の	醜を
# 醜を	蔽うの
# 蔽うの	陋策に
# 陋策に	もとづく
# もとづく	ものと
# ものと	せり
# ヴァレリアスかつ	おくって
# て書を	おくって
# その	友某に
# 友某に	おくって
# おくって	告げて
# 告げて	ものあらず
# 曰く天下に	ものあらず
# 何事も	ものあらず
# 女子の	忍んで
# 忍んで	なし得ざる
# なし得ざる	ものあらず
# 願わくは	垂れて
# 皇天憐を	垂れて
# 垂れて	むるなかれと
# 君を	して
# して	陥らし
# 彼等の	術中に
# 術中に	陥らし
# 陥らし	むるなかれと
# 彼また	何ぞ
# 曰く女子とは	何ぞ
# 友愛の	敵に
# 敵に	あらずや
# 避くべからざる	苦しみに
# 苦しみに	あらずや
# あらずや	あらずや
# 必然の	害に
# 害に	あらずや
# あらずや	あらずや
# 自然の	誘惑に
# 誘惑に	あらずや
# あらずや	毒に
# 蜜に	似たる
# 似たる	毒に
# 毒に	あらずや
# もし	不徳ならば
# 女子を	不徳ならば
# 棄つるが	不徳ならば
# 不徳ならば	云わざるべからず
# 彼等を	棄てざるは
# 棄てざるは	云わざるべからず
# 一層の	呵責と
# 呵責と	云わざるべからず
# もう	沢山です
# 沢山です	先生
# その	くらい
# くらい	拝聴すれば
# 愚妻の	わる口を
# わる口を	拝聴すれば
# 拝聴すれば	ありません
# 申し分は	ありません
# まだ	あるから
# 四五ページ	あるから
# あるから	どうだ
# ついでに	聞いたら
# 聞いたら	どうだ
# もう	するが
# たいていに	するが
# するが	いい
# もう	刻限だろうと
# 奥方の	御帰りの
# 御帰りの	刻限だろうと
# 刻限だろうと	迷亭先生が
# 迷亭先生が	からかい掛けると
# からかい掛けると	方で
# 茶の間の	方で
# 清や	清やと
# 清やと	呼ぶ
# 細君が	呼ぶ
# 下女を	呼ぶ
# 呼ぶ	声が
# 声が	する
# こいつは	大変だ
# 奥方は	君
# ちゃんと	いるぜ
# いるぜ	君
# ウフフフフと	云った
# 主人は	云った
# 笑いながら	云った
# 構う	ものかと
# ものかと	云った
# 奥さん	奥さん
# いつの間に	御帰りですか
# 茶の間では	ない
# しんとして	ない
# 答が	ない
# 奥さん	今のを
# 今のを	聞いたんですか
# 	ない
# 答は	ない
# まだ	ない
# 今の	はね
# はね	御考ではないですよ
# 御主人の	御考ではないですよ
# 十六世紀の	ナッシ君の
# ナッシ君の	説ですから
# 説ですから	御安心なさい
# 存じませんと	した
# 妻君は	した
# 遠くで	した
# 簡単な	返事を
# 返事を	した
# 寒月君は	笑った
# くすくすと	笑った
# 私も	存じませんで
# 存じませんで	失礼しました
# 失礼しました	アハハハハと
# アハハハハと	笑ってると
# 迷亭君は	笑ってると
# 遠慮なく	笑ってると
# 笑ってると	頼むとも
# 門口を	あけて
# あらあらしく	あけて
# あけて	頼むとも
# 頼むとも	あらわれた
# 御免とも	云わず
# 云わず	したと
# 大きな	足音が
# 足音が	したと
# したと	思ったら
# 思ったら	あらわれた
# 座敷の	唐紙が
# 唐紙が	あらわれた
# 乱暴に	あらわれた
# あいて	多々良三平君の
# 多々良三平君の	顔が
# 顔が	あらわれた
# その間から	あらわれた
# 三平君	今日は
# 今日は	似ず
# いつに	似ず
# 似ず	着て
# 真白な	シャツに
# シャツに	着て
# 卸立ての	フロックを
# フロックを	着て
# 着て	狂わせてる
# すでに	狂わせてる
# 幾分か	狂わせてる
# 相場を	狂わせてる
# 狂わせてる	上へ
# 上へ	置くと同時に
# 右の	手へ
# 手へ	下げた
# 重そうに	下げた
# 下げた	四本の
# 四本の	麦酒を
# 麦酒を	置くと同時に
# 縄ぐるみ	鰹節の
# 鰹節の	傍へ
# 傍へ	置くと同時に
# 置くと同時に	せず
# 挨拶も	せず
# せず	下ろしてかつ
# どっかと	下ろしてかつ
# 腰を	下ろしてかつ
# 下ろしてかつ	崩したのは
# 膝を	崩したのは
# 崩したのは	武者振である
# 目覚しい	武者振である
# 先生胃病は	いいですか
# 近来	いいですか
# こう	やって
# やって	うちにばかりいなさるから
# うちにばかりいなさるから	いかんたい
# まだ	悪いとも
# 悪いとも	いやしない
# 何とも	いやしない
# いわん	ばってんが
# ばってんが	かごたる
# 顔色は	かごたる
# よかな	かごたる
# 先生顔色が	黄です
# 黄です	ばい
# 近頃は	いいです
# 釣が	いいです
# 品川から	雇うて
# 舟を	雇うて
# 一艘	雇うて
# 雇うて	行きました
# 私は	行きました
# この前の	日曜に
# 日曜に	行きました
# 何か	釣れたかい
# 何も	釣れません
# 釣れなくっても	面白いのかい
# 浩然の気を	養うたい
# 養うたい	あなた。
# どうです	あなたがた
# 釣に	行った
# 行った	事が
# 事が	ありますか
# 大きな	海の
# 海の	上を
# 上を	あるくのですからねと
# 小舟で	あるくのですからねと
# 乗り廻わして	あるくのですからねと
# あるくのですからねと	容赦なく話しかける
# 誰彼の	容赦なく話しかける
# 僕は	なる
# 小さな	海の
# 海の	上を
# 上を	乗り廻してある
# 大船で	乗り廻してある
# 乗り廻してある	きた
# きた	いんだと
# いんだと	なる
# 迷亭君が	なる
# 相手に	なる
# どうせ	釣るなら
# 釣るなら	釣らなくっちゃ
# 鯨か	人魚でも
# 人魚でも	釣らなくっちゃ
# 釣らなくっちゃ	詰らないですと
# 詰らないですと	答えた
# 寒月君が	答えた
# そんな	ものが
# ものが	釣れますか
# 文学者は	ないですね
# 常識が	ないですね
# 僕は	ありません
# 文学者じゃ	ありません
# そうですか	あなたは
# 何ですか	あなたは
# 私のような	ビジネスマンに
# ビジネスマンに	なると
# なると	大切ですからね
# 常識が	大切ですからね
# 一番	大切ですからね
# 先生私は	富んで来ました
# 近来	富んで来ました
# よっぽど	富んで来ました
# 常識に	富んで来ました
# どうしても	いると
# あんな	所に
# 所に	いると
# いると	傍だから
# 傍が	傍だから
# 傍だから	なってしまうです
# おのずから	なってしまうです
# そう	なってしまうです
# 煙草でもですね	利かんですと
# 朝日や	敷島を
# 敷島を	ふかしていては
# ふかしていては	利かんですと
# 幅が	利かんですと
# 利かんですと	云いながら
# 云いながら	出して
# 吸口に	ついた
# 金箔の	ついた
# ついた	埃及煙草を
# 埃及煙草を	出して
# 出して	吸い出した
# すぱすぱ	吸い出した
# そんな	贅沢を
# 贅沢を	する
# する	金が
# 金が	あるのかい
# 金は	どうかなるたい
# なかばってんが	どうかなるたい
# 今に	どうかなるたい
# この	煙草を
# 煙草を	吸ってると
# 吸ってると	違います
# 大変信用が	違います
# 寒月君が	いい
# 珠を	磨くよりも
# 磨くよりも	いい
# 楽な	信用で
# 信用で	いい
# いい	かからない
# 手数が	かからない
# 軽便信用だねと	迷亭が
# 迷亭が	いうと
# 寒月に	いうと
# いうと	三平君は
# 寒月が	答えない
# 何とも	答えない
# 答えない	間に
# 間に	三平君は
# あなたが	寒月さんですか
# 博士にゃ	とうとうならんですか
# あなたが	ならん
# 博士に	ならん
# ならん	ものだから
# ものだから	しました
# 私が	貰う
# 貰う	事に
# 事に	しました
# いいえ	令嬢をです
# 金田家の	令嬢をです
# 実は	思うたですたい
# 御気の毒と	思うたですたい
# しかし	先生
# 先方で	是非貰うてくれ
# 是非貰うてくれ	貰うてくれと
# 貰うてくれと	云うから
# 云うから	先生
# とうとう	貰う
# 貰う	事に
# 事に	極めました
# 極めました	先生
# しかし	心配しています
# 寒月さんに	わるいと
# 義理が	わるいと
# わるいと	思って
# 思って	心配しています
# どうか御	遠慮なくと
# 遠慮なくと	云うと
# 寒月君が	云うと
# 云うと	主人は
# 貰いたければ	貰ったら
# 貰ったら	いいだろうと
# いいだろうと	する
# 曖昧な	返事を
# 返事を	する
# そいつは	話だ
# おめでたい	話だ
# だから	ないんだよ
# どんな	娘を
# 娘を	持っても
# 持っても	心配するが
# 心配するが	ないんだよ
# ものは	ないんだよ
# だれか	貰うと
# 貰うと	出来たじゃないか
# さっき	云った
# 僕が	云った
# 云った	通り
# 通り	出来たじゃないか
# ちゃんと	出来たじゃないか
# こんな	紳士の
# 立派な	紳士の
# 紳士の	御聟さんが
# 御聟さんが	出来たじゃないか
# 東風君新体詩の	種が
# 種が	出来た
# 早速	とりかかりたまえと
# とりかかりたまえと	迷亭君が
# 迷亭君が	調子づくと
# 例のごとく	調子づくと
# 調子づくと	三平君は
# あなたが	東風君ですか
# 東風君ですか	作ってくれませんか
# 結婚の	時に
# 時に	作ってくれませんか
# 何か	作ってくれませんか
# すぐ	して
# 活版に	して
# して	くばります
# 方々へ	くばります
# 太陽へも	出してもらいます
# ええ	作りましょう
# 何か	作りましょう
# 作りましょう	御入用ですか
# いつ頃	御入用ですか
# いつでも	いいです
# 今まで	作った
# 作った	うちでも
# うちでも	いいです
# その	代りです
# 披露の	とき
# とき	呼んで
# 呼んで	御馳走するです
# シャンパンを	飲ませるです
# 君シャンパンを	飲んだ
# 飲んだ	事が
# 事が	ありますか
# シャンパンは	旨いです
# 	呼ぶつもりですが
# 先生披露会の	ときに
# ときに	呼ぶつもりですが
# 楽隊を	呼ぶつもりですが
# 呼ぶつもりですが	どうでしょう
# 東風君の	作を
# 作を	して
# 譜に	して
# して	奏したら
# 奏したら	どうでしょう
# 先生	下さらんか
# 譜に	して
# して	下さらんか
# だれか	ものは
# この	うちに
# うちに	出来る
# 音楽の	出来る
# 出来る	ものは
# ものは	おらんですか
# 落第の	候補者寒月君は
# 候補者寒月君は	妙手だよ
# ヴァイオリンの	妙手だよ
# しっかり	頼んで
# 頼んで	見たまえ
# しかし	男だ
# シャンパンくらいじゃ	承知しそうもない
# 承知しそうもない	男だ
# シャンパンも	ですね
# 一瓶	四円や
# 四円や	五円の
# 五円の	じゃよく
# じゃよく	ないです
# 私の	御馳走するのは
# 御馳走するのは	安いのじゃないですが
# そんな	安いのじゃないですが
# 安いのじゃないですが	作ってくれませんか
# 君	一つ譜を
# 一つ譜を	作ってくれませんか
# ええ	作りますとも
# 作りますとも	作ります
# 一瓶	二十銭の
# 二十銭の	シャンパンでも
# シャンパンでも	作ります
# なんなら	作ります
# ただでも	作ります
# ただは	頼みません
# 頼みません	するです
# 御礼は	するです
# シャンパンが	いやなら
# いやなら	どうですと
# こう	云う
# 云う	御礼は
# 御礼は	どうですと
# どうですと	云いながら
# 云いながら	落す
# 上着の	隠袋の
# 隠袋の	なかから
# なかから	出して
# 七八枚の	写真を
# 写真を	出して
# 出して	落す
# ばらばらと	畳の
# 畳の	上へ
# 上へ	落す
# 半身が	ある
# 全身が	ある
# 立ってるのが	ある
# 坐ってるのが	ある
# 袴を	穿いてるが
# 穿いてるが	ある
# 振袖が	ある
# 高島田が	ある
# ことごとく	女子ばかりである
# 妙齢の	女子ばかりである
# 先生候補者が	あるです
# これだけ	あるです
# 寒月君と	東風君に
# 東風君に	周旋してもいいです
# この	うち
# うち	周旋してもいいです
# どれか	周旋してもいいです
# 御礼に	周旋してもいいです
# こりゃ	どうですと
# どうですと	付ける
# 一枚寒月君につき	付ける
# 是非周旋を	願いましょう
# これでも	いいですかと
# いいですかと	つきつける
# また	つきつける
# 一枚	つきつける
# それも	いいですね
# どれでも	いいです
# 君	多情ですね
# なかなか	多情ですね
# 先生	姪です
# これは	姪です
# 博士の	姪です
# この方は	いいです
# 性質が	いいです
# 極	いいです
# 年も	若いです
# これで	十七です
# 	千円あります
# これなら	千円あります
# 持参金が	千円あります
# 	こっちのは
# こっちのは	娘ですと
# 知事の	娘ですと
# 娘ですと	弁じ立てる
# 一人で	弁じ立てる
# それを	貰う
# みんな	貰う
# 貰う	訳にゃ
# 訳にゃ	いかないでしょうか
# みんなですか	張りたい
# それは	張りたい
# あまり	張りたい
# 慾	張りたい
# 多妻主義じゃないですが	肉食論者です
# 何でも	いいから
# いいから	よかろうと
# そんな	ものは
# ものは	よかろうと
# 早く	しまったら
# しまったら	よかろうと
# よかろうと	言い放ったので
# 主人は	言い放ったので
# 叱りつけるように	言い放ったので
# 言い放ったので	三平君は
# それじゃ	貰わんですねと
# どれも	貰わんですねと
# 貰わんですねと	押しながら
# 念を	押しながら
# 押しながら	収めた
# 写真を	収めた
# 一枚	一枚に
# 一枚に	収めた
# ポッケットへ	収めた
# 何だ	いそのビールは
# お見やげで	ござります
# 前祝に	買うて来ました
# 角の	酒屋で
# 酒屋で	買うて来ました
# 一つ	飲んで下さい
# 主人は	抜かせる
# 手を	呼んで
# 拍って	呼んで
# 下女を	呼んで
# 呼んで	抜かせる
# 栓を	抜かせる
# 主人	迷亭
# 迷亭	独仙
# 独仙	寒月
# 寒月	東風の
# 東風の	五君は
# 五君は	祝した
# 恭しく	捧げて
# コップを	捧げて
# 捧げて	祝した
# 三平君の	艶福を
# 艶福を	祝した
# 三平君は	様子で
# 大に	様子で
# 愉快な	様子で
# ここに	いる
# いる	諸君を
# 諸君を	招待しますが
# 披露会に	招待しますが
# 招待しますが	出てくれるでしょうねと
# みんな	出てくれますか
# 出てくれますか	出てくれるでしょうねと
# 出てくれるでしょうねと	云う
# おれは	いやだと
# いやだと	答える
# 主人は	答える
# すぐ	答える
# 私の	一生に
# 一生に	一度の
# 一度の	大礼です
# 大礼です	ばい
# 出てくんな	さらんか
# 少し	ごたるな
# 不人情の	ごたるな
# 不人情じゃないが	出ないよ
# おれは	出ないよ
# 着物が	ないですか
# 羽織と	袴くらい
# 袴くらい	しますたい
# どうでも	しますたい
# ちと	出るがよ
# 人中へも	出るがよ
# 出るがよ	かたい
# かたい	先生
# 有名な	人に
# 人に	紹介して上げます
# 真平	ご免だ
# 胃病が	癒ります
# 癒ります	ばい
# 癒らんでも	差支えない
# そげん頑固張りなさるなら	やむを得ません
# あなたは	来てくれますか
# どうです	来てくれますか
# 僕かね	是非行くよ
# 出来るなら	ものだ
# 媒酌人たるの	栄を
# 栄を	ものだ
# 得たいくらいの	ものだ
# シャンパンの	三々九度や
# 三々九度や	宵
# 春の	宵
#
# なに仲人は
# 鈴木の	藤さんだって
# 藤さんだって
# なるほど	そこいらだろうと
# そこいらだろうと	思った
# これは	残念だが
# 残念だが	仕方がない
# 仲人が	出来ても
# 二人	出来ても
# 出来ても	多過ぎるだろう
# 多過ぎるだろう	出席するよ
# ただの	人間として
# 人間として	出席するよ
# まさに	出席するよ
# あなたは	どうです
# 僕ですか	人釣白蘋紅蓼間
# 一竿風月閑生計	人釣白蘋紅蓼間
# 何ですか	唐詩選ですか
# それは	唐詩選ですか
# 何だか	わからんです
# わからんですか	困りますな
# 寒月君は	出てくれるでしょうね
# 今までの	関係も
# 関係も	あるから
# きっと	出る
# 出る	事に
# 事に	します
# します	奏するのを
# 僕の	作った
# 作った	曲を
# 曲を	奏するのを
# 楽隊が	奏するのを
# 奏するのを	きき落すのは
# きき落すのは	残念ですからね
# 君は	東風君
# どうです	東風君
# 出て御両人の	前で
# 前で	朗読したいです
# 新体詩を	朗読したいです
# そりゃ	愉快だ
# 先生	私は
# 私は	生れてから
# 生れてから	ないです
# こんな	事は
# 愉快な	事は
# 事は	ないです
# だから	飲みますと
# もう	飲みますと
# 一杯ビールを	飲みますと
# 飲みますと	買って来た
# 自分で	買って来た
# 買って来た	ビールを
# ビールを	飲んで
# 一人で	飲んで
# ぐいぐい	飲んで
# 飲んで	なった
# 真赤に	なった
# 	消えている
# 短かい秋の日は	消えている
# ようやく	暮れて
# 暮れて	見れば
# 巻煙草の	死骸が
# 死骸が	乱す
# 算を	乱す
# 乱す	火鉢の
# 火鉢の	なかを
# なかを	見れば
# 見れば	消えている
# 火は	消えている
# とくの	昔に
# 昔に	消えている
# さすが	尽きたと
# 呑気の	連中も
# 連中も	尽きたと
# 少しく	尽きたと
# 興が	尽きたと
# 尽きたと	見えて
# 見えて	大分遅くなった
# もう	帰ろうかと
# 帰ろうかと	立ち上がる
# まず	立ち上がる
# 独仙君が	立ち上がる
# つづいて	出る
# 僕も	帰ると
# 帰ると	出る
# 口々に	出る
# 玄関に	出る
# 寄席が	はねた
# はねた	あとのように
# あとのように	淋しくなった
# 座敷は	淋しくなった
# 主人は	入る
# 夕飯を	すまして
# すまして	入る
# 書斎に	入る
# 妻君は	縫う
# 肌寒の	襦袢の
# 襦袢の	襟を
# 襟を	かき合せて
# かき合せて	縫う
# 洗い晒しの	不断着を
# 不断着を	縫う
# 小供は	寝る
# 枕を	並べて
# 並べて	寝る
# 下女は	行った
# 湯に	行った
# 	呑気と
# 呑気と	見える
# 見える	人々も
# 人々も	見ると
# 心の	底を
# 底を	叩いて
# 叩いて	見ると
# 見ると	する
# どこか	悲しい
# 悲しい	音が
# 音が	する
# 悟ったようでも	踏まぬ
# 独仙君の	足は
# 足は	踏まぬ
# やはり	踏まぬ
# 地面の	ほかは
# ほかは	踏まぬ
# 気楽かも知れないが	世の中ではない
# 迷亭君の	世の中は
# 世の中は	世の中ではない
# 絵に	かいた
# かいた	世の中ではない
# 寒月君は	連れて来た
# 珠磨りを	やめて
# やめて	連れて来た
# とうとう	連れて来た
# お国から	連れて来た
# 奥さんを	連れて来た
# これが	順当だ
# しかし	退屈だろう
# 順当が	続くと
# 永く	続くと
# 続くと	退屈だろう
# 定めし	退屈だろう
# 東風君も	したら
# 今	十年
# 十年	したら
# したら	悟るだろう
# 無暗に	捧げる
# 新体詩を	捧げる
# 捧げる	事の
# 事の	非を
# 非を	悟るだろう
# 三平君に	至っては
# 至っては	むずかしい
# 水に	住む
# 住む	人か
# 人か	人か
# 山に	住む
# 住む	人か
# 人か	むずかしい
# ちと	むずかしい
# 鑑定が	むずかしい
# 生涯	三鞭酒を
# 三鞭酒を	御馳走して
# 御馳走して	得意と
# 得意と	思う
# 思う	事が
# 事が	出来れば
# 出来れば	結構だ
# 鈴木の	藤さんは
# 藤さんは	転がって行く
# どこまでも	転がって行く
# 転がれば	つく
# 泥が	つく
# 泥が	ついても
# ついても	転がれぬ
# 転がれぬ	ものよりも
# ものよりも	利く
# 幅が	利く
# 猫と	生れて
# 生れて	住む
# 人の	世に
# 世に	住む
# 住む	事
# 事	なる
# もはや	なる
# 二年越しに	なる
# 自分では	思うていたが
# これほどの	見識家は
# 見識家は	思うていたが
# またと	思うていたが
# あるまいと	思うていたが
# 思うていたが	吃驚した
# 先達てカーテル・ムルと	云う
# 云う	見ず知らずの
# 見ず知らずの	同族が
# 同族が	揚げたので
# 突然	揚げたので
# 大気を	揚げたので
# 揚げたので	吃驚した
# ちょっと	吃驚した
# よく	見たら
# よく	聞いて
# 聞いて	見たら
# 見たら	死んだのだが
# 実は	死んだのだが
# 百年前に	死んだのだが
# 死んだのだが	そうだ
# ふとした	好奇心から
# 好奇心から	なって
# わざと	なって
# 幽霊に	なって
# なって	驚かせる
# 吾輩を	驚かせる
# 驚かせる	ために
# ために	出張したのだ
# 遠い	冥土から
# 冥土から	出張したのだ
# 出張したのだ	そうだ
# この	猫は
# 猫は	あるそうだ
# 母と	する
# 対面を	する
# する	とき
# とき	出掛けた
# 挨拶の	しるしとして
# しるしとして	出掛けた
# 一匹の	肴を
# 肴を	出掛けた
# 啣えて	出掛けた
# 出掛けた	ところ
# ところ	あるそうだ
# 途中で	し切れなくなって
# とうとう	し切れなくなって
# 我慢が	し切れなくなって
# し切れなくなって	食ってしまったと
# 自分で	食ってしまったと
# 食ってしまったと	云う
# 云う	ほどの
# ほどの	不孝ものだけ
# 不孝ものだけ	あって
# あって	ほどで
# 才気も	負けぬ
# なかなか	負けぬ
# 人間に	負けぬ
# 負けぬ	ほどで
# ほどで	あるそうだ
# ある時などは	あるそうだ
# 詩を	作って
# 作って	驚かした
# 主人を	驚かした
# 驚かした	事も
# 事も	あるそうだ
# こんな	豪傑が
# 豪傑が	出現しているなら
# すでに	出現しているなら
# 一世紀も	出現しているなら
# 前に	出現しているなら
# 出現しているなら	帰臥してもいいはずであった
# 吾輩のような	碌で
# 碌で	なしは
# なしは	帰臥してもいいはずであった
# とうに	頂戴して
# 御暇を	頂戴して
# 頂戴して	帰臥してもいいはずであった
# 無何有郷に	帰臥してもいいはずであった
# 主人は	死ぬ
# 早晩	死ぬ
# 胃病で	死ぬ
# 金田の	じいさんは
# じいさんは	死んでいる
# 慾で	死んでいる
# もう	死んでいる
# 秋の	木の葉は
# 木の葉は	尽した
# 大概落ち	尽した
# 死ぬのが	定業で
# 万物の	定業で
# 定業で	役に立たないなら
# 生きていても	役に立たないなら
# あんまり	役に立たないなら
# 役に立たないなら	賢こいかも知れない
# 早く	死ぬだけが
# 死ぬだけが	賢こいかも知れない
# 諸先生の	説に
# 説に	従えば
# 従えば	帰するそうだ
# 人間の	運命は
# 運命は	帰するそうだ
# 自殺に	帰するそうだ
# 油断を	すると
# すると	生れなくてはならなくなる
# 猫も	生れなくてはならなくなる
# そんな	世に
# 窮屈な	世に
# 世に	生れなくてはならなくなる
# 恐るべき	事だ
# 何だか	くさくさして来た
# 気が	くさくさして来た
# 三平君の	ビールでも
# ビールでも	飲んで
# 飲んで	つけてやろう
# ちと	つけてやろう
# 景気を	つけてやろう
# 	廻る
# 勝手へ	廻る
# 秋風に	がたつく
# がたつく	戸が
# 戸が	あいてる
# 細目に	あいてる
# あいてる	間から
# 間から	吹き込んだと
# 吹き込んだと	見えて
# 見えて	消えているが
# ランプは	消えているが
# いつの間にか	消えているが
# 消えているが	さす
# 月夜と	思われて
# 思われて	さす
# 窓から	さす
# 影が	さす
# コップが	並んで
# 盆の	上に
# 上に	並んで
# 三つ	並んで
# 並んで	たまっている
# その	二つに
# 二つに	たまっている
# 茶色の	水が
# 水が	たまっている
# 半分ほど	たまっている
# 硝子の	中の
# 中の	ものは
# ものは	する
# 湯でも	冷たい
# 冷たい	気が
# 気が	する
# まして	照らされて
# 夜寒の	月影に
# 月影に	照らされて
# 照らされて	ならんでいる
# 静かに	ならんでいる
# 火消壺と	ならんでいる
# ならんでいる	液体の
# この	液体の
# 液体の	事だから
# 事だから	飲みたくもない
# 唇を	つけぬ
# つけぬ	先から
# 先から	飲みたくもない
# すでに	寒くて
# 寒くて	飲みたくもない
# しかし	試しだ
# ものは	試しだ
# 三平などは	した
# あれを	飲んでから
# 飲んでから	なって
# 真赤に	なって
# なって	した
# 熱苦しい	息遣いを
# 息遣いを	した
# 猫だって	飲めば
# 飲めば	陽気にならん
# 陽気にならん	事も
# 事も	あるまい
# どうせ	死ぬか
# いつ	死ぬか
# 死ぬか	知れぬ
# 知れぬ	命だ
# 何でも	ある
# 命の	ある
# ある	うちに
# うちに	しておく事だ
# 死んでから	悔やんでもおっつかない
# ああ	残念だと
# 残念だと	悔やんでもおっつかない
# 墓場の	影から
# 影から	悔やんでもおっつかない
# 思い切って	飲んで
# 飲んで	見ろと
# 見ろと	見ると
# 勢	よく
# よく	入れて
# 舌を	入れて
# 入れて	見ると
# ぴちゃぴちゃ	やって
# やって	見ると
# 見ると	驚いた
# 何だか	さされたように
# 舌の	先を
# 先を	さされたように
# 針で	さされたように
# さされたように	した
# ぴりりと	した
# 人間は	わからないが
# 何の	酔興で
# 酔興で	飲むのか
# こんな	ものを
# 腐った	ものを
# ものを	飲むのか
# 飲むのか	わからないが
# わからないが	飲み切れない
# 猫には	飲み切れない
# とても	飲み切れない
# どうしても	合わない
# 猫と	ビールは
# ビールは	合わない
# 性が	合わない
# これは	大変だと
# 大変だと	見たがまた
# 一度は	見たがまた
# 出した	舌を
# 舌を	引込めて
# 引込めて	見たがまた
# 見たがまた	考え直した
# 人間は	苦しと
# 口癖のように	苦しと
# 良薬口に	苦しと
# 苦しと	言って
# 言って	ひくと
# 風邪などを	ひくと
# ひくと	飲む
# 顔を	しかめて
# しかめて	飲む
# 変な	ものを
# ものを	飲む
# 飲むから	癒るのか
# 癒るのか	癒るのに
# 癒るのに	飲むのか
# 飲むのか	幸だ
# 今まで	疑問であったが
# 疑問であったが	幸だ
# ちょうど	いい
# いい	幸だ
# この	問題を
# 問題を	解決してやろう
# ビールで	解決してやろう
# 飲んで	にがくなったら
# 腹の中まで	にがくなったら
# にがくなったら	教えてやってもいい
# それまでの	事
# 事	教えてやってもいい
# もし	三平のように
# 三平のように	忘れる
# 前後を	忘れる
# 忘れる	ほど
# ほど	愉快になれば
# 愉快になれば	教えてやってもいい
# 空前の	儲け者で
# 儲け者で	教えてやってもいい
# 近所の	猫へ
# 猫へ	教えてやってもいい
# まあ	なるか
# どう	なるか
# なるか	任せて
# 運を	任せて
# 天に	任せて
# 任せて	やっつけると
# やっつけると	決心して
# 決心して	出した
# 再び	出した
# 舌を	出した
# 眼を	あいていると
# あいていると	飲みにくいから
# 飲みにくいから	眠ってまた
# しっかり	眠ってまた
# 眠ってまた	始めた
# ぴちゃぴちゃ	始めた
# 	起った
# 吾輩は	起った
# 我慢に	重ねて
# 我慢を	重ねて
# 重ねて	飲み干した
# ようやく	飲み干した
# 一杯のビールを	飲み干した
# 飲み干した	時
# 時	起った
# 妙な	現象が
# 現象が	起った
# 始めは	苦しかったのが
# 舌が	ぴりぴりして
# ぴりぴりして	圧迫されるように
# 口中が	圧迫されるように
# 外部から	圧迫されるように
# 圧迫されるように	苦しかったのが
# 苦しかったのが	折れなくなった
# 飲むに従って	なって
# ようやく楽に	なって
# なって	片付ける
# 一杯目を	片付ける
# 片付ける	時分には
# 時分には	折れなくなった
# 別段	折れなくなった
# 骨も	折れなくなった
# もう	やっつけた
# 大丈夫と	二杯目は
# 二杯目は	やっつけた
# 難なく	やっつけた
# ついでに	こぼれたのも
# 盆の	上に
# 上に	こぼれたのも
# こぼれたのも	拭うがごとく
# 拭うがごとく	収めた
# 腹内に	収めた
# それから	すくんでいた
# しばらくの	間は
# 間は	すくんでいた
# 自分で	伺う
# 自分の	動静を
# 動静を	伺う
# 伺う	ため
# ため	すくんでいた
# じっと	すくんでいた
# 次第に	暖かになる
# からだが	暖かになる
# 眼の	ふちが
# ふちが	する
# ぽうっと	する
# 耳が	ほてる
# 歌が	うたいたくなる
# 猫じゃ	踊りたくなる
# 猫じゃが	踊りたくなる
# 主人も	迷亭も
# 迷亭も	独仙も
# 独仙も	食えと
# 糞を	食えと
# 食えと	云う
# 云う	気に
# 気に	なる
# 金田の	じいさんを
# じいさんを	引掻いてやりたくなる
# 妻君の	鼻を
# 鼻を	食い欠きたくなる
# 最後に	立ちたくなる
# ふらふらと	立ちたくなる
# 起ったら	あるきたくなる
# よたよた	あるきたくなる
# こいつは	面白いと
# 面白いと	出たくなる
# そとへ	出たくなる
# 出ると	挨拶したくなる
# 御月様今晩はと	挨拶したくなる
# どうも	愉快だ
# 陶然とは	云うのだろうと
# こんな	事を
# 事を	云うのだろうと
# 云うのだろうと	思いながら
# 思いながら	運ばせてゆくと
# あても	なく
# なく	運ばせてゆくと
# そこ	かしこと
# かしこと	散歩するような
# 散歩するような	心持で
# しないような	心持で
# 心持で	ない
# しまりの	ない
# ない	足を
# 足を	運ばせてゆくと
# いい	加減に
# 加減に	運ばせてゆくと
# 運ばせてゆくと	眠い
# 何だか	眠い
# しきりに	眠い
# 寝ているのだか	あるいてるのだか
# あるいてるのだか	判然しない
# 眼は	あけるつもりだが
# あけるつもりだが	夥しい
# 重い	事
# 事	夥しい
# こう	なれば
# なれば	それまでだ
# 海だろうが	出したと
# 山だろうが	驚ろかないんだと
# 驚ろかないんだと	出したと
# 前足を	出したと
# ぐにゃりと	出したと
# 前へ	出したと
# 出したと	思う
# 思う	途端
# 途端	して
# ぼちゃんと	して
# 音が	して
# して	やられた
# はっと	云う
# 云う	うち
# うち	やられた
# どう	やられたのか
# やられたのか	考える
# 考える	間が
# 間が	ない
# ただ	やられたなと
# やられたなと	気がつくか
# 気がつくか	滅茶苦茶になってしまった
# つかないのに	滅茶苦茶になってしまった
# あとは	滅茶苦茶になってしまった
# 我に	帰った
# 帰った	ときは
# ときは	浮いている
# 水の上に	浮いている
# 苦しいから	掻いたが
# 爪で	もって
# もって	掻いたが
# 矢鱈に	掻いたが
# 掻いたが	もぐってしまう
# 掻ける	ものは
# ものは	水ばかりで
# 水ばかりで	もぐってしまう
# 掻くと	もぐってしまう
# すぐ	もぐってしまう
# 仕方がないから	飛び上っておいて
# 後足で	飛び上っておいて
# 飛び上っておいて	掻いたら
# 前足で	掻いたら
# 掻いたら	あった
# が	あった
# りりと	音が
# 音が	して
# して	あった
# わずかに	あった
# 手応が	あった
# ようやく	浮くから
# 頭だけ	浮くから
# 浮くから	落ちている
# どこだろうと	見廻
# 見廻	わすと
# わすと	落ちている
# 吾輩は	落ちている
# 大きな	甕の
# 甕の	中に
# 中に	落ちている
# この	甕は
# 甕は	使う
# 夏まで	称する
# 水葵と	称する
# 称する	水草が
# 水草が	茂っていたが
# 茂っていたが	使う
# その後	来て
# 烏の	勘公が
# 勘公が	来て
# 来て	食い尽した
# 葵を	食い尽した
# 食い尽した	上に
# 上に	使う
# 行水を	使う
# 行水を	使えば
# 使えば	減る
# 水が	減る
# 近来は	思ったが
# 大分減って	見えないなと
# 烏が	見えないなと
# 見えないなと	思ったが
# 先刻	思ったが
# 思ったが	寄らなかった
# 吾輩自身が	使おうなどとは
# 烏の	代りに
# 代りに	使おうなどとは
# こんな	所で
# 所で	使おうなどとは
# 行水を	使おうなどとは
# 使おうなどとは	寄らなかった
# 思いも	寄らなかった
# 	ある
# 水から	ある
# 縁までは	ある
# 四寸余も	ある
# 足を	のばしても
# のばしても	届かない
# 飛び上っても	出られない
# 呑気にしていれば	沈むばかりだ
# もがけば	あたるのみで
# がりがりと	甕に
# 甕に	あたるのみで
# 爪が	あたるのみで
# あたるのみで	気味だが
# あたった	時は
# 時は	気味だが
# 少し	浮く
# 浮く	気味だが
# 気味だが	もぐる
# すべれば	もぐる
# たちまち	もぐる
# ぐっと	もぐる
# もぐれば	苦しいから
# 苦しいから	やる
# すぐ	やる
# がりがりを	やる
# そのうち	疲れてくる
# からだが	疲れてくる
# 気は	焦るが
# 焦るが	利かなくなる
# 足は	利かなくなる
# さほど	利かなくなる
# ついには	分りにくくなった
# もぐる	ために
# ために	掻くのか
# 甕を	掻くのか
# 掻くのか	もぐるのか
# 掻く	ために
# ために	もぐるのか
# もぐるのか	分りにくくなった
# 自分でも	分りにくくなった
# 	考えた
# その	時
# 時	苦しいながら
# 苦しいながら	考えた
# こう	考えた
# こんな	呵責に
# 呵責に	逢うのは
# 逢うのは	願である
# つまり	願である
# 甕から	あがりたいばかりの
# 上へ	あがりたいばかりの
# あがりたいばかりの	願である
# あがりたいのは	山々であるが
# 山々であるが	知れ切っている
# 上がれないのは	知れ切っている
# 吾輩の	足は
# 足は	足らぬ
# 三寸に	足らぬ
# よし水の	面に
# 面に	浮いて
# からだが	浮いて
# 浮いて	ない
# 浮いた	所から
# 所から	のばしたって
# 思う存分	のばしたって
# 前足を	のばしたって
# のばしたって	あまる
# 五寸に	あまる
# あまる	甕の
# 甕の	縁に
# 縁に	ない
# 爪の	かかりようが
# かかりようが	ない
# 甕の	ふちに
# ふちに	なければ
# 爪の	かかりようが
# かかりようが	なければ
# なければ	あせっても
# いくらも	掻いても
# 掻いても	あせっても
# あせっても	しても
# 百年の	間身を
# 間身を	しても
# 粉に	しても
# しても	出られっこない
# 出られないと	分り切っている
# 分り切っている	ものを
# ものを	出ようとするのは
# 出ようとするのは	無理だ
# 無理を	通そうとするから
# 通そうとするから	苦しいのだ
# 自ら	苦しんで
# 求めて	苦しんで
# 苦しんで	罹っているのは
# 自ら	好んで
# 好んで	罹っているのは
# 拷問に	罹っているのは
# 罹っているのは	馬鹿気ている
# もう	よそう
# 勝手にするが	いい
# がりがりは	蒙るよと
# これぎりご免	蒙るよと
# 蒙るよと	した
# 前足も	後足も
# 後足も	尾も
# 頭も	尾も
# 尾も	抵抗しない
# 自然の	力に
# 力に	任せて
# 任せて	抵抗しない
# 抵抗しない	事に
# 事に	した
# 次第に	楽になってくる
# 苦しいのだか	ありがたいのだか
# ありがたいのだか	つかない
# 見当が	つかない
# 水の	中に
# 中に	いるのだか
# いるのだか	いるのだか
# 座敷の	上に
# 上に	いるのだか
# いるのだか	判然しない
# どこに	いても
# どうして	いても
# いても	ない
# 差支えは	ない
# ただ	楽である
# 否	感じ得ない
# 楽そのものすらも	感じ得ない
# 日月を	切り落し
# 切り落し	入る
# 天地を	粉韲して
# 粉韲して	入る
# 不可思議の	太平に
# 太平に	入る
# 吾輩は	死ぬ
# 死んで	得る
# この	太平を
# 太平を	得る
# 太平は	得られぬ
# 死ななければ	得られぬ
